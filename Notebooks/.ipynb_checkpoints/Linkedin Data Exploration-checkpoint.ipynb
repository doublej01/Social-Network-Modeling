# %% [markdown]
# ## Sprint 1 - Data Exploration and Basic EDA
#
# This notebook is the first notebook. It outlines processes to familiarize LinkedIn Job Postings dataset from 2023. Here, we will go over the data quality issues through various data cleaning methods and highlight any other notable observations regarding data processing. Then, the basic Exploratory Data Analysis (EDA) has been performed to showcase potential relationships between different variables and `views`, our target variable.
#
# Author: JJ Park
#
# Date: 28/02/2024

# %% [markdown]
# ## LinkedIn Job Postings 2023

# %% [markdown]
# ### Introduction

# %% [markdown]
# ### Dataset

# %% [markdown]
# Dataset has been sourced from: https://www.kaggle.com/datasets/arshkon/linkedin-job-postings/data.

# %% [markdown]
# ### Table of Contents
#
# 1. Data Dictionary
# 2. Data Loading
# 3. Data Cleaning - Datatypes
# 4. Data Cleaning - Duplicates
# 5. Data Cleaning - Null Values
# 6. Basic EDA
# 7. Summary

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# The data dictionary outlines all the variables from the `job_postings.csv` dataset. The descriptions of each variable are directly sourced from the author's Github: https://github.com/ArshKA/LinkedIn-Job-Scraper/blob/master/DatabaseStructure.md.

# %% [markdown]
# 1. `job_id`: The job ID as defined by LinkedIn (https://www.linkedin.com/jobs/view/{ job_id })
# 2. `company_id`: Identifier for the company associated with the job posting (maps to companies.csv)
# 3. `title`: Job title
# 4. `description`: Job description
# 5. `max_salary`: Maximum salary
# 6. `med_salary`: Median salary
# 7. `min_salary`: Minimum salary
# 8. `pay_period`: Pay period for salary (Hourly, Monthly, Yearly)
# 9. `formatted_work_type`: Type of work (Fulltime, Parttime, Contract)
# 10. `location`: Job location
# 11. `applies`: Number of applications that have been submitted
# 12. `original_listed_time`: Original time the job was listed
# 13. `remote_allowed`: Whether job permits remote work
# 14. `views`: Number of times the job posting has been viewed
# 15. `job_posting_url`: URL to the job posting on a platform
# 16. `application_url`: URL where applications can be submitted
# 17. `application_type`: Type of application process (offsite, complex/simple onsite)
# 18. `expiry`: Expiration date or time for the job listing
# 19. `closed_time`: Time to close job listing
# 20. `formatted_experience_level`: Job experience level (entry, associate, executive, etc)
# 21. `skills_desc`: Description detailing required skills for job
# 22. `listed_time`: Time when the job was listed
# 23. `posting_domain`: Domain of the website with application
# 24. `sponsored`: Whether the job listing is sponsored or promoted
# 25. `work_type`: Type of work associated with the job
# 26. `currency`: Currency in which the salary is provided
# 27. `compensation_type`: Type of compensation for the job
# 28. `scraped`: Has been scraped by `details_retriever`

# %% [markdown]
# ### Question of Interest
# How can we leverage the job postings data from LinkedIn to add significant value to both companies and job applicants? Here, we will tackle the `views` column by conducting preliminary EDA to find relationships between different variables within the dataset.
#
# - Company: what are the key features in a job posting that recruiters should emphasize to raise the number of views and attract more talents?
# - Applicant: can we predict the latest job trends by analyzing job postings with high views?

# %% [markdown]
# ## Data Loading

# %% [markdown]
# In this section, we will first load the LinkedIn dataset, then explore the dataset by checking the first and last few rows to improve our understanding.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('../Data/job_postings.csv')

# Display all the columns, avoiding truncated column names
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# Check the first few rows
df.head()
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
#    min_salary pay_period formatted_work_type          location  applies  \
# 0         NaN    MONTHLY           Full-time  Little River, SC      NaN
# 1         NaN        NaN           Full-time    Beaver Dam, WI      NaN
# 2         NaN        NaN           Full-time      Bessemer, AL      NaN
# 3         NaN     HOURLY           Full-time   Aliso Viejo, CA      NaN
# 4    205956.0     YEARLY           Full-time     United States      NaN
#
#    original_listed_time  remote_allowed  views  \
# 0          1.699090e+12             NaN    9.0
# 1          1.699080e+12             NaN    NaN
# 2          1.699080e+12             NaN    NaN
# 3          1.699080e+12             NaN    1.0
# 4          1.698970e+12             1.0    NaN
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
# 4  https://www.linkedin.com/jobs/view/3757937095/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#          expiry  closed_time formatted_experience_level  \
# 0  1.701680e+12          NaN                Entry level
# 1  1.701680e+12          NaN                        NaN
# 2  1.701680e+12          NaN                        NaN
# 3  1.701680e+12          NaN                Entry level
# 4  1.701680e+12          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
# 4                                                NaN  1.699090e+12
#
#              posting_domain  sponsored  work_type currency compensation_type  \
# 0  careers-demant.icims.com          0  FULL_TIME      USD       BASE_SALARY
# 1       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 2       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 3           jobs.apploi.com          0  FULL_TIME      USD       BASE_SALARY
# 4         careers.iherb.com          0  FULL_TIME      USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346

# %%
# Check the last few rows
df.tail()
# Out:
#           job_id  company_id                            title  \
# 33241  133114754  77766802.0                    Sales Manager
# 33242  108965123         NaN  Office Administrative Assistant
# 33243  102339515  52132271.0                  Franchise Owner
# 33244   85008768         NaN         Licensed Insurance Agent
# 33245    3958427    630152.0                 Stylist/ Clorist
#
#                                              description  max_salary  \
# 33241  Are you a dynamic and creative marketing profe...         NaN
# 33242  A fast-fashion wholesaler, is looking for a fu...         NaN
# 33243  DuctVentz is a dryer and A/C – heat vent clean...         NaN
# 33244  While many industries were hurt by the last fe...     52000.0
# 33245  Karen Marie is looking for an awesome experien...     80000.0
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 33241         NaN         NaN        NaN           Full-time
# 33242         NaN         NaN        NaN           Full-time
# 33243         NaN         NaN        NaN           Full-time
# 33244         NaN     45760.0     YEARLY           Full-time
# 33245         NaN     35000.0     YEARLY           Full-time
#
#                 location  applies  original_listed_time  remote_allowed  \
# 33241  Santa Clarita, CA      NaN          1.692830e+12             NaN
# 33242       New York, NY      2.0          1.699040e+12             NaN
# 33243     Greater Boston      NaN          1.699050e+12             NaN
# 33244          Chico, CA      NaN          1.692750e+12             NaN
# 33245        Chicago, IL      NaN          1.699050e+12             NaN
#
#        views                                    job_posting_url  \
# 33241    NaN  https://www.linkedin.com/jobs/view/133114754/?...
# 33242    4.0  https://www.linkedin.com/jobs/view/108965123/?...
# 33243    NaN  https://www.linkedin.com/jobs/view/102339515/?...
# 33244    5.0  https://www.linkedin.com/jobs/view/85008768/?t...
# 33245    7.0  https://www.linkedin.com/jobs/view/3958427/?tr...
#
#       application_url    application_type        expiry  closed_time  \
# 33241             NaN  ComplexOnsiteApply  1.695430e+12          NaN
# 33242             NaN  ComplexOnsiteApply  1.701630e+12          NaN
# 33243             NaN   SimpleOnsiteApply  1.701640e+12          NaN
# 33244             NaN  ComplexOnsiteApply  1.708300e+12          NaN
# 33245             NaN  ComplexOnsiteApply  1.714600e+12          NaN
#
#       formatted_experience_level  \
# 33241                        NaN
# 33242                        NaN
# 33243                        NaN
# 33244                        NaN
# 33245                        NaN
#
#                                              skills_desc   listed_time  \
# 33241                                                NaN  1.692830e+12
# 33242                                                NaN  1.699040e+12
# 33243                                                NaN  1.699050e+12
# 33244                                                NaN  1.692750e+12
# 33245  Must be a seasoned stylist with an existing bo...  1.699050e+12
#
#       posting_domain  sponsored  work_type currency compensation_type  \
# 33241            NaN          0  FULL_TIME      NaN               NaN
# 33242            NaN          0  FULL_TIME      NaN               NaN
# 33243            NaN          0  FULL_TIME      NaN               NaN
# 33244            NaN          1  FULL_TIME      USD       BASE_SALARY
# 33245            NaN          0  FULL_TIME      USD       BASE_SALARY
#
#           scraped
# 33241           1
# 33242  1699044401
# 7172                                   Quality Inspector
# 157                                   Production Manager
# 25141                                Executive Assistant
# 24039                                   Trailer Mechanic
# 27694                                           Engineer
# 10331                            Preconstruction Manager
# 696    (USA) Staff Pharmacist- $50,000 Sign On Bonus ...
# 2808                                   HR Representative
# 1096                       MERCHANDISE ASSISTANT MANAGER
# 32481     Senior Project Controller - The River District
# 12276                                    General Manager
# 8659                                  Sr. SCADA Engineer
# 15664                                    Spanish Teacher
#
#                                              description  max_salary  \
# 26487  Overview\nDo you enjoy meeting and talking to ...         NaN
# 28281  Overview\nAs an Intern, you will be introduced...         NaN
# 26260  Before you apply to a job, select your languag...         NaN
# 20065  Our client is a leader in Data and Computing T...    10125.00
# 32210  Hi\nThis is Kavin from Synectics!!!\nWe have a...         NaN
# 4602   National Interstate is a member of Great Ameri...         NaN
# 19294  At Fortescue Future Industries (FFI) we are le...         NaN
# 22376  What You Will Do\nUnder general direction, act...         NaN
# 24772  Please make sure to attach your resume to comp...       25.29
# 22150  Position Summary: \nThe Front of House Manager...         NaN
# 581    The Meta Reality Labs (RL) Accounting Team is ...   159000.00
# 17536  Are you a passionate and experienced sales pro...         NaN
# 17390  GovCIO is currently hiring for a Corporate Ser...    75000.00
# 31487  Optomi, in partnership with a multi-billion do...         NaN
# 5484   \nSchool Custodian\nUS-SC-CHARLESTON\nRequisit...         NaN
# 11997  Company Description\nRESA Power is the premier...         NaN
# 31635  Type: Full Time Location: Bryn Mawr, PA or Pit...         NaN
# 404    This position is primarily a technical role wi...         NaN
# 30061  Experienced Business Analyst in Telecom Promos...         NaN
# 32294  MD Imaging is a modern outpatient imaging cent...         NaN
# 31632  Yale University offers exciting opportunities ...         NaN
# 10354  East Coast (NYC Metro Area)\nAbout Us:Botrista...   100000.00
# 21142  R367669\n\nComcast brings together the best in...         NaN
# 13847  With a company culture rooted in collaboration...         NaN
# 17714  GovCIO is currently hiring a Senior Leadership...    85000.00
# 32247  Who We AreStuzo, with its Open Commerce® produ...         NaN
# 30747  Job Summary and MissionAs a Customer Success M...       40.00
# 4267   We’re Hiring! Our key client is hiring and loo...         NaN
# 18996  HAI Group®[1], a property-casualty insurance c...         NaN
# 19821  Opportunity: NYC Hotel Operations Intern (Fall...       20.00
# 27928  The Mechanical detailer/designer position work...       27.00
# 2394   R00216709\n\nWe are looking for motivated, cus...    56000.00
# 1852   If you’re looking for a special place to build...         NaN
# 2152   Maintenance professionals are the backbone of ...         NaN
# 26010  Odle Management – A subsidiary of Eckerd Conne...         NaN
# 32291  AWS DevOps EngineerAre you seeking to grow and...         NaN
# 19243  A Fortune 50 client of ours in the retail indu...         NaN
# 7172   Position Overview:Perform in-process and final...         NaN
# 157    Production ManagerJob Summary:The Hang Loose H...    65000.00
# 25141  Are you looking for a place where you can brin...         NaN
# 24039  \n \n\nSolutions driven success.\n\n \n\nXPO i...         NaN
# 27694  We’re on the hunt for professionals in the Eng...         NaN
# 10331  If you're a driven and results-oriented indivi...         NaN
# 696    Position Summary...\n\nWhat you'll do...\n\nPr...         NaN
# 2808   Job Description\n\nWhy Join Altec?\n\nIf you'r...         NaN
# 1096   Store Dollar Tree\n\nWork where you love to sh...         NaN
# 32481  Crescent Communities is a nationally recognize...         NaN
# 12276  Starting from $65,000 annually plus monthly tr...         NaN
# 8659   Overview\n\nTHE ROLE: \n\nThe Senior SCADA Eng...         NaN
# 15664  St. Augustine High School is currently seeking...    45000.00
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 26487         NaN         NaN        NaN           Part-time
# 28281         NaN         NaN        NaN           Part-time
# 26260         NaN         NaN        NaN           Full-time
# 20065         NaN     9431.00    MONTHLY            Contract
# 32210         NaN         NaN        NaN            Contract
# 4602          NaN         NaN        NaN           Full-time
# 19294         NaN         NaN        NaN           Full-time
# 22376         NaN         NaN        NaN           Full-time
# 24772         NaN       23.85     HOURLY           Full-time
# 22150         NaN         NaN        NaN           Full-time
# 581           NaN   110000.00     YEARLY           Full-time
# 17536         NaN         NaN        NaN           Full-time
# 17390         NaN    65000.00     YEARLY           Full-time
# 31487         NaN         NaN        NaN            Contract
# 5484        16.00         NaN     HOURLY           Full-time
# 11997         NaN         NaN        NaN           Full-time
# 31635         NaN         NaN        NaN           Full-time
# 404           NaN         NaN        NaN           Full-time
# 30061         NaN         NaN        NaN            Contract
# 32294       38.00         NaN     HOURLY           Full-time
# 31632         NaN         NaN        NaN           Full-time
# 10354         NaN    80000.00     YEARLY           Full-time
# 21142       21.00         NaN     HOURLY           Full-time
# 13847         NaN         NaN        NaN           Full-time
# 17714         NaN    54000.00     YEARLY           Full-time
# 32247         NaN         NaN        NaN           Full-time
# 30747         NaN       38.00     HOURLY           Full-time
# 4267        47.00         NaN     HOURLY            Contract
# 18996         NaN         NaN        NaN           Full-time
# 19821         NaN       20.00     HOURLY          Internship
# 27928         NaN       25.00     HOURLY           Full-time
# 2394          NaN    46000.00     YEARLY           Full-time
# 1852          NaN         NaN        NaN           Full-time
# 2152          NaN         NaN        NaN           Full-time
# 26010       16.20         NaN     HOURLY           Full-time
# 32291         NaN         NaN        NaN           Full-time
# 19243         NaN         NaN        NaN           Full-time
# 7172          NaN         NaN        NaN           Full-time
# 157           NaN    60000.00     YEARLY           Full-time
# 25141         NaN         NaN        NaN           Full-time
# 24039       30.82         NaN     HOURLY           Full-time
# 27694         NaN         NaN        NaN            Contract
# 10331         NaN         NaN        NaN           Full-time
# 696           NaN         NaN        NaN           Full-time
# 2808          NaN         NaN        NaN           Full-time
# 1096          NaN         NaN        NaN           Full-time
# 32481         NaN         NaN        NaN           Full-time
# 12276    65000.00         NaN     YEARLY           Full-time
# 8659          NaN         NaN        NaN           Full-time
# 15664         NaN    40000.00     YEARLY           Full-time
#
#                               location  applies  original_listed_time  \
# 26487                       Towson, MD      NaN          1.692850e+12
# 28281                Greater Cleveland      2.0          1.692820e+12
# 26260                      Livonia, MI      NaN          1.692750e+12
# 20065                        Plano, TX     36.0          1.692730e+12
# 32210  Austin, Texas Metropolitan Area      NaN          1.692730e+12
# 4602                     Richfield, OH      NaN          1.699050e+12
# 19294                   Harrington, DE     10.0          1.692730e+12
# 22376                       Helena, MT      NaN          1.692830e+12
# 24772                    Paramount, CA      NaN          1.692740e+12
# 22150                       Naples, FL      NaN          1.692830e+12
# 581                         Austin, TX      1.0          1.698970e+12
# 17536                 Philadelphia, PA      8.0          1.692740e+12
# 17390                      Fairfax, VA      NaN          1.692740e+12
# 31487                    United States    254.0          1.692730e+12
# 5484                    Charleston, SC      NaN          1.699040e+12
# 11997                       Denver, CO      NaN          1.699040e+12
# 31635                    Bryn Mawr, PA     29.0          1.692730e+12
# 404                    Bridgewater, NJ      2.0          1.698970e+12
# 30061                     St Louis, MO      NaN          1.692740e+12
# 32294                      Redding, CA      NaN          1.692730e+12
# 31632                    New Haven, CT     10.0          1.692730e+12
# 10354          New York, United States      1.0          1.699050e+12
# 21142                   Wilmington, NC      NaN          1.692750e+12
# 13847                   Farmington, CT      NaN          1.698960e+12
# 17714                      Fairfax, VA      1.0          1.692740e+12
# 32247                 Philadelphia, PA    127.0          1.692730e+12
# 30747                      Seattle, WA     86.0          1.692730e+12
# 4267                     Melbourne, FL      5.0          1.699050e+12
# 18996                     Cheshire, CT      7.0          1.692730e+12
# 19821                     New York, NY     12.0          1.692730e+12
# 27928                      Garland, TX      3.0          1.692830e+12
# 2394                   Des Plaines, IL      NaN          1.698970e+12
# 1852                    Huntsville, AL      5.0          1.699050e+12
# 2152                    Boca Raton, FL      NaN          1.698970e+12
# 26010                      Denison, IA      NaN          1.692750e+12
# 32291                      Atlanta, GA     76.0          1.692730e+12
# 19243          Virginia, United States     16.0          1.692730e+12
# 7172                      Bensalem, PA      2.0          1.699040e+12
# 157                Fountain Valley, CA      NaN          1.699080e+12
# 25141                         Waco, TX     11.0          1.692730e+12
# 24039                    Nashville, TN      NaN          1.692660e+12
# 27694          New York, United States      1.0          1.692830e+12
# 10331                  Minneapolis, MN      1.0          1.699050e+12
# 696                         Laurel, MT      NaN          1.699070e+12
# 2808                 Elizabethtown, KY      NaN          1.699050e+12
# 1096                      Victoria, TX      NaN          1.698970e+12
# 32481                    Charlotte, NC      NaN          1.692730e+12
# 12276                      Chester, VA      1.0          1.699040e+12
# 8659                 Winston-Salem, NC      1.0          1.698940e+12
# 15664                  New Orleans, LA      NaN          1.699040e+12
#
#        remote_allowed  views  \
# 26487             NaN    NaN
# 28281             NaN    4.0
# 26260             NaN    NaN
# 20065             NaN  126.0
# 32210             NaN   57.0
# 4602              NaN    NaN
# 19294             NaN   96.0
# 22376             NaN    NaN
# 24772             NaN    1.0
# 22150             NaN    2.0
# 581               NaN   20.0
# 17536             NaN   27.0
# 17390             NaN   14.0
# 31487             1.0  634.0
# 5484              NaN    NaN
# 11997             NaN   12.0
# 31635             NaN  122.0
# 404               NaN   10.0
# 30061             1.0   50.0
# 32294             NaN    3.0
# 31632             NaN  123.0
# 10354             NaN    2.0
# 21142             NaN    NaN
# 13847             NaN    3.0
# 17714             NaN    5.0
# 32247             NaN  235.0
# 30747             NaN  226.0
# 4267              NaN   36.0
# 27694                    https://cadcow.com/sign-up.html        OffsiteApply
# 10331                                                NaN  ComplexOnsiteApply
# 696    https://click.appcast.io/track/heuo5yr-org?cs=...        OffsiteApply
# 2808   https://jobs.altec.com/jobs/13561287-hr-repres...        OffsiteApply
# 1096   https://careers.dollartree.com/us/en/job/DTYDT...        OffsiteApply
# 32481  https://recruiting.ultipro.com/CRE1011/JobBoar...        OffsiteApply
# 12276  https://raisingcanes.jibeapply.com/jobs/93317?...        OffsiteApply
# 8659   https://herbalifecareers.ttcportals.com/jobs/1...        OffsiteApply
# 15664                                                NaN  ComplexOnsiteApply
#
#              expiry   closed_time formatted_experience_level skills_desc  \
# 26487  1.695440e+12           NaN                Entry level         NaN
# 28281  1.695420e+12           NaN                        NaN         NaN
# 26260  1.695440e+12           NaN                Entry level         NaN
# 20065  1.695320e+12           NaN           Mid-Senior level         NaN
# 32210  1.695320e+12  1.690000e+12                        NaN         NaN
# 4602   1.701640e+12           NaN           Mid-Senior level         NaN
# 19294  1.695330e+12           NaN           Mid-Senior level         NaN
# 22376  1.695420e+12           NaN           Mid-Senior level         NaN
# 24772  1.695340e+12           NaN                Entry level         NaN
# 22150  1.695420e+12           NaN           Mid-Senior level         NaN
# 581    1.701670e+12           NaN                        NaN         NaN
# 17536  1.708290e+12           NaN                        NaN         NaN
# 17390  1.695340e+12           NaN                Entry level         NaN
# 31487  1.695320e+12           NaN           Mid-Senior level         NaN
# 5484   1.701640e+12           NaN                        NaN         NaN
# 11997  1.701640e+12           NaN                        NaN         NaN
# 31635  1.697920e+12           NaN           Mid-Senior level         NaN
# 404    1.701670e+12           NaN           Mid-Senior level         NaN
# 30061  1.695330e+12  1.690000e+12                        NaN         NaN
# 32294  1.695330e+12           NaN                        NaN         NaN
# 31632  1.695330e+12           NaN                  Associate         NaN
# 10354  1.701640e+12           NaN           Mid-Senior level         NaN
# 21142  1.695440e+12           NaN                        NaN         NaN
# 13847  1.701560e+12           NaN           Mid-Senior level         NaN
# 17714  1.695340e+12           NaN           Mid-Senior level         NaN
# 32247  1.695330e+12           NaN                  Associate         NaN
# 30747  1.695330e+12           NaN                  Associate         NaN
# 4267   1.701640e+12           NaN           Mid-Senior level         NaN
# 18996  1.695340e+12           NaN           Mid-Senior level         NaN
# 19821  1.695320e+12           NaN                        NaN         NaN
# 27928  1.695420e+12           NaN           Mid-Senior level         NaN
# 2394   1.701640e+12           NaN                  Associate         NaN
# 1852   1.701650e+12           NaN                        NaN         NaN
# 2152   1.701650e+12           NaN                Entry level         NaN
# 26010  1.695440e+12           NaN                Entry level         NaN
# 32291  1.708290e+12           NaN                        NaN         NaN
# 19243  1.695330e+12           NaN           Mid-Senior level         NaN
# 7172   1.714590e+12           NaN                        NaN         NaN
# 157    1.714630e+12           NaN                        NaN         NaN
# 25141  1.695330e+12           NaN           Mid-Senior level         NaN
# 24039  1.695340e+12           NaN                        NaN         NaN
# 27694  1.708390e+12           NaN                        NaN         NaN
# 10331  1.701640e+12           NaN                        NaN         NaN
# 696    1.701670e+12           NaN                  Associate         NaN
# 2808   1.701640e+12           NaN                Entry level         NaN
# 1096   1.701660e+12           NaN           Mid-Senior level         NaN
# 32481  1.695330e+12           NaN                  Associate         NaN
# 12276  1.701640e+12           NaN                  Executive         NaN
# 8659   1.701540e+12           NaN           Mid-Senior level         NaN
# 15664  1.701630e+12           NaN                        NaN         NaN
#
#         listed_time                          posting_domain  sponsored  \
# 26487  1.692850e+12                   sprouts.jibeapply.com          0
# 28281  1.692820e+12          careers-amtrustgroup.icims.com          1
# 26260  1.692850e+12                        www.jobs-ups.com          0
# 20065  1.692730e+12                                     NaN          1
# 32210  1.692730e+12                                     NaN          0
# 4602   1.699050e+12              gaig.wd1.myworkdayjobs.com          0
# 19294  1.692730e+12             secure.dc2.pageuppeople.com          0
# 22376  1.692830e+12               jci.wd5.myworkdayjobs.com          0
# 24772  1.692740e+12                       careers.aspca.org          1
# 22150  1.692830e+12                          myjobs.adp.com          1
# 581    1.699080e+12                     jsv3.recruitics.com          0
# 17536  1.692740e+12                                     NaN          1
# 17390  1.692740e+12                careers-govcio.icims.com          0
# 31487  1.692730e+12                                     NaN          0
# 5484   1.699040e+12                     www.click2apply.net          0
# 11997  1.699040e+12                                     NaN          0
# 31635  1.692820e+12                                     NaN          0
# 404    1.699080e+12                   careers.cognizant.com          0
# 30061  1.692740e+12                                     NaN          0
# 32294  1.692730e+12                                     NaN          0
# 31632  1.692730e+12                                     NaN          0
# 10354  1.699050e+12                                     NaN          0
# 21142  1.692850e+12                   comcast.contacthr.com          0
# 13847  1.698970e+12         archgroup.wd1.myworkdayjobs.com          0
# 17714  1.692740e+12                careers-govcio.icims.com          0
# 32247  1.692730e+12                                     NaN          1
# 30747  1.692730e+12                                     NaN          1
# 4267   1.699050e+12                                     NaN          0
# 18996  1.692730e+12                                     NaN          0
# 19821  1.692730e+12                                     NaN          0
# 27928  1.692830e+12                                     NaN          0
# 2394   1.699050e+12                    ecolab.contacthr.com          0
# 1852   1.699050e+12          idexcorp.wd5.myworkdayjobs.com          0
# 2152   1.699050e+12                  recruiting.ultipro.com          1
# 26010  1.692850e+12                    workforcenow.adp.com          0
# 32291  1.692730e+12                                     NaN          1
# 19243  1.692730e+12                                     NaN          0
# 7172   1.699040e+12                                     NaN          1
# 157    1.699080e+12                                     NaN          1
# 25141  1.692740e+12  neighborlybrands.wd1.myworkdayjobs.com          0
# 24039  1.692740e+12                            jobs.xpo.com          1
# 27694  1.692830e+12                                     NaN          0
# 10331  1.699050e+12                                     NaN          0
# 696    1.699080e+12                        click.appcast.io          0
# 2808   1.699050e+12                          jobs.altec.com          0
# 1096   1.699060e+12                  careers.dollartree.com          0
# 32481  1.692730e+12                  recruiting.ultipro.com          0
# 12276  1.699050e+12              raisingcanes.jibeapply.com          0
# 8659   1.698940e+12         herbalifecareers.ttcportals.com          1
# 15664  1.699040e+12                                     NaN          0
#
#         work_type currency compensation_type     scraped
# 26487   PART_TIME      NaN               NaN           1
# 28281   PART_TIME      NaN               NaN           1
# 26260   FULL_TIME      NaN               NaN           1
# 20065    CONTRACT      USD       BASE_SALARY           1
# 32210    CONTRACT      NaN               NaN           1
# 4602    FULL_TIME      NaN               NaN  1699051026
# 19294   FULL_TIME      NaN               NaN           1
# 22376   FULL_TIME      NaN               NaN           1
# 24772   FULL_TIME      USD       BASE_SALARY           1
# 22150   FULL_TIME      NaN               NaN           1
# 581     FULL_TIME      USD       BASE_SALARY  1699138627
# 17536   FULL_TIME      NaN               NaN           1
# 17390   FULL_TIME      USD       BASE_SALARY           1
# 31487    CONTRACT      NaN               NaN           1
# 5484    FULL_TIME      USD       BASE_SALARY  1699046104
# 11997   FULL_TIME      NaN               NaN  1699082085
# 31635   FULL_TIME      NaN               NaN           1
# 404     FULL_TIME      NaN               NaN  1699133129
# 30061    CONTRACT      NaN               NaN           1
# 32294   FULL_TIME      USD       BASE_SALARY           1
# 31632   FULL_TIME      NaN               NaN           1
# 10354   FULL_TIME      USD       BASE_SALARY  1699051395
# 21142   FULL_TIME      USD       BASE_SALARY           1
# 13847   FULL_TIME      NaN               NaN  1698994731
# 17714   FULL_TIME      USD       BASE_SALARY           1
# 32247   FULL_TIME      NaN               NaN           1
# 30747   FULL_TIME      USD       BASE_SALARY           1
# 4267     CONTRACT      USD       BASE_SALARY  1699090372
# 18996   FULL_TIME      NaN               NaN           1
# 19821  INTERNSHIP      USD       BASE_SALARY           1
# 27928   FULL_TIME      USD       BASE_SALARY           1
# 2394    FULL_TIME      USD       BASE_SALARY  1699085792
# 1852    FULL_TIME      NaN               NaN  1699073153
# 2152    FULL_TIME      NaN               NaN  1699086648
# 26010   FULL_TIME      USD       BASE_SALARY           1
# 32291   FULL_TIME      NaN               NaN           1
# 19243   FULL_TIME      NaN               NaN           1
# 7172    FULL_TIME      NaN               NaN  1699072030
# 157     FULL_TIME      USD       BASE_SALARY  1699081789
# 25141   FULL_TIME      NaN               NaN           1
# 24039   FULL_TIME      USD       BASE_SALARY           1
# 27694    CONTRACT      NaN               NaN           1
# 10331   FULL_TIME      NaN               NaN  1699081197
# 696     FULL_TIME      NaN               NaN  1699136073
# 2808    FULL_TIME      NaN               NaN  1699053991
# 1096    FULL_TIME      NaN               NaN  1699082306
# 32481   FULL_TIME      NaN               NaN           1
# 12276   FULL_TIME      USD       BASE_SALARY  1699134036
# 8659    FULL_TIME      NaN               NaN  1698996228
# 15664   FULL_TIME      USD       BASE_SALARY  1699038855

# %% [markdown]
# From the initial observation, we can report the following:
# - Several NaN (missing) values
# - Irrelevant columns (i.e. "job_posting_url", "application_url", and "scraped")
# - Presence of dummy variables (binary columns)
# - Data entries from time-related variables must be reformatted into datetime format
# - Columns, "Formatted_Work_Type" and "Work_Type" display identical information
# - Two categorical variables, "Currency" and "Compensation_Type" require further investigation as they seem to have only one type of data entry.
#
# Now let's check the data types:

# %%
# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  float64
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  job_posting_url             33246 non-null  object
#  15  application_url             20996 non-null  object
#  16  application_type            33246 non-null  object
#  17  expiry                      33246 non-null  float64
#  18  closed_time                 1172 non-null   float64
#  19  formatted_experience_level  24065 non-null  object
#  20  skills_desc                 337 non-null    object
#  21  listed_time                 33246 non-null  float64
#  22  posting_domain              19688 non-null  object
#  23  sponsored                   33246 non-null  int64
#  24  work_type                   33246 non-null  object
#  25  currency                    13352 non-null  object
#  26  compensation_type           13352 non-null  object
#  27  scraped                     33246 non-null  int64
# dtypes: float64(11), int64(3), object(14)
# memory usage: 7.1+ MB

# %% [markdown]
# Next, we will go over each of the time variables in the dataset ("original_listed_time", "expiry", "closed_time", and "listed_time"), and convert the data entries into a standard datetime format (Year-Month-Date, Hour-Minute_Second).

# %% [markdown]
# ### Dealing with Time Variables

# %%
df['original_listed_time'].value_counts()
# Out:
# original_listed_time
# 1.699050e+12    5005
# 1.699040e+12    4958
# 1.692740e+12    3798
# 1.692730e+12    3407
# 1.698970e+12    2398
# 1.692750e+12    1578
# 1.692830e+12    1536
# 1.692660e+12    1365
# 1.699060e+12     993
# 1.699070e+12     908
# 1.692840e+12     854
# 1.692850e+12     726
# 1.692820e+12     685
# 1.698960e+12     654
# 1.698880e+12     325
# 1.696890e+12     314
# 1.699080e+12     308
# 1.690580e+12     219
# 1.692860e+12     206
# 1.699030e+12     203
# 1.692680e+12     196
# 1.696880e+12     166
# 1.692580e+12     155
# 1.690690e+12     109
# 1.690670e+12     100
# 1.696910e+12      96
# 1.692870e+12      96
# 1.698790e+12      85
# 1.698780e+12      76
# 1.692640e+12      73
# 1.692720e+12      69
# 1.696800e+12      62
# 1.698770e+12      61
# 1.691690e+12      57
# 1.696870e+12      52
# 1.690570e+12      51
# 1.691700e+12      46
# 1.699020e+12      41
# 1.696900e+12      37
# 1.698760e+12      36
# 1.690660e+12      35
# 1.698800e+12      31
# 1.692140e+12      31
# 1.690520e+12      30
# 1.698950e+12      30
# 1.692230e+12      29
# 1.691710e+12      25
# 1.697560e+12      21
# 1.698940e+12      21
# 1.692060e+12      20
# 1.691680e+12      20
# 1.692280e+12      18
# 1.690930e+12      17
# 1.699090e+12      16
# 1.690590e+12      16
# 1.699010e+12      15
# 1.696920e+12      15
# 1.692320e+12      13
# 1.698620e+12      13
# 1.696980e+12      12
# 1.690680e+12      12
# 1.691190e+12      12
# 1.690850e+12      12
# 1.691790e+12      11
# 1.698750e+12      11
# 1.696810e+12      11
# 1.691630e+12      11
# 1.690480e+12      11
# 1.697670e+12      10
# 1.698710e+12      10
# 1.692630e+12       9
# 1.697590e+12       9
# 1.691610e+12       9
# 1.698190e+12       8
# 1.691970e+12       8
# 1.697070e+12       8
# 1.692650e+12       8
# 1.697130e+12       8
# 1.698110e+12       8
# 1.691720e+12       8
# 1.697580e+12       8
# 1.697660e+12       8
# 1.698700e+12       7
# 1.698100e+12       7
# 1.697060e+12       7
# 1.691180e+12       7
# 1.691020e+12       7
# 1.697840e+12       7
# 1.691600e+12       7
# 1.691440e+12       7
# 1.691670e+12       6
# 1.692670e+12       6
# 1.697750e+12       6
# 1.698870e+12       6
# 1.698020e+12       6
# 1.690840e+12       6
# 1.697490e+12       6
# 1.696930e+12       6
# 1.690700e+12       6
# 1.697500e+12       6
# 1.697230e+12       6
# 1.698680e+12       6
# 1.692380e+12       5
# 1.691530e+12       5
# 1.692120e+12       5
# 1.692400e+12       5
# 1.697600e+12       5
# 1.698360e+12       5
# 1.697240e+12       5
# 1.690970e+12       5
# 1.691010e+12       4
# 1.698240e+12       4
# 1.698920e+12       4
# 1.697760e+12       4
# 1.698830e+12       4
# 1.690980e+12       4
# 1.690860e+12       4
# 1.696990e+12       4
# 1.698300e+12       4
# 1.697520e+12       4
# 1.696860e+12       4
# 1.696960e+12       4
# 1.697300e+12       4
# 1.696970e+12       4
# 1.691370e+12       4
# 1.698320e+12       3
# 1.698730e+12       3
# 1.698930e+12       3
# 1.698980e+12       3
# 1.698280e+12       3
# 1.697850e+12       3
# 1.698160e+12       3
# 1.698270e+12       3
# 1.692250e+12       3
# 1.692710e+12       3
# 1.698420e+12       3
# 1.698080e+12       3
# 1.697040e+12       3
# 1.698850e+12       3
# 1.691980e+12       3
# 1.691100e+12       3
# 1.691780e+12       3
# 1.690950e+12       3
# 1.698180e+12       3
# 1.698370e+12       3
# 1.690760e+12       3
# 1.691540e+12       3
# 1.697140e+12       3
# 1.698440e+12       3
# 1.692040e+12       3
# 1.691470e+12       3
# 1.697860e+12       3
# 1.698450e+12       3
# 1.697710e+12       3
# 1.698720e+12       3
# 1.698120e+12       3
# 1.697160e+12       3
# 1.691800e+12       2
# 1.692110e+12       2
# 1.692810e+12       2
# 1.691080e+12       2
# 1.692760e+12       2
# 1.697640e+12       2
# 1.698690e+12       2
# 1.691110e+12       2
# 1.698660e+12       2
# 1.697690e+12       2
# 1.691620e+12       2
# 1.692550e+12       2
# 1.697210e+12       2
# 1.697250e+12       2
# 1.698250e+12       2
# 1.698090e+12       2
# 1.692700e+12       2
# 1.692220e+12       2
# 1.698330e+12       2
# 1.698630e+12       2
# 1.698290e+12       2
# 1.690560e+12       2
# 1.692070e+12       2
# 1.690960e+12       2
# 1.697000e+12       2
# 1.697650e+12       2
# 1.697880e+12       2
# 1.697110e+12       2
# 1.690990e+12       2
# 1.692420e+12       2
# 1.692330e+12       2
# 1.695680e+12       2
# 1.697510e+12       2
# 1.698430e+12       2
# 1.698890e+12       2
# 1.698460e+12       2
# 1.698340e+12       2
# 1.690710e+12       2
# 1.696030e+12       2
# 1.695940e+12       2
# 1.697730e+12       2
# 1.686210e+12       1
# 1.691560e+12       1
# 1.690470e+12       1
# 1.692390e+12       1
# 1.690920e+12       1
# 1.692800e+12       1
# 1.692310e+12       1
# 1.691280e+12       1
# 1.698400e+12       1
# 1.691500e+12       1
# 1.694540e+12       1
# 1.696690e+12       1
# 1.696450e+12       1
# 1.694140e+12       1
# 1.696300e+12       1
# 1.695950e+12       1
# 1.695690e+12       1
# 1.691030e+12       1
# 1.692610e+12       1
# 1.696310e+12       1
# 1.696290e+12       1
# 1.697780e+12       1
# 1.695590e+12       1
# 1.695410e+12       1
# 1.696610e+12       1
# 1.697430e+12       1
# 1.692050e+12       1
# 1.692100e+12       1
# 1.691060e+12       1
# 1.701710e+12      18
# 1.707230e+12      17
# 1.701610e+12      17
# 1.714570e+12      17
# 1.708270e+12      16
# 1.708210e+12      15
# 1.695380e+12      15
# 1.701360e+12      14
# 1.695370e+12      13
# 1.700260e+12      12
# 1.708200e+12      11
# 1.708420e+12      11
# 1.695510e+12      11
# 1.701600e+12       9
# 1.694290e+12       9
# 1.701390e+12       9
# 1.701350e+12       9
# 1.700180e+12       8
# 1.708350e+12       8
# 1.708180e+12       8
# 1.700510e+12       8
# 1.701730e+12       8
# 1.708360e+12       7
# 1.708220e+12       7
# 1.714350e+12       7
# 1.708320e+12       6
# 1.697930e+12       6
# 1.707260e+12       6
# 1.708370e+12       6
# 1.694300e+12       6
# 1.697910e+12       6
# 1.714300e+12       5
# 1.701720e+12       5
# 1.714640e+12       5
# 1.698020e+12       5
# 1.708240e+12       4
# 1.694280e+12       4
# 1.707220e+12       3
# 1.695310e+12       3
# 1.698030e+12       3
# 1.698050e+12       3
# 1.701700e+12       3
# 1.698010e+12       3
# 1.706830e+12       3
# 1.703100e+12       3
# 1.703960e+12       3
# 1.704220e+12       3
# 1.704240e+12       2
# 1.697940e+12       2
# 1.694390e+12       2
# 1.714560e+12       2
# 1.701530e+12       2
# 1.706740e+12       2
# 1.704150e+12       2
# 1.706810e+12       2
# 1.714580e+12       2
# 1.700500e+12       2
# 1.705690e+12       2
# 1.707840e+12       2
# 1.695250e+12       2
# 1.704270e+12       1
# 1.707600e+12       1
# 1.707580e+12       1
# 1.707570e+12       1
# 1.707330e+12       1
# 1.707770e+12       1
# 1.694270e+12       1
# 1.707760e+12       1
# 1.707560e+12       1
# 1.695300e+12       1
# 1.695260e+12       1
# 1.701570e+12       1
# 1.714530e+12       1
# 1.714510e+12       1
# 1.714680e+12       1
# 1.699050e+12       1
# 1.706820e+12       1
# 1.699080e+12       1
# 1.700860e+12       1
# 1.714490e+12       1
# 1.701340e+12       1
# 1.701320e+12       1
# 1.714500e+12       1
# 1.714410e+12       1
# 1.698040e+12       1
# 1.700600e+12       1
# 1.705710e+12       1
# 1.707670e+12       1
# 1.714420e+12       1
# 1.700170e+12       1
# 1.705700e+12       1
# 1.703110e+12       1
# 1.714400e+12       1
# 1.703120e+12       1
# 1.700520e+12       1
# 1.708310e+12       1
# 1.708340e+12       1
# 1.708230e+12       1
# Name: count, dtype: int64

# %%
df['closed_time'].value_counts()
# Out:
# closed_time
# 1.690000e+12    928
# 1.700000e+12    244
# Name: count, dtype: int64

# %%
df['listed_time'].value_counts()
# Out:
# listed_time
# 1.699050e+12    6910
# 1.699040e+12    5465
# 1.692740e+12    4550
# 1.692730e+12    3189
# 1.692830e+12    2561
# 1.692850e+12    1389
# 1.699070e+12    1328
# 1.692750e+12    1216
# 1.699060e+12    1138
# 1.692840e+12     947
# 1.698960e+12     795
# 1.692820e+12     686
# 1.699080e+12     643
# 1.698970e+12     464
# 1.692860e+12     300
# 1.692680e+12     286
# 1.692760e+12     123
# 1.692870e+12     121
# 1.692810e+12      99
# 1.692640e+12      86
# 1.699030e+12      81
# 1.699090e+12      74
# 1.698780e+12      73
# 1.698790e+12      69
# 1.692800e+12      68
# 1.698770e+12      48
# 1.698950e+12      47
# 1.692770e+12      40
# 1.691700e+12      39
# 1.691690e+12      38
# 1.698760e+12      37
# 1.699100e+12      37
# 1.699020e+12      35
# 1.698990e+12      29
# 1.692720e+12      28
# 1.692790e+12      25
# 1.692660e+12      20
# 1.691680e+12      19
# 1.699010e+12      16
# 1.699120e+12      16
# 1.692780e+12      15
# 1.698940e+12      14
# 1.692630e+12       8
# 1.699130e+12       7
# 1.698750e+12       7
# 1.698800e+12       7
# 1.699110e+12       7
# 1.692670e+12       5
# 1.691710e+12       5
# 1.692650e+12       5
# 1.698980e+12       4
# 1.691670e+12       4
# 1.699140e+12       3
# 1.692210e+12       2
# 1.692290e+12       2
# 1.691760e+12       2
# 1.698850e+12       2
# 1.692710e+12       2
# 1.691770e+12       1
# 1.692030e+12       1
# 1.698870e+12       1
# 1.698730e+12       1
# 1.692040e+12       1
# 1.698860e+12       1
# 1.692020e+12       1
# 1.699000e+12       1
# 1.692120e+12       1
# 1.692000e+12       1
# Name: count, dtype: int64

# %% [markdown]
# After checking the unique values from each of the time variables, we can spot a pattern where the time values are listed in a scientific timestamp format (i.e. 1.692000e+12). Hence, we will convert this to a datetime format where the data entries are recorded in a standard format.

# %% [markdown]
# #### Original_Listed_Time

# %%
# Convert scientific notation to standard notation (float)
df['original_listed_time']=df['original_listed_time'].astype('float64')

# %%
# Convert milliseconds to seconds 
df['original_listed_time']=df['original_listed_time']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
df['original_listed_time'] = df['original_listed_time'].apply(lambda x: datetime.fromtimestamp(x))
df['original_listed_time']
# Out:
# 0       2023-11-04 05:26:40
# 1       2023-11-04 02:40:00
# 2       2023-11-04 02:40:00
# 3       2023-11-04 02:40:00
# 4       2023-11-02 20:06:40
#                 ...
# 33241   2023-08-23 18:33:20
# 33242   2023-11-03 15:33:20
# 33243   2023-11-03 18:20:00
# 33244   2023-08-22 20:20:00
# 33245   2023-11-03 18:20:00
# Name: original_listed_time, Length: 33246, dtype: datetime64[ns]

# %%
# Sanity Check
df.head()
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
#    min_salary pay_period formatted_work_type          location  applies  \
# 0         NaN    MONTHLY           Full-time  Little River, SC      NaN
# 1         NaN        NaN           Full-time    Beaver Dam, WI      NaN
# 2         NaN        NaN           Full-time      Bessemer, AL      NaN
# 3         NaN     HOURLY           Full-time   Aliso Viejo, CA      NaN
# 4    205956.0     YEARLY           Full-time     United States      NaN
#
#   original_listed_time  remote_allowed  views  \
# 0  2023-11-04 05:26:40             NaN    9.0
# 1  2023-11-04 02:40:00             NaN    NaN
# 2  2023-11-04 02:40:00             NaN    NaN
# 3  2023-11-04 02:40:00             NaN    1.0
# 4  2023-11-02 20:06:40             1.0    NaN
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
# 4  https://www.linkedin.com/jobs/view/3757937095/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#          expiry  closed_time formatted_experience_level  \
# 0  1.701680e+12          NaN                Entry level
# 1  1.701680e+12          NaN                        NaN
# 2  1.701680e+12          NaN                        NaN
# 3  1.701680e+12          NaN                Entry level
# 4  1.701680e+12          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
# 4                                                NaN  1.699090e+12
#
#              posting_domain  sponsored  work_type currency compensation_type  \
# 0  careers-demant.icims.com          0  FULL_TIME      USD       BASE_SALARY
# 1       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 2       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 3           jobs.apploi.com          0  FULL_TIME      USD       BASE_SALARY
# 4         careers.iherb.com          0  FULL_TIME      USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346

# %% [markdown]
# From above, we can observe that the data entries from `original_listed_time` have been transformed into datetime format. We will repeat this process for the remaining three columns.

# %% [markdown]
# #### Expiry

# %%
# Convert scientific notation to standard notation (float)
df['expiry']=df['expiry'].astype('float64')

# %%
# Convert milliseconds to seconds 
df['expiry']=df['expiry']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
df['expiry'] = df['expiry'].apply(lambda x: datetime.fromtimestamp(x))
df['expiry']
# Out:
# 0       2023-12-04 03:53:20
# 1       2023-12-04 03:53:20
# 2       2023-12-04 03:53:20
# 3       2023-12-04 03:53:20
# 4       2023-12-04 03:53:20
#                 ...
# 33241   2023-09-22 20:46:40
# 33242   2023-12-03 14:00:00
# 33243   2023-12-03 16:46:40
# 33244   2024-02-18 18:46:40
# 33245   2024-05-01 17:46:40
# Name: expiry, Length: 33246, dtype: datetime64[ns]

# %%
# Sanity Check
df.head()
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
#    min_salary pay_period formatted_work_type          location  applies  \
# 0         NaN    MONTHLY           Full-time  Little River, SC      NaN
# 1         NaN        NaN           Full-time    Beaver Dam, WI      NaN
# 2         NaN        NaN           Full-time      Bessemer, AL      NaN
# 3         NaN     HOURLY           Full-time   Aliso Viejo, CA      NaN
# 4    205956.0     YEARLY           Full-time     United States      NaN
#
#   original_listed_time  remote_allowed  views  \
# 0  2023-11-04 05:26:40             NaN    9.0
# 1  2023-11-04 02:40:00             NaN    NaN
# 2  2023-11-04 02:40:00             NaN    NaN
# 3  2023-11-04 02:40:00             NaN    1.0
# 4  2023-11-02 20:06:40             1.0    NaN
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
# 4  https://www.linkedin.com/jobs/view/3757937095/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#                expiry  closed_time formatted_experience_level  \
# 0 2023-12-04 03:53:20          NaN                Entry level
# 1 2023-12-04 03:53:20          NaN                        NaN
# 2 2023-12-04 03:53:20          NaN                        NaN
# 3 2023-12-04 03:53:20          NaN                Entry level
# 4 2023-12-04 03:53:20          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
# 4                                                NaN  1.699090e+12
#
#              posting_domain  sponsored  work_type currency compensation_type  \
# 0  careers-demant.icims.com          0  FULL_TIME      USD       BASE_SALARY
# 1       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 2       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 3           jobs.apploi.com          0  FULL_TIME      USD       BASE_SALARY
# 4         careers.iherb.com          0  FULL_TIME      USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346

# %% [markdown]
# #### Closed_Time

# %%
# Convert scientific notation to standard notation (float)
df['closed_time']=df['closed_time'].astype('float64')

# %%
# Convert milliseconds to seconds 
df['closed_time']=df['closed_time']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
df['closed_time'] = df['closed_time'].apply(lambda x: datetime.fromtimestamp(x))
df['closed_time']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Convert timestamp into datetime
#       2 from datetime import datetime
# ----> 3 df['closed_time'] = df['closed_time'].apply(lambda x: datetime.fromtimestamp(x))
#       4 df['closed_time']
#
# File /Applications/anaconda3/envs/LinkedIn_Capstone/lib/python3.12/site-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File /Applications/anaconda3/envs/LinkedIn_Capstone/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /Applications/anaconda3/envs/LinkedIn_Capstone/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Applications/anaconda3/envs/LinkedIn_Capstone/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /Applications/anaconda3/envs/LinkedIn_Capstone/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[20], line 3, in <lambda>(x)
#       1 # Convert timestamp into datetime
#       2 from datetime import datetime
# ----> 3 df['closed_time'] = df['closed_time'].apply(lambda x: datetime.fromtimestamp(x))
#       4 df['closed_time']
#
# ValueError: Invalid value NaN (not a number)

# %% [markdown]
# Since there are NaN (missing) values from `closed_time` column, we first have to filter these null values to apply datetime function.

# %%
# Filter out NaN values
not_null_ct = df['closed_time'].notnull()
df.loc[not_null_ct, 'closed_time'] = df.loc[not_null_ct, 'closed_time'].apply(lambda x: datetime.fromtimestamp(x))

# Print the updated DataFrame
print(df['closed_time'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 33241    NaN
# 33242    NaN
# 33243    NaN
# 33244    NaN
# 33245    NaN
# Name: closed_time, Length: 33246, dtype: object
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_8767/2531425563.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<DatetimeArray>
# ['2023-11-14 17:13:20', '2023-11-14 17:13:20', '2023-11-14 17:13:20',
#  '2023-11-14 17:13:20', '2023-11-14 17:13:20', '2023-11-14 17:13:20',
#  '2023-11-14 17:13:20', '2023-11-14 17:13:20', '2023-11-14 17:13:20',
#  '2023-11-14 17:13:20',
#  ...
#  '2023-07-22 00:26:40', '2023-07-22 00:26:40', '2023-07-22 00:26:40',
#  '2023-07-22 00:26:40', '2023-07-22 00:26:40', '2023-07-22 00:26:40',
#  '2023-07-22 00:26:40', '2023-07-22 00:26:40', '2023-07-22 00:26:40',
#  '2023-07-22 00:26:40']
# Length: 1172, dtype: datetime64[ns]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[not_null_ct, 'closed_time'] = df.loc[not_null_ct, 'closed_time'].apply(lambda x: datetime.fromtimestamp(x))

# %%
df.sample(50)
# Out:
#            job_id  company_id  \
# 25585  3697343182      3589.0
# 13863  3753096607     70553.0
# 18957  3701315786     12709.0
# 24742  3697378986     72483.0
# 32996  3690840799  10223966.0
# 11793  3755587839      2152.0
# 5420   3757482820      6919.0
# 15625  3749351208  42876933.0
# 7538   3757445838    777243.0
# 17106  3748839491      1185.0
# 29152  3693071321      1586.0
# 431    3757912463      5394.0
# 5301   3757484330      7260.0
# 2102   3757736359   1491336.0
# 22853  3699063242   5352294.0
# 9045   3756147198  18860134.0
# 14245  3749900931    450323.0
# 22784  3699075698     30086.0
# 20043  3701199855  18629838.0
# 18957  About Us:Customers count on Kinetic Business b...         NaN
# 24742  Job Summary\nThe Convention Services/Catering ...         NaN
# 32996  Wealthstream Advisors, Inc., a fast-growing bo...    85000.00
# 11793  Are you interested in gaining an opportunity w...         NaN
# 5420   Title: Dispute AnalystLocation: San Antonio, T...       25.00
# 15625  Python (Data Engineer) (PySpark, DB, AWS)Locat...         NaN
# 7538   Key Responsibilities:Client Engagement: Cultiv...         NaN
# 17106  All over the world, Pfizer colleagues work tog...   167200.00
# 29152  Description\nAbout Maintenance at Amazon:\nOpe...         NaN
# 431    The basic function of the production technicia...         NaN
# 5301   This is a 1.5 year contract starting in Decemb...       22.00
# 2102   Make a Difference on Your Own Schedule and Ter...         NaN
# 22853  Hi \n\nHope You are doing well |We have an urg...         NaN
# 9045   Want to learn more about this role and Jobot? ...       30.00
# 14245  Scion Nonprofit Staffing has been engaged to c...    90000.00
# 22784  Company Description\nOur Mission\nAt Palo Alto...         NaN
# 20043  Mental Health Therapist, Counselor or Psycholo...         NaN
# 18886  At Johnsonville, we use our business to build ...       26.01
# 1495   POSITION TITLE: Liquid Loader\n\nREPORTING TO:...         NaN
# 5561   Company Overview\n\nDocuSign helps organizatio...         NaN
# 11441  District located in Newport News, VA\n\nPositi...         NaN
# 28949  *Please note: we know there's a lot to read. I...    65000.00
# 10915  Morrison Foerster LLP, an Am Law 50 law firm w...    81000.00
# 11942  Role: Laboratory AssistantLocation: Mansfield ...       39.00
# 6006   Assistant Designer\nSuccess Profile: The Assis...       26.44
# 13566  Job Overview: The production manager will over...   100000.00
# 29510  Job Title: Microsoft 365 EngineerLocation: Mou...         NaN
# 15101  Create a healthier, brighter future for pets, ...         NaN
# 30166  Closing Date: September 5, 2023\n\nTeck Alaska...         NaN
# 8619   Excellent opportunity with a great company! Co...         NaN
# 26355  Job Description: Data ArchitectLocation:(Candi...         NaN
# 2128   Are you a dynamic and results-driven professio...   115000.00
# 8574   Position Title:\n\nOffice Manager and Universi...       22.79
# 1850   Working across the globe, V2X builds smart sol...         NaN
# 23748  Our vision is to transform how the world uses ...         NaN
# 25587  Hi,\nHope you are doing great today. Please fi...         NaN
# 12978  Networks Connect Professional Staffing is cond...   115000.00
# 10475  We are more than a health system. We are a bel...         NaN
# 30487  Looking for a passionate volunteer to help a s...         NaN
# 8209   Address: USA-PA-Harrisburg-2300 Linglestown Ro...         NaN
# 29710  The Area Sales Representative is responsible f...         NaN
# 32214  We're TeeTurtle, a rapidly growing consumer pr...    75000.00
# 21345  Join a strong community where all we do is car...         NaN
# 18410  Unique leadership opportunity within an organi...         NaN
# 2090   System Engineer12 month contractDallas, TX (Hy...       60.00
# 13630  As a Principal Statistical Programmer you will...         NaN
# 5574   Your Job\n\nAt Koch Industries, our mission is...         NaN
# 6664   GrepBeat is a media organization covering tech...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 25585         NaN         NaN        NaN           Full-time
# 13863         NaN         NaN        NaN           Full-time
# 18957         NaN         NaN        NaN           Full-time
# 24742         NaN         NaN        NaN           Full-time
# 32996         NaN    65000.00     YEARLY           Full-time
# 11793         NaN         NaN        NaN           Full-time
# 5420          NaN       20.00     HOURLY           Full-time
# 15625         NaN         NaN        NaN           Full-time
# 7538          NaN         NaN        NaN           Full-time
# 17106         NaN    70600.00     YEARLY           Full-time
# 29152         NaN         NaN        NaN           Full-time
# 431           NaN         NaN        NaN           Full-time
# 5301          NaN       20.00     HOURLY            Contract
# 2102         85.0         NaN     HOURLY           Part-time
# 22853         NaN         NaN        NaN            Contract
# 9045          NaN       20.00     HOURLY           Full-time
# 14245         NaN    75000.00     YEARLY           Temporary
# 22784         NaN         NaN        NaN           Full-time
# 20043         NaN         NaN        NaN            Contract
# 18886         NaN       24.48     HOURLY           Full-time
# 1495          NaN         NaN        NaN           Full-time
# 5561          NaN         NaN        NaN           Full-time
# 11441        77.0         NaN     HOURLY           Full-time
# 28949         NaN    60000.00     YEARLY           Full-time
# 10915         NaN    55000.00     YEARLY           Full-time
# 11942         NaN       37.00     HOURLY            Contract
# 6006          NaN       24.04     HOURLY           Full-time
# 13566         NaN    85000.00     YEARLY           Full-time
# 29510         NaN         NaN        NaN           Full-time
# 15101         NaN         NaN        NaN           Part-time
# 30166         NaN         NaN        NaN           Full-time
# 8619          NaN         NaN        NaN           Full-time
# 26355         NaN         NaN        NaN           Full-time
# 2128          NaN    95000.00     YEARLY           Full-time
# 8574          NaN       20.72     HOURLY           Full-time
# 1850          NaN         NaN        NaN           Part-time
# 23748         NaN         NaN        NaN           Full-time
# 25587         NaN         NaN        NaN            Contract
# 12978         NaN   105000.00     YEARLY           Full-time
# 10475         NaN         NaN        NaN           Part-time
# 30487         NaN         NaN        NaN           Volunteer
# 8209          NaN         NaN        NaN           Full-time
# 29710         NaN         NaN        NaN           Full-time
# 32214         NaN    55000.00     YEARLY           Full-time
# 21345         NaN         NaN        NaN           Full-time
# 18410         NaN         NaN        NaN           Full-time
# 2090          NaN       50.00     HOURLY           Full-time
# 13630         NaN         NaN        NaN           Full-time
# 5574          NaN         NaN        NaN           Full-time
# 6664          NaN         NaN        NaN           Full-time
#
#                                    location  applies original_listed_time  \
# 25585                           Windsor, WI      4.0  2023-08-22 14:46:40
# 13863                        Birmingham, AL      1.0  2023-11-01 19:06:40
# 18957                Georgia, United States     45.0  2023-08-22 17:33:20
# 24742                            Boston, MA      NaN  2023-08-22 17:33:20
# 32996                          New York, NY    309.0  2023-08-10 16:40:00
# 11793                           Bristol, IN      1.0  2023-11-02 20:06:40
# 5420   San Antonio, Texas Metropolitan Area      2.0  2023-11-03 15:33:20
# 15625                        Wilmington, DE     30.0  2023-11-03 15:33:20
# 7538                            Chicago, IL      NaN  2023-11-03 15:33:20
# 17106                        Fort Smith, AR      NaN  2023-11-02 17:20:00
# 29152                        Carrollton, TX      1.0  2023-07-28 17:33:20
# 431                              Maxton, NC      NaN  2023-11-02 20:06:40
# 5301                          Kissimmee, FL      3.0  2023-11-03 15:33:20
# 2102                            Seattle, WA      NaN  2023-10-09 18:20:00
# 22853                           Midland, MI      1.0  2023-08-23 18:33:20
2023-12-03 16:46:40                  NaN           Mid-Senior level
# 13630 2023-12-02 18:33:20                  NaN           Mid-Senior level
# 5574  2023-12-03 16:46:40                  NaN                 Internship
# 6664  2023-12-03 14:00:00                  NaN                        NaN
#
#       skills_desc   listed_time                           posting_domain  \
# 25585         NaN  1.692730e+12                                      NaN
# 13863         NaN  1.698960e+12                     workforcenow.adp.com
# 18957         NaN  1.692740e+12                                      NaN
# 24742         NaN  1.692740e+12              careers-aimbridge.icims.com
# 32996         NaN  1.691700e+12                                      NaN
# 11793         NaN  1.699050e+12                      jsv3.recruitics.com
# 5420          NaN  1.699040e+12                                      NaN
# 15625         NaN  1.699040e+12                                      NaN
# 7538          NaN  1.699040e+12                                      NaN
# 17106         NaN  1.698960e+12             pfizer.wd1.myworkdayjobs.com
# 29152         NaN  1.692830e+12                          www.amazon.jobs
# 431           NaN  1.699070e+12                         meritor.jobs.net
# 5301          NaN  1.699040e+12                                      NaN
# 2102          NaN  1.699050e+12  procasemanagement.wd1.myworkdayjobs.com
# 22853         NaN  1.692830e+12                                      NaN
# 9045          NaN  1.699070e+12                                jobot.com
# 14245         NaN  1.699070e+12                        scionstaffing.com
# 22784         NaN  1.692830e+12                 jobs.smartrecruiters.com
# 20043         NaN  1.692730e+12                                      NaN
# 18886         NaN  1.692740e+12                 careers.johnsonville.com
# 1495          NaN  1.699050e+12                 jobs.barry-callebaut.com
# 5561          NaN  1.699040e+12                     careers.docusign.com
# 11441         NaN  1.699050e+12                careers.maximstaffing.com
# 28949         NaN  1.692750e+12                                      NaN
# 10915         NaN  1.699050e+12                                      NaN
# 11942         NaN  1.699040e+12                                      NaN
# 6006          NaN  1.699040e+12                                      NaN
# 13566         NaN  1.698770e+12                                      NaN
# 29510         NaN  1.692750e+12                                      NaN
# 15101         NaN  1.699050e+12                        careers.petco.com
# 30166         NaN  1.692740e+12                            jobs.teck.com
# 8619          NaN  1.698960e+12                                      NaN
# 26355         NaN  1.692850e+12                                      NaN
# 2128          NaN  1.699050e+12                                      NaN
# 8574          NaN  1.698960e+12                    wd1.myworkdaysite.com
# 1850          NaN  1.699060e+12                  recruiting2.ultipro.com
# 23748         NaN  1.692750e+12                      micron.eightfold.ai
# 25587         NaN  1.692730e+12                                      NaN
# 12978         NaN  1.699040e+12                                      NaN
# 10475         NaN  1.699050e+12         ohiohealth.wd5.myworkdayjobs.com
# 30487         NaN  1.692740e+12                                      NaN
# 8209          NaN  1.698970e+12        thegiantcompany.careerswithus.com
# 29710         NaN  1.692740e+12                                      NaN
# 32214         NaN  1.692730e+12                                      NaN
# 21345         NaN  1.692850e+12            careers.learningcaregroup.com
# 18410         NaN  1.692740e+12                                      NaN
# 2090          NaN  1.699050e+12                                      NaN
# 13630         NaN  1.698970e+12                      careers.iconplc.com
# 5574          NaN  1.699040e+12                         koch.avature.net
# 6664          NaN  1.699040e+12                                      NaN
#
#        sponsored  work_type currency compensation_type     scraped
# 25585          0  FULL_TIME      NaN               NaN           1
# 13863          1  FULL_TIME      NaN               NaN  1698994731
# 18957          0  FULL_TIME      NaN               NaN           1
# 24742          0  FULL_TIME      NaN               NaN           1
# 32996          1  FULL_TIME      USD       BASE_SALARY           1
# 11793          1  FULL_TIME      NaN               NaN  1699050583
# 5420           0  FULL_TIME      USD       BASE_SALARY  1699088951
# 15625          0  FULL_TIME      NaN               NaN  1699050952
# 7538           0  FULL_TIME      NaN               NaN  1699129881
# 17106          0  FULL_TIME      USD       BASE_SALARY  1698964261
# 29152          1  FULL_TIME      NaN               NaN           1
# 431            0  FULL_TIME      NaN               NaN  1699086944
# 5301           0   CONTRACT      USD       BASE_SALARY  1699057125
# 2102           0  PART_TIME      USD       BASE_SALARY  1699136900
# 22853          1   CONTRACT      NaN               NaN           1
# 9045           0  FULL_TIME      USD       BASE_SALARY  1699138026
# 14245          0  TEMPORARY      USD       BASE_SALARY  1699133812
# 22784          0  FULL_TIME      NaN               NaN           1
# 20043          0   CONTRACT      NaN               NaN           1
# 18886          0  FULL_TIME      USD       BASE_SALARY           1
# 1495           0  FULL_TIME      NaN               NaN  1699055857
# 5561           0  FULL_TIME      NaN               NaN  1699072030
# 11441          0  FULL_TIME      USD       BASE_SALARY  1699061498
# 28949          0  FULL_TIME      USD       BASE_SALARY           1
# 10915          0  FULL_TIME      USD       BASE_SALARY  1699072929
# 11942          0   CONTRACT      USD       BASE_SALARY  1699044327
# 6006           1  FULL_TIME      USD       BASE_SALARY  1699044623
# 13566          1  FULL_TIME      USD       BASE_SALARY  1699091122
# 29510          0  FULL_TIME      NaN               NaN           1
# 15101          1  PART_TIME      NaN               NaN  1699080680
# 30166          0  FULL_TIME      NaN               NaN           1
# 8619           1  FULL_TIME      NaN               NaN  1698996375
# 26355          0  FULL_TIME      NaN               NaN           1
# 2128           0  FULL_TIME      USD       BASE_SALARY  1699059201
# 8574           0  FULL_TIME      USD       BASE_SALARY  1699044549
# 1850           0  PART_TIME      NaN               NaN  1699055783
# 23748          0  FULL_TIME      NaN               NaN           1
# 25587          0   CONTRACT      NaN               NaN           1
# 12978          0  FULL_TIME      USD       BASE_SALARY  1699042234
# 10475          0  PART_TIME      NaN               NaN  1699085792
# 30487          0  VOLUNTEER      NaN               NaN           1
# 8209           0  FULL_TIME      NaN               NaN  1699053693
# 29710          0  FULL_TIME      NaN               NaN           1
# 32214          1  FULL_TIME      USD       BASE_SALARY           1
# 21345          0  FULL_TIME      NaN               NaN           1
# 18410          0  FULL_TIME      NaN               NaN           1
# 2090           0  FULL_TIME      USD       BASE_SALARY  1699081937
# 13630          0  FULL_TIME      NaN               NaN  1698996154
# 5574           0  FULL_TIME      NaN               NaN  1699052579
# 6664           0  FULL_TIME      NaN               NaN  1699064167

# %% [markdown]
# Through filtering the NaN values and applying the datetime function, the data entries are now in the proper datetime format.

# %% [markdown]
# #### Listed_Time

# %%
# Convert scientific notation to standard notation (float)
df['listed_time']=df['listed_time'].astype('float64')

# %%
# Convert milliseconds to seconds 
df['listed_time']=df['listed_time']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
# 9727   Locum Surgery Physician job in Boston, MA - Ma...
# 14779                     Occupational Therapy Assistant
# 31270                      Project Architect/Coordinator
# 3196                                    Security Officer
# 29541                            Vice President of Sales
# 26902      Senior Manager, Credit Strategy and Analytics
# 12764              Research Associate - II, Pathobiology
# 2392      Travel - PCU - Nurse Job - $2432/wk - $2621/wk
# 17218                                 Software Developer
# 362                            Physician - Pulmonologist
# 13542                           Senior Interior Designer
# 18543           STREETS OPERATOR III - TRAFFIC & SIGNAGE
# 21562  Faculty Group Practice Secretary I Intake/Sche...
# 4301   Automation Engineer-Node.js and TestCafe- ONLY w2
# 25409                      Audio Visual Tech - Part Time
# 8205                                   Cashier - Driving
# 13310                           Radiologic Technologists
# 1846                Legal Services - Project Specialist
# 2750   Technical Supervisor - General Lab (Evening Sh...
# 3999                  Travel Turbine - Generation Tech I
# 18756                   Sales Director {Owner/Operator}
# 23650  Customer Service Representative-Farmers Direct...
# 26589           Entry Level Phlebotomist - Paid Training
# 13076                             Manufacturing Engineer
#
#                                              description  max_salary  \
# 13677  What The Role Is\n\nThe Continuous Improvement...         NaN
# 11188  andatory skills: Windows/Mac, Office 365, Clou...         NaN
# 5703   Employment Type\n\nFull time\n\nShift\n\nDay S...        41.4
# 5207   *THIS ROLE IS NOT OPEN TO C2C OR H1B. SUCCESSF...         NaN
# 27379  \nThe Temecula/Vail Lake KOA is an outdoor cam...         NaN
# 4818   Registered Nursing- RN - Skilled Nursing Facil...         NaN
# 16456  The Role\nAs an Implementation and Onboarding ...         NaN
# 1769   At AAM, the POWER is in our people. We believe...         NaN
# 24053  Michelin is hiring!\n- - - - - - - - - - - -\n...         NaN
# 9706   Senior Manager, Data Science - Strategy & Insi...         NaN
# 3594   Fast Growing Company is Seeking Telephonic Pat...         NaN
# 26587  Direct Supply, Inc. is seeking a qualified can...         NaN
# 18308  Please note – currently this role may not requ...         NaN
# 21343  ADP is hiring a Relationship Manager within Ne...    113700.0
# 18136  We believe that great healthcare is an essenti...         NaN
# 15101  Create a healthier, brighter future for pets, ...         NaN
# 19321  Job Description\n NA Retail Excellence and Cat...         NaN
# 25825  Overview\nAllied Universal® Compliance and Inv...        36.0
# 4841   CornerStone Technology Talent Services is seek...         NaN
# 10939  We are currently looking to expand our team wi...         NaN
# 3842   Job Summary\n\nWEX seeks a Director, External ...         NaN
# 23464  Job Description\n\nWe are looking for an Encap...        22.0
# 17373  ENGIE is committed to reshaping the energy fut...    176670.0
# 23070  This position is posted on behalf of People So...     80000.0
# 27172  Principal Product Development Project Manageme...         NaN
# 7702   Job Description\n\nDo people describe you as d...         NaN
# 9727   Aya Locums has an immediate opening for a 13-w...         NaN
# 14779  Work With Purpose\n\nAt Ageility, we bring the...         NaN
# 31270  JOB RESPONSIBILITIES:Work under the direction ...         NaN
# 3196   Overview: To be responsible for ensuring the s...         NaN
# 29541  Position Overview \nAt Fellow, we are on a mis...    230000.0
# 26902  About CarvanaIf you like disrupting the norm a...         NaN
# 12764  Title: Research Associate II, PathobiologyLoca...        43.0
# 2392   Aya Healthcare has an immediate opening for th...         NaN
# 17218  664392BR\n\nIntroduction\n\nAs a Software Deve...    192000.0
# 362    Description\n\nPosition Summary:\n\nCHRISTUS S...         NaN
# 13542  \n APPARATUS is a New York-based design studio...         NaN
# 18543  \n\nJOB SUMMARY: The Streets Operator III – Tr...         NaN
# 21562  1110989_RR00076289 Job ID: 1110989_RR00076289\...         NaN
# 4301   Top skills:Test automation using Node.js and T...         NaN
# 25409  Description\nKalahari Resorts and Conventions ...         NaN
# 8205   Overview\n\nSP+ is driven by Our Promise, “Mak...         NaN
# 13310  Job Name: CO-1750-Rad Tech for OR Cases\n\nFac...         NaN
# 1846   Join our team at Akkodis as a Legal Services P...         NaN
# 2750   Primary City/State\n\nPhoenix, Arizona\n\nDepa...         NaN
# 3999   More than a career - a chance to make a differ...         NaN
# 18756  The Entrepreneur we seek is an experienced sal...         NaN
# 23650  We are Farmers!\nWe are… more than just your f...        19.5
# 26589  By clicking the "Apply" button, I understand t...         NaN
# 13076  Paint Manufacturing Engineer - Manufacturing E...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 13677         NaN         NaN        NaN           Full-time
# 11188         NaN         NaN        NaN            Contract
# 5703          NaN        28.8     HOURLY           Full-time
# 5207          NaN         NaN        NaN            Contract
# 27379        15.5         NaN     HOURLY           Full-time
# 4818          NaN         NaN        NaN           Full-time
# 16456     60000.0         NaN     YEARLY           Full-time
# 1769          NaN         NaN        NaN           Full-time
# 24053         NaN         NaN        NaN           Full-time
# 9706          NaN         NaN        NaN           Full-time
# 3594          NaN         NaN        NaN           Full-time
# 26587         NaN         NaN        NaN           Full-time
# 18308         NaN         NaN        NaN           Full-time
# 21343         NaN     55900.0     YEARLY           Full-time
# 18136         NaN         NaN        NaN           Full-time
# 15101         NaN         NaN        NaN           Part-time
# 19321         NaN         NaN        NaN           Full-time
# 25825         NaN        27.0     HOURLY           Full-time
# 4841          NaN         NaN        NaN           Full-time
# 10939         NaN         NaN        NaN           Full-time
# 3842          NaN         NaN        NaN           Full-time
# 23464         NaN        18.0     HOURLY           Full-time
# 17373         NaN     69275.0     YEARLY           Full-time
# 23070         NaN     50000.0     YEARLY           Full-time
# 27172         NaN         NaN        NaN            Contract
# 7702          NaN         NaN        NaN           Full-time
# 9727         95.0         NaN     HOURLY           Full-time
# 14779         NaN         NaN        NaN           Part-time
# 31270         NaN         NaN        NaN           Full-time
# 3196         22.0         NaN     HOURLY           Full-time
# 29541         NaN    215000.0     YEARLY           Full-time
# 26902         NaN         NaN        NaN           Full-time
# 12764         NaN        37.0     HOURLY            Contract
# 2392          NaN         NaN        NaN           Part-time
# 17218         NaN    102000.0     YEARLY           Full-time
# 362           NaN         NaN        NaN           Full-time
# 13542         NaN         NaN        NaN           Full-time
# 18543     10000.0         NaN     YEARLY           Full-time
# 21562     48308.0         NaN     YEARLY           Full-time
# 4301          NaN         NaN        NaN            Contract
# 25409         NaN         NaN        NaN           Part-time
# 8205         18.0         NaN     HOURLY           Full-time
# 13310        62.0         NaN     HOURLY           Full-time
# 31270                                                NaN 2023-08-22 14:46:40
# 3196                                                 NaN 2023-11-03 18:20:00
# 29541                                                NaN 2023-08-22 20:20:00
# 26902                                                NaN 2023-08-23 21:20:00
# 12764                                                NaN 2023-11-03 15:33:20
# 2392                                                 NaN 2023-11-03 18:20:00
# 17218                                                NaN 2023-11-02 17:20:00
# 362                                                  NaN 2023-11-03 23:53:20
# 13542                                                NaN 2023-10-31 18:06:40
# 18543                                                NaN 2023-08-22 17:33:20
# 21562                                                NaN 2023-08-24 00:06:40
# 4301                                                 NaN 2023-11-03 18:20:00
# 25409                                                NaN 2023-08-22 17:33:20
# 8205                                                 NaN 2023-11-02 20:06:40
# 13310                                                NaN 2023-11-03 15:33:20
# 1846                                                 NaN 2023-11-03 18:20:00
# 2750                                                 NaN 2023-11-03 18:20:00
# 3999                                                 NaN 2023-11-03 18:20:00
# 18756                                                NaN 2023-08-22 17:33:20
# 23650                                                NaN 2023-08-22 20:20:00
# 26589                                                NaN 2023-08-24 00:06:40
# 13076                                                NaN 2023-11-03 15:33:20
#
#                            posting_domain  sponsored  work_type currency  \
# 13677                boards.greenhouse.io          1  FULL_TIME      NaN
# 11188                                 NaN          0   CONTRACT      NaN
# 5703              jobs.trinity-health.org          0  FULL_TIME      USD
# 5207                                  NaN          0   CONTRACT      NaN
# 27379                 www.click2apply.net          0  FULL_TIME      USD
# 4818                  www.click2apply.net          0  FULL_TIME      NaN
# 16456                                 NaN          1  FULL_TIME      USD
# 1769                      careers.aam.com          0  FULL_TIME      NaN
# 24053    michelinhr.wd3.myworkdayjobs.com          1  FULL_TIME      NaN
# 9706                                  NaN          0  FULL_TIME      NaN
# 3594                                  NaN          0  FULL_TIME      NaN
# 26587  directsupply.wd5.myworkdayjobs.com          0  FULL_TIME      NaN
# 18308                 jsv3.recruitics.com          0  FULL_TIME      NaN
# 21343                    click.appcast.io          0  FULL_TIME      USD
# 18136                                 NaN          1  FULL_TIME      NaN
# 15101                   careers.petco.com          1  PART_TIME      NaN
# 19321                    kenvue.taleo.net          0  FULL_TIME      NaN
# 25825      corporatecareers-aus.icims.com          0  FULL_TIME      USD
# 4841                                  NaN          0  FULL_TIME      NaN
# 10939                                 NaN          1  FULL_TIME      NaN
# 3842         wexinc.wd5.myworkdayjobs.com          1  FULL_TIME      NaN
# 23464               jobs.optistaffing.com          0  FULL_TIME      USD
# 17373                      jobs.engie.com          0  FULL_TIME      USD
# 23070                                 NaN          0  FULL_TIME      USD
# 27172                                 NaN          0   CONTRACT      NaN
# 7702          ekcf.fa.us6.oraclecloud.com          0  FULL_TIME      NaN
# 9727                    www.ayalocums.com          0  FULL_TIME      USD
# 14779                careers.ageility.com          1  PART_TIME      NaN
# 31270                                 NaN          0  FULL_TIME      NaN
# 3196       careers.rosewoodhotelgroup.com          0  FULL_TIME      USD
# 29541                                 NaN          1  FULL_TIME      USD
# 26902                                 NaN          0  FULL_TIME      NaN
# 12764                                 NaN          0   CONTRACT      USD
# 2392                www.ayahealthcare.com          0  PART_TIME      NaN
# 17218                   IBM.contacthr.com          0  FULL_TIME      USD
# 362            careers.christushealth.org          0  FULL_TIME      NaN
# 13542                                 NaN          1  FULL_TIME      NaN
# 18543                 www.click2apply.net          0  FULL_TIME      USD
# 21562                   nyu.contacthr.com          0  FULL_TIME      USD
# 4301                                  NaN          1   CONTRACT      NaN
# 25409                  recruiting.adp.com          0  PART_TIME      NaN
# 8205          externalsp-spplus.icims.com          0  FULL_TIME      USD
# 13310              www.trioptushealth.com          0  FULL_TIME      USD
# 1846                                  NaN          1   CONTRACT      USD
# 2750   bannerhealth.wd5.myworkdayjobs.com          0  FULL_TIME      NaN
# 3999     dukeenergy.wd1.myworkdayjobs.com          0  FULL_TIME      NaN
# 18756                                 NaN          1  FULL_TIME      NaN
# 23650           jobs.farmersinsurance.com          0  FULL_TIME      USD
# 26589              jobs.biolifeplasma.com          1  PART_TIME      NaN
# 13076                                 NaN          0  FULL_TIME      NaN
#
#       compensation_type     scraped
# 13677               NaN  1698996004
# 11188               NaN  1699050657
# 5703        BASE_SALARY  1699054437
# 5207                NaN  1699058089
# 27379       BASE_SALARY           1
# 4818                NaN  1699051395
# 16456       BASE_SALARY  1699042895
# 1769                NaN  1699056459
# 24053               NaN           1
# 9706                NaN  1699057125
# 3594                NaN  1699065500
# 26587               NaN           1
# 18308               NaN           1
# 21343       BASE_SALARY           1
# 18136               NaN           1
# 15101               NaN  1699080680
# 19321               NaN           1
# 25825       BASE_SALARY           1
# 4841                NaN  1699080606
# 10939               NaN  1699060313
# 3842                NaN  1699053618
# 23464       BASE_SALARY           1
# 17373       BASE_SALARY           1
# 23070       BASE_SALARY           1
# 27172               NaN           1
# 7702                NaN  1699042456
# 9727        BASE_SALARY  1699132905
# 14779               NaN  1699082749
# 31270               NaN           1
# 3196        BASE_SALARY  1699052431
# 29541       BASE_SALARY           1
# 26902               NaN           1
# 12764       BASE_SALARY  1699139453
# 2392                NaN  1699058312
# 17218       BASE_SALARY  1698964111
# 362                 NaN  1699139003
# 13542               NaN  1699087314
# 18543       BASE_SALARY           1
# 21562       BASE_SALARY           1
# 4301                NaN  1699053770
# 25409               NaN           1
# 8205        BASE_SALARY  1699039889
# 13310       BASE_SALARY  1699037530
# 1846        BASE_SALARY  1699064759
# 2750                NaN  1699086574
# 3999                NaN  1699061719
# 18756               NaN           1
# 23650       BASE_SALARY           1
# 26589               NaN           1
# 13076               NaN  1699042086

# %% [markdown]
# From the sample table above, we can see that all time variables have been converted into standard datetime format. In the standard notation, we can observe the following:
# - `original_listed_time` and `listed_time` are displaying similar information, further investigation is needed to remove any data redundancy.
# - `closed_time` variable contains a lot of null values and the non-null values seem to be inconsistent as some timestamps occur prior to `original_listed_time` timestamps (closed_time: 2023-07-22, 00:26:40 vs original_listed_time: 2023-08-22, 17:33:20). We will conduct further analysis to determine whether to keep `closed_time` column or not.

# %%
# Find rows with duplicate combinations of 'original_time_listed' and 'listed_time'
duplicate_rows = df[df.duplicated(subset=['original_listed_time', 'listed_time'], keep=False)]

# Group by the combination of 'original_time_listed' and 'listed_time' and count the occurrences
duplicate_counts = duplicate_rows.groupby(['original_listed_time', 'listed_time']).size().reset_index(name='count')

# Sum the counts to get the total duplicate count
total_duplicate_count = duplicate_counts['count'].sum()

print("Total duplicate count:", total_duplicate_count)
# Out:
# Total duplicate count: 32861

# %% [markdown]
# Since there are total 32861 duplicated rows (out of 33246 rows) between `original_listed_time` and `listed_time`, it would be quite redundant to keep both columns. We are mostly interested in when the job was originally listed and there's no need for additional timestamps, we will keep just one column. Hence, we will drop `listed_time` variable as `original_listed_time` contains enough information for our analysis.

# %%
df['closed_time'].isna().sum()/df.shape[0]*100
# Out:
# 96.47476388136919

# %% [markdown]
# Since the `closed_time` column is missing approximately 96 percent of the data, it will be difficult to draw any meaningful insights. The `expiry` column shows timestamps of when the job postings will expire compared to `closed_time` column where it displays timestamps of when the job postings were actually closed. For our analysis, `expiry` data is sufficient enough to showcase the relationship between number of views and the duration of the job posting. Therefore, we will drop the `closed_time` variable to avoid data inconsistency and redundancy.

# %% [markdown]
# #### Dealing with Unnecessary Columns

# %% [markdown]
# From the datatype table and time analysis, we can remove `job_posting_url`, `application_url`, `closed_time`, `listed_time`, and `scraped` as these variables are irrelevant to the problem area, thus unnecessary to keep them in the dataset. We will drop them here:

# %%
# Drop irrelevant columns 
df_clean = df.drop(['job_posting_url', 'application_url', 'closed_time', 'listed_time', 'scraped'], axis=1)

# Sanity Check
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  posting_domain              19688 non-null  object
#  19  sponsored                   33246 non-null  int64
#  20  work_type                   33246 non-null  object
#  21  currency                    13352 non-null  object
#  22  compensation_type           13352 non-null  object
# dtypes: datetime64[ns](2), float64(7), int64(2), object(12)
# memory usage: 5.8+ MB

# %% [markdown]
# The three variables mentioned above have been successfully dropped, we will now look at the "formatted_work_type" vs "work_type".

# %% [markdown]
# #### "formatted_work_type" vs "work_type"

# %%
df_clean['formatted_work_type'].value_counts()
# Out:
# formatted_work_type
# Full-time     26900
# Contract       3459
# Part-time      2244
# Temporary       260
# Internship      228
# Other           110
# Volunteer        45
# Name: count, dtype: int64

# %%
df_clean['work_type'].value_counts()
# Out:
# work_type
# FULL_TIME     26900
# CONTRACT       3459
# PART_TIME      2244
# TEMPORARY       260
# INTERNSHIP      228
# OTHER           110
# VOLUNTEER        45
# Name: count, dtype: int64

# %% [markdown]
# Since the two 'work type' columns have identical data entries, we can confirm that the two columns are redundant. Hence, we will drop 'work_type' column as the 'formatted_work_type' column is the refined version of 'work_type' column with proper headings (only the first letter is capitalized instead of every letter being  capitalized).

# %%
df_clean.drop(columns=['work_type'], inplace=True)

# Sanity Check
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  posting_domain              19688 non-null  object
#  19  sponsored                   33246 non-null  int64
#  20  currency                    13352 non-null  object
#  21  compensation_type           13352 non-null  object
# dtypes: datetime64[ns](2), float64(7), int64(2), object(11)
# memory usage: 5.6+ MB

# %% [markdown]
# Lastly, let's take a look at the two categorical variables, `Currency` and `Compensation_Type`.

# %% [markdown]
# #### Currency

# %%
df_clean['currency'].value_counts()
# Out:
# currency
# USD    13352
# Name: count, dtype: int64

# %%
df_clean['currency'].unique()
# Out:
# array(['USD', nan], dtype=object)

# %% [markdown]
# Since the `currency` only has one type of data entry, "USD", we will drop this column.

# %%
df_clean.drop(columns=['currency'], inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  posting_domain              19688 non-null  object
#  19  sponsored                   33246 non-null  int64
#  20  compensation_type           13352 non-null  object
# dtypes: datetime64[ns](2), float64(7), int64(2), object(10)
# memory usage: 5.3+ MB

# %% [markdown]
# The column `currency` has been successfully dropped, now we will take a look at the column `compensation_type`.

# %% [markdown]
# #### Compensation Type

# %%
df_clean['compensation_type'].value_counts()
# Out:
# compensation_type
# BASE_SALARY    13352
# Name: count, dtype: int64

# %%
df_clean['compensation_type'].unique()
# Out:
# array(['BASE_SALARY', nan], dtype=object)

# %% [markdown]
# Similar to `currency`, the `compensation_type` variable contains "BASE_SALARY" as the only response, thus we will drop this column.

# %%
df_clean.drop(columns=['compensation_type'], inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  posting_domain              19688 non-null  object
#  19  sponsored                   33246 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(9)
# memory usage: 5.1+ MB

# %% [markdown]
# The `compensation_type` column has been removed from the dataset. From the new datatype table, we can see that all the unnecessary columns have been dropped. Following the data loading process, we will enter the data cleaning phase using the refined dataset.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# In this section, we will be conducting various data cleaning methods, such as checking datatypes, finding any duplicates, and removing null values to prepare a clean dataset for future analysis.

# %% [markdown]
# ### DataType

# %% [markdown]
# Now let's check the updated number of rows and columns in the dataset

# %%
print(f"We have {df_clean.shape[0]} rows and {df_clean.shape[1]} columns with  string (categorical), floats and integers.")
# Out:
# We have 33246 rows and 20 columns with  string (categorical), floats and integers.

# %% [markdown]
# Revisit the datatypes using the updated dataset after dropping variables.

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  posting_domain              19688 non-null  object
#  19  sponsored                   33246 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(9)
# memory usage: 5.1+ MB

# %% [markdown]
# After dropping irrelevant columns, the dataset now has 20 columns, 2 datetime variables, 9 numerical variables and 9 categorical variables. We will continue data processing and conduct various data cleaning methods to prepare a clean dataset for preliminary EDA.

# %% [markdown]
# We will delve deeper into the dataset by observing each of the categorical and numerical variables in the data cleaning section where we deal with nulls.

# %% [markdown]
# Now let's check for any duplicates in the dataset.

# %% [markdown]
# ### Duplicates

# %%
df_clean.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 33241    False
# 33242    False
# 33243    False
# 33244    False
# 33245    False
# Length: 33246, dtype: bool

# %%
df_clean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicated rows, now let's check duplicated columns

# %%
df_clean.T.duplicated()
# Out:
# job_id                        False
# company_id                    False
# title                         False
# description                   False
# max_salary                    False
# med_salary                    False
# min_salary                    False
# pay_period                    False
# formatted_work_type           False
# location                      False
# applies                       False
# original_listed_time          False
# remote_allowed                False
# views                         False
# application_type              False
# expiry                        False
# formatted_experience_level    False
# skills_desc                   False
# posting_domain                False
# sponsored                     False
# dtype: bool

# %%
df_clean.T.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Since there are no duplicate columns, we can proceed to the final stage of data cleaning, dealing with null values.

# %% [markdown]
# ### Missing Data

# %% [markdown]
# Let's first take a look at the missing values present in each column

# %%
df_clean.isna().sum()
# Out:
# job_id                            0
# company_id                      654
# title                             0
# description                       1
# max_salary                    22135
# med_salary                    31005
# min_salary                    22135
# pay_period                    19894
# formatted_work_type               0
# location                          0
# applies                       17008
# original_listed_time              0
# remote_allowed                28444
# views                          7360
# application_type                  0
# expiry                            0
# formatted_experience_level     9181
# skills_desc                   32909
# posting_domain                13558
# sponsored                         0
# dtype: int64

# %%
df_clean.isna().sum()/df.shape[0]*100
# Out:
# job_id                         0.000000
# company_id                     1.967154
# title                          0.000000
# description                    0.003008
# max_salary                    66.579438
# med_salary                    93.259339
# min_salary                    66.579438
# pay_period                    59.838778
# formatted_work_type            0.000000
# location                       0.000000
# applies                       51.158034
# original_listed_time           0.000000
# remote_allowed                85.556157
# views                         22.138002
# application_type               0.000000
# expiry                         0.000000
# formatted_experience_level    27.615352
# skills_desc                   98.986344
# posting_domain                40.780846
# sponsored                      0.000000
# dtype: float64

# %% [markdown]
# We can observe that there are several missing values across different columns within the dataset. Let's separate them by their respective datatypes and try to deal with them one by one. This process could involve filling in the null values or entirely dropping the columns if needed.

# %% [markdown]
# ### Categorical Variables

# %% [markdown]
# #### Description

# %%
df_clean['description'].isna().sum()
# Out:
# 1

# %% [markdown]
# Since the `description` column is only missing one value, we will fill this missing information using "Not Specified".

# %%
df_clean['description'] = df_clean['description'].fillna("Not Specified")
df_clean['description'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Pay Period

# %%
df_clean['pay_period'].value_counts()
# Out:
# pay_period
# YEARLY     8009
# HOURLY     5036
# MONTHLY     224
# WEEKLY       82
# ONCE          1
# Name: count, dtype: int64

# %%
df_clean['pay_period'].isna().sum()/df_clean.shape[0]*100
# Out:
# 59.83877759730494

# %% [markdown]
# We will fill the missing values with "Not Specified" as `pay_period` is a categorical variable.

# %%
df_clean['pay_period'] = df_clean['pay_period'].fillna("Not Specified")
df_clean['pay_period'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Experience Level

# %%
df_clean['formatted_experience_level'].value_counts()
# Out:
# formatted_experience_level
# Mid-Senior level    11258
# Entry level          7969
# Associate            2793
# Director             1354
# Internship            387
# Executive             304
# Name: count, dtype: int64

# %%
df_clean['formatted_experience_level'].isna().sum()/df_clean.shape[0]*100
# Out:
# 27.615352222823798

# %% [markdown]
# Similarly, we will fill in the missing values from `formatted_experience_level` using "Not Specified" as it is a categorical variable.

# %%
df_clean['formatted_experience_level'] = df_clean['formatted_experience_level'].fillna("Not Specified")
df_clean['formatted_experience_level'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Skills Description

# %%
df_clean['skills_desc'].isna().sum()
# Out:
# 32909

# %%
df_clean['skills_desc'].isna().sum()/df_clean.shape[0]*100
# Out:
# 98.98634422186127

# %% [markdown]
# Since it's missing roughly 99 percent of the values, we will create a binary column of '0' and '1' to depict whether the job posting provides the required skills description or not. Hence, the '0' will represent the missing values where the company has not provided the skills information within the job posting, and '1' will represent the job postings that have listed the skills description within the job posting. Then, we will drop the `skills_desc` column.

# %%
df_clean['skills_present'] = df_clean['skills_desc'].notnull().astype(int)

# %%
df_clean.drop(columns=['skills_desc'], inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  33246 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  33246 non-null  object
#  17  posting_domain              19688 non-null  object
#  18  sponsored                   33246 non-null  int64
#  19  skills_present              33246 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(3), object(8)
# memory usage: 5.1+ MB

# %% [markdown]
# #### Posting Domain

# %%
df_clean['posting_domain'].value_counts()
# Out:
# posting_domain
# www.click2apply.net                    533
# jobs.smartrecruiters.com               466
# click.appcast.io                       447
# boards.greenhouse.io                   385
# recruiting.ultipro.com                 351
#                                       ...
# santegroup.clearcompany.com              1
# sforce.co                                1
# libertyglobal.wd3.myworkdayjobs.com      1
# matthey.wd3.myworkdayjobs.com            1
# jobs.armstrongceilings.com               1
# Name: count, Length: 2576, dtype: int64

# %%
df_clean['posting_domain'].isna().sum()/df_clean.shape[0]*100
# Out:
# 40.78084581603802

# %% [markdown]
# LinkedIn has two options for applying, first method is to apply through LinkedIn directly using their "Easy Apply" feature, and the second method is to apply through company's website as LinkedIn redirects the applicant to a specific company's web domain through "Apply" button. Therefore, we will assume that the reported missing values from `posting_domain` column represent the applications submitted through "Easy Apply" feature on LinkedIn.

# %% [markdown]
# Now let's organize this into a binary column where '0' represents the missing values or the direct apply through LinkedIn and '1' represents the applications through a specific company's website (having specific web domain).

# %%
df_clean['application_method'] = df_clean['posting_domain'].notnull().astype(int)

# %%
df_clean.drop(columns=['posting_domain'], inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  33246 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  33246 non-null  object
#  17  sponsored                   33246 non-null  int64
#  18  skills_present              33246 non-null  int64
#  19  application_method          33246 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(4), object(7)
# memory usage: 5.1+ MB

# %%
# Sanity Check
df_clean.isna().sum()
# Out:
# job_id                            0
# company_id                      654
# title                             0
# description                       0
# max_salary                    22135
# med_salary                    31005
# min_salary                    22135
# pay_period                        0
# formatted_work_type               0
# location                          0
# applies                       17008
# original_listed_time              0
# remote_allowed                28444
# views                          7360
# application_type                  0
# expiry                            0
# formatted_experience_level        0
# sponsored                         0
# skills_present                    0
# application_method                0
# dtype: int64

# %% [markdown]
# We have completed the data cleaning process for categorical variables by filling in the null values. Now we will take a look at numerical variables and deal with missing values.

# %% [markdown]
# ### Numerical Variables

# %% [markdown]
# #### Company ID

# %%
df_clean['company_id'].isna().sum()

# %%
df_clean['company_id'].isna().sum()/df_clean.shape[0]*100

# %% [markdown]
# Let's check for the unique values within the `company_id` column.

# %%
df_clean['company_id'].unique()

# %% [markdown]
# #### Max Salary

# %%
df_clean['max_salary'].describe()

# %%
df_clean['max_salary'].isna().sum()/df_clean.shape[0]*100

# %% [markdown]
# Let's create a visualization to observe the distribution of `max_salary` column.

# %%
plt.figure()

plt.hist(df_clean['max_salary'], bins=40)
plt.axvline(df_clean['max_salary'].mean(), color="lightcoral", label="mean")
plt.axvline(df_clean['max_salary'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of max_salary - before imputation".title())
plt.xlabel("Max Salary Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `max_salary` data is right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df_clean['max_salary'] = df_clean['max_salary'].fillna(df_clean['max_salary'].median())
df_clean['max_salary'].isna().sum()

# %% [markdown]
# #### Min Salary

# %%
df_clean['min_salary'].describe()

# %%
df_clean['min_salary'].isna().sum()/df_clean.shape[0]*100

# %% [markdown]
# Let's create a visualization to observe the distribution of `min_salary` column.

# %%
plt.figure()

plt.hist(df_clean['min_salary'], bins=40)
plt.axvline(df_clean['min_salary'].mean(), color="lightcoral", label="mean")
plt.axvline(df_clean['min_salary'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of min_salary - before imputation".title())
plt.xlabel("Min Salary Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `min_salary` data is right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df_clean['min_salary'] = df_clean['min_salary'].fillna(df_clean['min_salary'].median())
df_clean['min_salary'].isna().sum()

# %% [markdown]
# #### Median Salary

# %%
df_clean['med_salary'].isna().sum()/df.shape[0]*100

# %%
df_clean['med_salary'].describe()

# %% [markdown]
# Unlike `min_salary` and `max_salary`, `med_salary` is missing 93 percent of the dataset, thus it is harder to impute the null values. Here we will focus on whether the company has provided the median salary information in the job posting or not by creating a binary column. The entries of '0' indicates that companies have not disclosed the median salary information and the entries of '1' suggests that the companies have included the median salary information within the dataset. Then, we will drop the `med_salary` column.

# %%
df_clean['med_salary_present'] = df_clean['med_salary'].notnull().astype(int)

# %%
df_clean.drop(columns=['med_salary'], inplace=True)
df_clean.info()

# %% [markdown]
# #### Applies

# %%
df_clean['applies'].isna().sum()

# %%
df_clean['applies'].isna().sum()/df_clean.shape[0]

# %%
df_clean['applies'].describe()

# %% [markdown]
# Let's create a visualization to observe the distribution of `applies` column.

# %%
plt.figure()

plt.hist(df_clean['applies'], bins=40)
plt.axvline(df_clean['applies'].mean(), color="lightcoral", label="mean")
plt.axvline(df_clean['applies'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of applies - before imputation".title())
plt.xlabel("Applies Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `applies` data is heavily right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df_clean['applies'] = df_clean['applies'].fillna(df_clean['applies'].median())

# %%
df_clean['applies'].isna().sum()

# %% [markdown]
# #### Views

# %%
df_clean['views'].isna().sum()

# %%
df_clean['views'].isna().sum()/df_clean.shape[0]*100

# %%
df_clean['views'].describe()

# %%
# Calculate the median
median = df_clean['views'].median()

# Quartiles (Q1 and Q3)
q1 = df_clean['views'].quantile(0.25)
q3 = df_clean['views'].quantile(0.998)

# Interquartile range (IQR)
iqr = q3 - q1

# Determining the outliers
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Box Plot
plt.figure(figsize=(8, 6))
plt.boxplot(df_clean['views'], vert=False)
plt.title('Number of Views Box Plot')
plt.xlabel('Views')

# Marking the outliers
# Identifying outliers based on Views using lower and upper bounds
outliers = df_clean[(df_clean['views'] < lower_bound) | (df_clean['views'] > upper_bound)]['views']
# Plotting outliers on a horizontal line at y=1
plt.plot(outliers, [1] * len(outliers), 'ro', label='Outliers')

plt.legend()

plt.show()

# %%
df_clean[df_clean['views'] < df_clean['views'].quantile(0.995)]

# %%
df_clean.shape

# %% [markdown]
# Let's create a visualization to observe the distribution of `views` column.

# %%
plt.figure()

plt.hist(df_clean['views'], bins=40)
plt.axvline(df_clean['views'].mean(), color="lightcoral", label="mean")
plt.axvline(df_clean['views'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of views - before imputation".title())
plt.xlabel("Views Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `views` data is heavily right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df_clean['views'] = df_clean['views'].fillna(df_clean['views'].median())

# %%
df_clean['views'].isna().sum()

# %% [markdown]
# #### Remote Allowed

# %%
df_clean['remote_allowed'].describe()

# %%
df_clean['remote_allowed'].value_counts()

# %% [markdown]
# The dataset only contains the response of '1'. This could be due to the method of data collection. For instance, if the survey only had one tick-off box to check off whether the remote-working is allowed or not, then it would make sense why the data only contains '1' (check mark) as its only response.

# %%
df_clean['remote_allowed'].isna().sum()/df_clean.shape[0]*100

# %% [markdown]
# To fill in the null values, we will convert this variable into a binary column (0 and 1). Here, we are making an assumption that '0' will represent the missing values (remote-working not allowed), and '1' will be remote working allowed responses. We can simply fill the missing values in with 0s to achieve this.

# %%
df_clean['remote_allowed'] = df_clean['remote_allowed'].fillna(0)
df_clean['remote_allowed'].isna().sum()

# %% [markdown]
# #### Closed Time

# %%
df_clean['closed_time'].describe()

# %%
df_clean['closed_time'].isna().sum()/df_clean.shape[0]*100

# %% [markdown]
# Since it's missing majority of the values (96.5%), we will focus on whether the companies have included the closed time information or not in their job postings and observe if the presence of `closed_time` variable is relevant in terms of number of views. To achieve this, we will create a binary column with '0' and '1' where '0' represents no closed time information and '1' represents the indication of closed time information within the dataset.

# %%
df_clean['closed_time_present'] = df_clean['closed_time'].notnull().astype(int)

# %%
df_clean.drop(columns=['closed_time'], inplace=True)
df_clean.info()

# %%
df_clean.isna().sum()

# %% [markdown]
# We have completed all the data cleaning processes by filling in the null values. Now we will plot some graphs to analyze any patterns that may occur to address our question of interest: "Is there any relationships between the `views` column with other variables within the `job_postings` dataset?"

# %% [markdown]
# ## EDA

# %% [markdown]
# We will begin by creating some visualizations to depict any potential relationships between the `views` column and other variables. Our goal is to see if there are any patterns within the visualizations to analyze the job trends regarding the `views`.

# %% [markdown]
# ### Work Type

# %% [markdown]
# Let's take a look at the distribution of the `formatted_work_type` column.

# %%
df_clean['formatted_work_type'].value_counts(normalize=True).plot(kind="barh")
plt.show()

# %% [markdown]
# The "Full-time" work type was the most common, followed by "Contract" and "Part-time". Hence, within the LinkedIn space, most companies are looking to hire full-time positions rather than part-time or contract. Will the preference of full-time positions by recruiters have affects on the number of job posting views?

# %% [markdown]
# ### Experience Level

# %% [markdown]
# Let's create a bar chart to check the distribution of `formatted_experience_level` variable.

# %%
df_clean['formatted_experience_level'].value_counts(normalize=True).plot(kind="barh")
plt.show()

# %% [markdown]
# The "Mid-Senior level" was the most common experience level that the companies were looking for, followed by "Not Specified", "Entry level", "Associate", "Director", "Internship" and "Executive". Through modeling, we will see if the experience level has any relationship with the number of views, which can help us to identify the preference of applicants.

# %% [markdown]
# ### Sponsored

# %%
df_clean['sponsored'].value_counts(normalize=True).plot(kind="bar")
plt.show()

# %% [markdown]
# According to the visualization above, there were a lot more job postings that weren't sponsored or promoted than ones that were sponsored or promoted. In the later analysis, we will look for a potential relationship between sponsorship and number of views to test whether the `sponsor` column has an influence on the number of views.

# %% [markdown]
# ### Skills Description

# %%
df_clean['skills_present'].value_counts(normalize=True).plot(kind="bar")
plt.show()

# %% [markdown]
# Majority of the job postings were missing skills description. Hence, we will look for a potential relationship between the number of views and the presence of skills description within the job posting.

# %% [markdown]
# ### Median Salary

# %%
df_clean['med_salary_present'].value_counts(normalize=True).plot(kind="bar")
plt.show()

# %% [markdown]
# Majority of the companies did not disclose the median salary information. This is normal, and we will look into the potential relationship between number of views and the presence of median salary data within the job posting.

# %% [markdown]
# ### Views and Applies

# %%
x = df_clean['views']
y = df_clean['applies']

plt.scatter(x, y)
plt.xlabel("Number of Views") 
plt.ylabel("Number of Applications") 
plt.title("Relationship between Views and Applies") 
plt.show()

# %% [markdown]
# The scatter plot between `views` and `applies` depicts a positive correlation between the two variables. In other words, as the number of views increase, the number of applications submitted also rises. The more views the job posting get, the more likely to receive applications.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this notebook, we performed an analysis of a job posting dataset from LinkedIn, focusing on the `views` variable. The preliminary analysis included data loading, data cleaning, and basic EDA with visualization. Through experimentation, we were able to see the impacts of various job posting features, such as the experience level, number of applications submitted, median salary and more. The basic EDA analysis culminated in visualizations and insights aimed at understanding the job market trends, with an emphasis on number of views.
