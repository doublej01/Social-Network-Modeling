# %% [markdown]
# # Part I - Data Exploration and Basic EDA
#
# This is the first notebook of the capstone project. It outlines detailed steps to familiarize LinkedIn Job Postings dataset from 2023. Here, we will go over the data quality issues through various data cleaning methods and highlight any notable observations regarding data processing. Then, the basic Exploratory Data Analysis (EDA) is performed to showcase potential relationships between different job attributes and `views`, our target variable.
#
# **Author: JJ Park**
#
# **Date: 28/02/2024**

# %% [markdown]
# ## LinkedIn Job Postings 2023

# %% [markdown]
# ### Question of Interest
# How can we leverage the job postings data from LinkedIn to add significant value to both companies and job applicants? Here, we will tackle the `views` column by conducting preliminary EDA to find relationships between different variables within the dataset.
#
# - Company: what are the key features in a job posting that recruiters should emphasize to raise the number of views and attract more talents?
# - Applicant: can we assess the latest job trends by analyzing job postings with high views to boost the chances of getting hired?

# %% [markdown]
# ### Dataset

# %% [markdown]
# Dataset has been sourced from: https://www.kaggle.com/datasets/arshkon/linkedin-job-postings/data.

# %% [markdown]
# <a id= 'table' ></a>
# ### Table of Contents
#
# 1. [Data Dictionary](#Dictionary)
# 2. [Data Loading](#Load)
# 3. [Data Cleaning - Datatypes](#Datatypes)
# 4. [Data Cleaning - Duplicates](#Duplicates)
# 5. [Data Cleaning - Null Values](#Null)
# 6. [Basic EDA - Visualizing Patterns](#EDA)
# 7. [Summary](#Summary)

# %% [markdown]
# <a id = 'Dictionary'><a/>
# ## Data Dictionary
#
# ---

# %% [markdown]
# The data dictionary outlines all the variables from the `job_postings.csv` dataset. The descriptions of each variable are directly sourced from the author's Github: https://github.com/ArshKA/LinkedIn-Job-Scraper/blob/master/DatabaseStructure.md.

# %% [markdown]
# 1. `job_id`: The job ID as defined by LinkedIn (https://www.linkedin.com/jobs/view/{ job_id })
# 2. `company_id`: Identifier for the company associated with the job posting (maps to companies.csv)
# 3. `title`: Job title
# 4. `description`: Job description
# 5. `max_salary`: Maximum salary
# 6. `med_salary`: Median salary
# 7. `min_salary`: Minimum salary
# 8. `pay_period`: Pay period for salary (Hourly, Monthly, Yearly)
# 9. `formatted_work_type`: Type of work (Fulltime, Parttime, Contract)
# 10. `location`: Job location
# 11. `applies`: Number of applications that have been submitted
# 12. `original_listed_time`: Original time the job was listed
# 13. `remote_allowed`: Whether job permits remote work
# 14. `views`: Number of times the job posting has been viewed
# 15. `job_posting_url`: URL to the job posting on a platform
# 16. `application_url`: URL where applications can be submitted
# 17. `application_type`: Type of application process (offsite, complex/simple onsite)
# 18. `expiry`: Expiration date or time for the job listing
# 19. `closed_time`: Time to close job listing
# 20. `formatted_experience_level`: Job experience level (entry, associate, executive, etc)
# 21. `skills_desc`: Description detailing required skills for job
# 22. `listed_time`: Time when the job was listed
# 23. `posting_domain`: Domain of the website with application
# 24. `sponsored`: Whether the job listing is sponsored or promoted
# 25. `work_type`: Type of work associated with the job
# 26. `currency`: Currency in which the salary is provided
# 27. `compensation_type`: Type of compensation for the job
# 28. `scraped`: Has been scraped by `details_retriever`

# %% [markdown]
# <a id = 'Load'><a/>
# ## Data Loading
#
# ---

# %% [markdown]
# In this section, we will first load the LinkedIn dataset, then explore the dataset by checking the first and last few rows to improve our understanding.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
raw_df = pd.read_csv('../Data/job_postings.csv')

# Display all the columns, avoiding truncated column names
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# Check the first few rows
raw_df.head()
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
#    min_salary pay_period formatted_work_type          location  applies  \
# 0         NaN    MONTHLY           Full-time  Little River, SC      NaN
# 1         NaN        NaN           Full-time    Beaver Dam, WI      NaN
# 2         NaN        NaN           Full-time      Bessemer, AL      NaN
# 3         NaN     HOURLY           Full-time   Aliso Viejo, CA      NaN
# 4    205956.0     YEARLY           Full-time     United States      NaN
#
#    original_listed_time  remote_allowed  views  \
# 0          1.699090e+12             NaN    9.0
# 1          1.699080e+12             NaN    NaN
# 2          1.699080e+12             NaN    NaN
# 3          1.699080e+12             NaN    1.0
# 4          1.698970e+12             1.0    NaN
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
# 4  https://www.linkedin.com/jobs/view/3757937095/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#          expiry  closed_time formatted_experience_level  \
# 0  1.701680e+12          NaN                Entry level
# 1  1.701680e+12          NaN                        NaN
# 2  1.701680e+12          NaN                        NaN
# 3  1.701680e+12          NaN                Entry level
# 4  1.701680e+12          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
# 4                                                NaN  1.699090e+12
#
#              posting_domain  sponsored  work_type currency compensation_type  \
# 0  careers-demant.icims.com          0  FULL_TIME      USD       BASE_SALARY
# 1       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 2       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 3           jobs.apploi.com          0  FULL_TIME      USD       BASE_SALARY
# 4         careers.iherb.com          0  FULL_TIME      USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346

# %%
# Check the last few rows
raw_df.tail()
# Out:
#           job_id  company_id                            title  \
# 33241  133114754  77766802.0                    Sales Manager
# 33242  108965123         NaN  Office Administrative Assistant
# 33243  102339515  52132271.0                  Franchise Owner
# 33244   85008768         NaN         Licensed Insurance Agent
# 33245    3958427    630152.0                 Stylist/ Clorist
#
#                                              description  max_salary  \
# 33241  Are you a dynamic and creative marketing profe...         NaN
# 33242  A fast-fashion wholesaler, is looking for a fu...         NaN
# 33243  DuctVentz is a dryer and A/C – heat vent clean...         NaN
# 33244  While many industries were hurt by the last fe...     52000.0
# 33245  Karen Marie is looking for an awesome experien...     80000.0
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 33241         NaN         NaN        NaN           Full-time
# 33242         NaN         NaN        NaN           Full-time
# 33243         NaN         NaN        NaN           Full-time
# 33244         NaN     45760.0     YEARLY           Full-time
# 33245         NaN     35000.0     YEARLY           Full-time
#
#                 location  applies  original_listed_time  remote_allowed  \
# 33241  Santa Clarita, CA      NaN          1.692830e+12             NaN
# 33242       New York, NY      2.0          1.699040e+12             NaN
# 33243     Greater Boston      NaN          1.699050e+12             NaN
# 33244          Chico, CA      NaN          1.692750e+12             NaN
# 33245        Chicago, IL      NaN          1.699050e+12             NaN
#
#        views                                    job_posting_url  \
# 33241    NaN  https://www.linkedin.com/jobs/view/133114754/?...
# 33242    4.0  https://www.linkedin.com/jobs/view/108965123/?...
# 33243    NaN  https://www.linkedin.com/jobs/view/102339515/?...
# 33244    5.0  https://www.linkedin.com/jobs/view/85008768/?t...
# 33245    7.0  https://www.linkedin.com/jobs/view/3958427/?tr...
#
#       application_url    application_type        expiry  closed_time  \
# 33241             NaN  ComplexOnsiteApply  1.695430e+12          NaN
# 33242             NaN  ComplexOnsiteApply  1.701630e+12          NaN
# 33243             NaN   SimpleOnsiteApply  1.701640e+12          NaN
# 33244             NaN  ComplexOnsiteApply  1.708300e+12          NaN
# 33245             NaN  ComplexOnsiteApply  1.714600e+12          NaN
#
#       formatted_experience_level  \
# 33241                        NaN
# 33242                        NaN
# 33243                        NaN
# 33244                        NaN
# 33245                        NaN
#
#                                              skills_desc   listed_time  \
# 33241                                                NaN  1.692830e+12
# 33242                                                NaN  1.699040e+12
# 33243                                                NaN  1.699050e+12
# 33244                                                NaN  1.692750e+12
# 33245  Must be a seasoned stylist with an existing bo...  1.699050e+12
#
#       posting_domain  sponsored  work_type currency compensation_type  \
# 23899  Construction Project Manager - FAA Experience ...
# 30801                        Wholesale Account Executive
# 2466                            Territory Representative
# 16686  Frontend / UI Developer (Angular, Typescript, ...
# 3324                    Healthcare Facets Lead Developer
# 25136  Managing Director - Washington DC Health Practice
# 30663  Manager, Workforce Technologies - Capital Tech...
# 21758                  LOCAL CDLA Feed Haul Truck Driver
# 14542  Travel Nurse RN - ED - Emergency Department - ...
# 15760                           Financial Representative
# 27810  Publisher, Local Marketing Specialist & Parent...
# 1254          Maintenance Manager (Relocation Available)
# 21005  Radiographer - Per Diem Variable Shifts - Radi...
# 10654           Pharmacy Technician & Technician Trainee
# 18856                             Craftsmanship Engineer
# 12802                       Software Engineering Manager
# 21700                     Territory Sales Representative
# 1473                            Lobby Ambassador (39432)
# 30999                      Class B Route Delivery Driver
# 1962   Part-Time Sales Associate - 6743 OUTLET SHOPPE...
# 28004                             Transportation Manager
# 18678                    Multifamily Real Estate Analyst
# 12257                               IT Finiacial Analyst
#
#                                              description  max_salary  \
# 7012   Interested in making a positive impact? You’ve...         NaN
# 27990  Design, estimate, and code intermediate to com...    166420.0
# 192    Make a Difference on Your Own Schedule and Ter...        38.5
# 2950   Summary\n\n SUMMARY: Facilitates transfer requ...         NaN
# 9084   What You'll Be Doing:\n\nYou'll lead by exampl...         NaN
# 25775  Responsibilities:• Prepare and review corporat...         NaN
# 27858  When you join Verizon\n\nVerizon is one of the...     56000.0
# 27087  About the Company:\n\nWe are an industry thoug...         NaN
# 12211  Dietary Cook- Offering Sign-on Bonus!\n\nStart...         NaN
# 15314  EyeCare Partners is the nation’s leading provi...         NaN
# 18379  Best People + Right Culture. These are the dri...         NaN
# 6807   Senior Scientist, Clinical Translational Scien...    165000.0
# 2424   Job Description\n\nHKA is working on behalf of...         NaN
# 20647  Access This Exclusive Permanent Staff Acute Ca...        39.0
# 13429  Accounts Payable SpecialistThis role is onsite...     65000.0
# 6164   Overview\n\nThe Director, Search Engine Market...    115000.0
# 12460  Senior Project Manager / Project Executive – C...    160000.0
# 6203   VIVA Railings, LLC has been consistently ranke...         NaN
# 2790   The Sensors Division at STR focuses on technol...         NaN
# 19661  City Lifestyle [formerly Lifestyle Publication...         NaN
# 18872  About Lunavi At Lunavi, we believe in illumina...         NaN
# 606    Job Description\n\nCustomer Service Specialist...        15.0
# 25218  Position Title: Associate Network Construction...     83720.0
# 23860  Rocket Lab\n\nRocket Lab is a vertically integ...         NaN
# 9276   CompanyPrivate practiceRole DescriptionThis is...         NaN
# 5137   Registered Nurse - RN - LTC/SNF\nCareerStaff U...         NaN
# 19446  One Team, One Vision, One Goal\nEstablished in...         NaN
# 23899  In a world of possibilities, pursue one with e...    161400.0
# 30801  Company Description\nExcelerate Capital is a f...         NaN
# 2466   R00216477\n\nJoin Ecolab’s Global Quick Servic...         NaN
# 16686  Greeting from Accionlabs;\nWe are seeking cand...    115000.0
# 3324   Job Descriptions Below: This position requires...         NaN
# 25136  Milliman is opening a location in Washington D...         NaN
# 30663  Office: MTA Headquarters, 2 Broadway, New York...         NaN
# 21758  Job Description\n\nPosition # 10109261\n\nJob ...         NaN
# 14542  Coast Medical Service is seeking a travel nurs...         NaN
# 15760  Company Description\nRole DescriptionThis part...         NaN
# 27810  Are you looking for a flexible, work-from-home...         NaN
# 1254   Company OverviewJoin one of the world's top fo...    180000.0
# 21005  Allied Health --> Radiology\nPatchogue, NY\nID...         NaN
# 10654  Pharmacy Technician\Technician in Training Con...         NaN
# 18856  Job Summary\nOur client is seeking a Craftsman...        68.0
# 12802  We are looking for a Software Development Mana...         NaN
# 21700  Our client has been in the Iowa construction i...         NaN
# 1473   Job Title:  Concierge Associate \n\n Reports T...         NaN
# 30999  CrossCountry Freight Solutions is hiring a Cla...         NaN
# 1962   Overview\n\nOur Sales Associates promote our c...         NaN
# 28004  Our client is looking to add a Transportation ...         NaN
# 18678  At Freddie Mac, you will do important work to ...     90000.0
# 12257  Role: IT Financial AnalystLocation: Richmond, ...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 7012          NaN         NaN        NaN           Part-time
# 27990         NaN    136760.0     YEARLY           Full-time
# 192           NaN        36.0     HOURLY           Part-time
# 2950          NaN         NaN        NaN           Full-time
# 9084          NaN         NaN        NaN           Full-time
# 25775         NaN         NaN        NaN           Full-time
# 27858         NaN     43000.0     YEARLY           Full-time
# 27087         NaN         NaN        NaN           Part-time
# 12211       20.00         NaN     HOURLY           Full-time
# 15314         NaN         NaN        NaN           Full-time
# 18379         NaN         NaN        NaN           Full-time
# 6807          NaN    130000.0     YEARLY           Full-time
# 2424          NaN         NaN        NaN           Full-time
# 20647         NaN        31.0     HOURLY           Full-time
# 13429         NaN     60000.0     YEARLY           Full-time
# 6164          NaN     99999.0     YEARLY           Full-time
# 12460         NaN    120000.0     YEARLY           Full-time
# 6203          NaN         NaN        NaN           Full-time
# 2790          NaN         NaN        NaN           Full-time
# 19661   201182.00         NaN     YEARLY           Full-time
# 18872         NaN         NaN        NaN           Full-time
# 606           NaN        15.0     HOURLY           Full-time
# 25218         NaN     58240.0     YEARLY           Full-time
# 23860         NaN         NaN        NaN           Full-time
# 9276          NaN         NaN        NaN           Part-time
# 5137        48.00         NaN     HOURLY           Full-time
# 19446         NaN         NaN        NaN           Full-time
# 23899         NaN     92200.0     YEARLY           Full-time
# 30801         NaN         NaN        NaN           Full-time
# 2466          NaN         NaN        NaN           Full-time
# 16686         NaN     80000.0     YEARLY            Contract
# 3324          NaN         NaN        NaN           Full-time
# 25136         NaN         NaN        NaN           Full-time
# 30663         NaN         NaN        NaN           Full-time
# 21758       25.45         NaN     HOURLY           Full-time
# 14542         NaN         NaN        NaN           Part-time
# 15760         NaN         NaN        NaN           Part-time
# 27810         NaN         NaN        NaN            Contract
# 1254          NaN    140000.0     YEARLY           Full-time
# 21005         NaN         NaN        NaN           Temporary
# 10654         NaN         NaN        NaN           Full-time
# 18856         NaN        50.0     HOURLY            Contract
# 12802         NaN         NaN        NaN           Full-time
# 21700         NaN         NaN        NaN           Full-time
# 1473          NaN         NaN        NaN           Full-time
# 30999       24.00         NaN     HOURLY           Full-time
# 1962          NaN         NaN        NaN           Part-time
# 28004         NaN         NaN        NaN           Full-time
# 18678         NaN     60000.0     YEARLY           Full-time
# 12257         NaN         NaN        NaN            Contract
#
#                               location  applies  original_listed_time  \
# 7012                          Kula, HI      NaN          1.699040e+12
# 27990                San Francisco, CA     16.0          1.692820e+12
# 192                    Dallas City, IL      NaN          1.696920e+12
# 2950                       Oakland, CA      NaN          1.699050e+12
# 9084                    Huntsville, AL      NaN          1.698970e+12
# 25775                        Lisle, IL      NaN          1.692640e+12
# 27858                         Avon, MA      NaN          1.692830e+12
# 27087                        Miami, FL      NaN          1.692840e+12
# 12211                 New Holstein, WI      1.0          1.699040e+12
# 15314                   Brownstown, MI      NaN          1.698970e+12
# 18379                       Dallas, TX      NaN          1.692740e+12
# 6807                       Waltham, MA     11.0          1.699040e+12
# 2424                      Chandler, AZ      1.0          1.698970e+12
# 20647                       Seneca, SC      NaN          1.692680e+12
# 13429                      Seattle, WA     31.0          1.698790e+12
# 6164                       Buffalo, NY      NaN          1.699040e+12
# 12460      Dallas-Fort Worth Metroplex      NaN          1.699040e+12
# 6203                    Lewisville, TX      NaN          1.699040e+12
# 2790                        Woburn, MA      1.0          1.698970e+12
# 19661                   Sebastopol, CA      1.0          1.692730e+12
# 18872                     Cheyenne, WY      1.0          1.692740e+12
# 606                     Cottonwood, AZ      NaN          1.696910e+12
# 25218                       Mahwah, NJ      NaN          1.692660e+12
# 23860       Mississippi, United States      NaN          1.692740e+12
# 9276                    Wilmington, NC      NaN          1.699060e+12
# 5137                    Pittsburgh, PA      NaN          1.699050e+12
# 19446           Florida, United States     44.0          1.692730e+12
# 23899          Virginia, United States      6.0          1.692740e+12
# 30801                       Irvine, CA      NaN          1.692740e+12
# 2466                 Port St Lucie, FL      1.0          1.698970e+12
# 16686                   Pittsburgh, PA      NaN          1.699040e+12
# 3324                     Baltimore, MD      NaN          1.699050e+12
# 25136                       Vienna, VA      1.0          1.692660e+12
# 30663                     New York, NY      4.0          1.692740e+12
# 21758                   Dardanelle, AR      NaN          1.692840e+12
# 14542                 Port Angeles, WA      NaN          1.698970e+12
# 15760                        Wixom, MI      NaN          1.699040e+12
# 27810                    United States      7.0          1.692830e+12
# 1254                     Vancouver, WA      NaN          1.699060e+12
# 21005                    Patchogue, NY      NaN          1.692140e+12
# 10654                       Ottawa, OH      NaN          1.699050e+12
# 18856                San Francisco, CA      1.0          1.692740e+12
# 12802  Raleigh-Durham-Chapel Hill Area    124.0          1.699040e+12
# 21700                   Des Moines, IA      NaN          1.692840e+12
# 1473                    Alpharetta, GA      NaN          1.699060e+12
# 30999               Grand Junction, CO      NaN          1.692660e+12
# 1962                     Woodstock, GA      NaN          1.699050e+12
# 28004                       Denver, CO      NaN          1.692820e+12
# 18678                       McLean, VA     29.0          1.692660e+12
# 12257                     Richmond, VA      3.0          1.699040e+12
#
#        remote_allowed  views  \
# 7012              NaN    NaN
# 27990             NaN   64.0
# 192               NaN    NaN
# 2950              NaN    3.0
# 16686                                                NaN  ComplexOnsiteApply
# 3324                                                 NaN  ComplexOnsiteApply
# 25136  https://recruiting2.ultipro.com/MIL1017/JobBoa...        OffsiteApply
# 30663                                                NaN  ComplexOnsiteApply
# 21758  https://intelliapp.driverapponline.com/c/tyson...        OffsiteApply
# 14542  https://click.appcast.io/track/hw3e3dd?cs=j9z&...        OffsiteApply
# 15760                                                NaN   SimpleOnsiteApply
# 27810                                                NaN   SimpleOnsiteApply
# 1254                                                 NaN  ComplexOnsiteApply
# 21005  https://jobs.silkroad.com/licommunityhospital/...        OffsiteApply
# 10654  https://careers.riteaid.com/rite_aid_jobs/7145...        OffsiteApply
# 18856  https://www.randstadusa.com/jobs/141/1023627/c...        OffsiteApply
# 12802                                                NaN  ComplexOnsiteApply
# 21700  https://jobs.thepalmergroup.com/job/territory-...        OffsiteApply
# 1473   https://www.paycomonline.net/v4/ats/web.php/jo...        OffsiteApply
# 30999  https://recruiting2.ultipro.com/CRO1008CROS/Jo...        OffsiteApply
# 1962   https://retail-brooks-sparcgroup.icims.com/job...        OffsiteApply
# 28004  https://www.w3global.com/candidate-apply.php/T...        OffsiteApply
# 18678  https://careers.freddiemac.com/us/en/job/FRMAU...        OffsiteApply
# 12257                                                NaN  ComplexOnsiteApply
#
#              expiry   closed_time formatted_experience_level skills_desc  \
# 7012   1.701630e+12           NaN           Mid-Senior level         NaN
# 27990  1.695420e+12           NaN                Entry level         NaN
# 192    1.701670e+12           NaN           Mid-Senior level         NaN
# 2950   1.701640e+12           NaN                Entry level         NaN
# 9084   1.701660e+12           NaN           Mid-Senior level         NaN
# 25775  1.708190e+12           NaN                        NaN         NaN
# 27858  1.695420e+12           NaN                Entry level         NaN
# 27087  1.695430e+12           NaN                        NaN         NaN
# 12211  1.701640e+12           NaN                Entry level         NaN
# 15314  1.701640e+12           NaN                  Associate         NaN
# 18379  1.695330e+12           NaN                   Director         NaN
# 6807   1.701630e+12           NaN           Mid-Senior level         NaN
# 2424   1.701640e+12           NaN                Entry level         NaN
# 20647  1.695280e+12           NaN                Entry level         NaN
# 13429  1.714340e+12           NaN                        NaN         NaN
# 6164   1.701640e+12           NaN                   Director         NaN
# 12460  1.701630e+12           NaN           Mid-Senior level         NaN
# 6203   1.701630e+12           NaN           Mid-Senior level         NaN
# 2790   1.701650e+12           NaN                Entry level         NaN
# 19661  1.695330e+12           NaN                   Director         NaN
# 18872  1.695330e+12           NaN                  Associate         NaN
# 606    1.701670e+12           NaN                Entry level         NaN
# 25218  1.695330e+12           NaN           Mid-Senior level         NaN
# 23860  1.695340e+12           NaN           Mid-Senior level         NaN
# 9276   1.701650e+12           NaN                        NaN         NaN
# 5137   1.701640e+12           NaN                        NaN         NaN
# 19446  1.695330e+12           NaN           Mid-Senior level         NaN
# 23899  1.695340e+12           NaN           Mid-Senior level         NaN
# 30801  1.695330e+12  1.690000e+12                        NaN         NaN
# 2466   1.701640e+12           NaN                  Associate         NaN
# 16686  1.701630e+12           NaN           Mid-Senior level         NaN
# 3324   1.701640e+12           NaN           Mid-Senior level         NaN
# 25136  1.695330e+12           NaN                  Executive         NaN
# 30663  1.695330e+12           NaN           Mid-Senior level         NaN
# 21758  1.695440e+12           NaN                Entry level         NaN
# 14542  1.701640e+12           NaN                Entry level         NaN
# 15760  1.701630e+12           NaN                        NaN         NaN
# 27810  1.695420e+12           NaN                        NaN         NaN
# 1254   1.701650e+12           NaN                   Director         NaN
# 21005  1.695450e+12           NaN                Entry level         NaN
# 10654  1.701640e+12           NaN                 Internship         NaN
# 18856  1.695350e+12           NaN                        NaN         NaN
# 12802  1.701630e+12           NaN           Mid-Senior level         NaN
# 21700  1.695430e+12           NaN                Entry level         NaN
# 1473   1.701650e+12           NaN           Mid-Senior level         NaN
# 30999  1.695350e+12           NaN                Entry level         NaN
# 1962   1.701640e+12           NaN                Entry level         NaN
# 28004  1.695420e+12           NaN           Mid-Senior level         NaN
# 18678  1.695330e+12           NaN                Entry level         NaN
# 12257  1.701630e+12           NaN                        NaN         NaN
#
#         listed_time                                 posting_domain  sponsored  \
# 7012   1.699040e+12                         www.fusionmedstaff.com          0
# 27990  1.692830e+12                                  jobs.lever.co          0
# 192    1.699080e+12        procasemanagement.wd1.myworkdayjobs.com          0
# 2950   1.699050e+12  alameda-health-system-careers.hctsportals.com          1
# 9084   1.699070e+12                            careers.synovus.com          0
# 25775  1.692640e+12                                            NaN          0
# 27858  1.692830e+12                               www.aplitrak.com          1
# 27087  1.692840e+12                                            NaN          0
# 12211  1.699040e+12                         nshorehc.hcshiring.com          1
# 15314  1.699050e+12                       www.eyecare-partners.com          0
# 18379  1.692740e+12                                jobs.jedunn.com          1
# 6807   1.699040e+12                                            NaN          0
# 2424   1.699050e+12                                  jobs.hkaa.com          0
# 20647  1.692680e+12                          www.ayahealthcare.com          0
# 13429  1.698790e+12                                            NaN          1
# 6164   1.699040e+12                       careers-audacy.icims.com          0
# 12460  1.699040e+12                                            NaN          0
# 6203   1.699040e+12                                            NaN          1
# 2790   1.699050e+12                           boards.greenhouse.io          0
# 19661  1.692730e+12                                            NaN          1
# 18872  1.692740e+12                                            NaN          0
# 606    1.699070e+12                    ejhp.fa.us6.oraclecloud.com          0
# 25218  1.692740e+12                        recruiting2.ultipro.com          1
# 23860  1.692750e+12                           www.rocketlabusa.com          0
# 9276   1.699060e+12                                            NaN          0
# 5137   1.699050e+12                            www.click2apply.net          1
# 19446  1.692730e+12                                            NaN          0
# 23899  1.692740e+12                  parsons.wd5.myworkdayjobs.com          0
# 30801  1.692740e+12                                            NaN          0
# 2466   1.699050e+12                           ecolab.contacthr.com          0
# 16686  1.699040e+12                                            NaN          0
# 3324   1.699050e+12                                            NaN          0
# 25136  1.692740e+12                        recruiting2.ultipro.com          0
# 30663  1.692740e+12                                            NaN          1
# 21758  1.692840e+12                 intelliapp.driverapponline.com          0
# 14542  1.699050e+12                               click.appcast.io          0
# 15760  1.699040e+12                                            NaN          0
# 27810  1.692830e+12                                            NaN          0
# 1254   1.699060e+12                                            NaN          1
# 21005  1.692850e+12                              jobs.silkroad.com          0
# 10654  1.699050e+12                            careers.riteaid.com          1
# 18856  1.692760e+12                            www.randstadusa.com          1
# 12802  1.699040e+12                                            NaN          0
# 21700  1.692840e+12                        jobs.thepalmergroup.com          0
# 1473   1.699060e+12                           www.paycomonline.net          0
# 30999  1.692760e+12                        recruiting2.ultipro.com          0
# 1962   1.699050e+12             retail-brooks-sparcgroup.icims.com          0
# 28004  1.692830e+12                               www.w3global.com          1
# 18678  1.692740e+12                         careers.freddiemac.com          0
# 12257  1.699040e+12                                            NaN          0
#
#        work_type currency compensation_type     scraped
# 7012   PART_TIME      NaN               NaN  1699086162
# 27990  FULL_TIME      USD       BASE_SALARY           1
# 192    PART_TIME      USD       BASE_SALARY  1699133581
# 2950   FULL_TIME      NaN               NaN  1699132305
# 9084   FULL_TIME      NaN               NaN  1699083491
# 25775  FULL_TIME      NaN               NaN           1
# 27858  FULL_TIME      USD       BASE_SALARY           1
# 27087  PART_TIME      NaN               NaN           1
# 12211  FULL_TIME      USD       BASE_SALARY  1699133431
# 15314  FULL_TIME      NaN               NaN  1699072698
# 18379  FULL_TIME      NaN               NaN           1
# 6807   FULL_TIME      USD       BASE_SALARY  1699062681
# 2424   FULL_TIME      NaN               NaN  1699064013
# 20647  FULL_TIME      USD       BASE_SALARY           1
# 13429  FULL_TIME      USD       BASE_SALARY  1699137350
# 6164   FULL_TIME      USD       BASE_SALARY  1699053693
# 12460  FULL_TIME      USD       BASE_SALARY  1699041863
# 6203   FULL_TIME      NaN               NaN  1699044179
# 2790   FULL_TIME      NaN               NaN  1699054585
# 19661  FULL_TIME      USD       BASE_SALARY           1
# 18872  FULL_TIME      NaN               NaN           1
# 606    FULL_TIME      USD       BASE_SALARY  1699087909
# 25218  FULL_TIME      USD       BASE_SALARY           1
# 23860  FULL_TIME      NaN               NaN           1
# 9276   PART_TIME      NaN               NaN  1699133812
# 5137   FULL_TIME      USD       BASE_SALARY  1699071957
# 19446  FULL_TIME      NaN               NaN           1
# 23899  FULL_TIME      USD       BASE_SALARY           1
# 30801  FULL_TIME      NaN               NaN           1
# 2466   FULL_TIME      NaN               NaN  1699084307
# 16686   CONTRACT      USD       BASE_SALARY  1699036622
# 3324   FULL_TIME      NaN               NaN  1699051617
# 25136  FULL_TIME      NaN               NaN           1
# 30663  FULL_TIME      NaN               NaN           1
# 21758  FULL_TIME      USD       BASE_SALARY           1
# 14542  PART_TIME      NaN               NaN  1699057347
# 15760  PART_TIME      NaN               NaN  1699041790
# 27810   CONTRACT      NaN               NaN           1
# 1254   FULL_TIME      USD       BASE_SALARY  1699073595
# 21005  TEMPORARY      NaN               NaN           1
# 10654  FULL_TIME      NaN               NaN  1699072252
# 18856   CONTRACT      USD       BASE_SALARY           1
# 12802  FULL_TIME      NaN               NaN  1699057868
# 21700  FULL_TIME      NaN               NaN           1
# 1473   FULL_TIME      NaN               NaN  1699080975
# 30999  FULL_TIME      USD       BASE_SALARY           1
# 1962   PART_TIME      NaN               NaN  1699080309
# 28004  FULL_TIME      NaN               NaN           1
# 18678  FULL_TIME      USD       BASE_SALARY           1
# 12257   CONTRACT      NaN               NaN  1699137801

# %% [markdown]
# Let's check the number of rows and columns in the dataset.

# %%
raw_df.shape
# Out:
# (33246, 28)

# %% [markdown]
# From the initial observation, we can report the following:
# - Several NaN (missing) values across different columns
# - Presence of irrelevant columns (i.e. "job_posting_url", "application_url", and "scraped")
# - Presence of dummy variables (binary columns)
# - Data entries from time-related variables must be reformatted into a standard datetime format
# - Columns, "Formatted_Work_Type" and "Work_Type" display identical information
# - Two categorical variables, "Currency" and "Compensation_Type" require further investigation as they seem to have only one type of data entry.
#
# Now let's check the data types:

# %%
# Sanity Check
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  float64
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  job_posting_url             33246 non-null  object
#  15  application_url             20996 non-null  object
#  16  application_type            33246 non-null  object
#  17  expiry                      33246 non-null  float64
#  18  closed_time                 1172 non-null   float64
#  19  formatted_experience_level  24065 non-null  object
#  20  skills_desc                 337 non-null    object
#  21  listed_time                 33246 non-null  float64
#  22  posting_domain              19688 non-null  object
#  23  sponsored                   33246 non-null  int64
#  24  work_type                   33246 non-null  object
#  25  currency                    13352 non-null  object
#  26  compensation_type           13352 non-null  object
#  27  scraped                     33246 non-null  int64
# dtypes: float64(11), int64(3), object(14)
# memory usage: 7.1+ MB

# %% [markdown]
# Next we will go over each of the time variable in the dataset ("original_listed_time", "expiry", "closed_time", and "listed_time"), and convert the data entries into a standard datetime format (Year-Month-Date, Hour-Minute_Second).

# %% [markdown]
# ### Dealing with Time Variables

# %%
# Check the unique values of 'original_listed_time' column
raw_df['original_listed_time'].value_counts()
# Out:
# original_listed_time
# 1.699050e+12    5005
# 1.699040e+12    4958
# 1.692740e+12    3798
# 1.692730e+12    3407
# 1.698970e+12    2398
# 1.692750e+12    1578
# 1.692830e+12    1536
# 1.692660e+12    1365
# 1.699060e+12     993
# 1.699070e+12     908
# 1.692840e+12     854
# 1.692850e+12     726
# 1.692820e+12     685
# 1.698960e+12     654
# 1.698880e+12     325
# 1.696890e+12     314
# 1.699080e+12     308
# 1.690580e+12     219
# 1.692860e+12     206
# 1.699030e+12     203
# 1.692680e+12     196
# 1.696880e+12     166
# 1.692580e+12     155
# 1.690690e+12     109
# 1.690670e+12     100
# 1.696910e+12      96
# 1.692870e+12      96
# 1.698790e+12      85
# 1.698780e+12      76
# 1.692640e+12      73
# 1.692720e+12      69
# 1.696800e+12      62
# 1.698770e+12      61
# 1.691690e+12      57
# 1.696870e+12      52
# 1.690570e+12      51
# 1.691700e+12      46
# 1.699020e+12      41
# 1.696900e+12      37
# 1.698760e+12      36
# 1.690660e+12      35
# 1.698800e+12      31
# 1.692140e+12      31
# 1.690520e+12      30
# 1.698950e+12      30
# 1.692230e+12      29
# 1.691710e+12      25
# 1.697560e+12      21
# 1.698940e+12      21
# 1.692060e+12      20
# 1.691680e+12      20
# 1.692280e+12      18
# 1.690930e+12      17
# 1.699090e+12      16
# 1.690590e+12      16
# 1.699010e+12      15
# 1.696920e+12      15
# 1.692320e+12      13
# 1.698620e+12      13
# 1.696980e+12      12
# 1.690680e+12      12
# 1.691190e+12      12
# 1.690850e+12      12
# 1.691790e+12      11
# 1.698750e+12      11
# 1.696810e+12      11
# 1.691630e+12      11
# 1.690480e+12      11
# 1.697670e+12      10
# 1.698710e+12      10
# 1.692630e+12       9
# 1.697590e+12       9
# 1.691610e+12       9
# 1.698190e+12       8
# 1.691970e+12       8
# 1.697070e+12       8
# 1.692650e+12       8
# 1.697130e+12       8
# 1.698110e+12       8
# 1.691720e+12       8
# 1.697580e+12       8
# 1.697660e+12       8
# 1.698700e+12       7
# 1.698100e+12       7
# 1.697060e+12       7
# 1.691180e+12       7
# 1.691020e+12       7
# 1.697840e+12       7
# 1.691600e+12       7
# 1.691440e+12       7
# 1.691670e+12       6
# 1.692670e+12       6
# 1.697750e+12       6
# 1.698870e+12       6
# 1.698020e+12       6
# 1.690840e+12       6
# 1.697490e+12       6
# 1.696930e+12       6
# 1.690700e+12       6
# 1.697500e+12       6
# 1.697230e+12       6
# 1.698680e+12       6
# 1.692380e+12       5
# 1.691530e+12       5
# 1.692120e+12       5
# 1.692400e+12       5
# 1.697600e+12       5
# 1.698360e+12       5
# 1.697240e+12       5
# 1.690970e+12       5
# 1.691010e+12       4
# 1.698240e+12       4
# 1.698920e+12       4
# 1.697760e+12       4
# 1.698830e+12       4
# 1.690980e+12       4
# 1.690860e+12       4
# 1.696990e+12       4
# 1.698300e+12       4
# 1.697520e+12       4
# 1.696860e+12       4
# 1.696960e+12       4
# 1.697300e+12       4
# 1.696970e+12       4
# 1.691370e+12       4
# 1.698320e+12       3
# 1.698730e+12       3
# 1.698930e+12       3
# 1.698980e+12       3
# 1.698280e+12       3
# 1.697850e+12       3
# 1.698160e+12       3
# 1.698270e+12       3
# 1.692250e+12       3
# 1.692710e+12       3
# 1.698420e+12       3
# 1.698080e+12       3
# 1.697040e+12       3
# 1.698850e+12       3
# 1.691980e+12       3
# 1.691100e+12       3
# 1.691780e+12       3
# 1.690950e+12       3
# 1.698180e+12       3
# 1.698370e+12       3
# 1.690760e+12       3
# 1.691540e+12       3
# 1.697140e+12       3
# 1.698440e+12       3
# 1.692040e+12       3
# 1.691470e+12       3
# 1.697860e+12       3
# 1.698450e+12       3
# 1.697710e+12       3
# 1.698720e+12       3
# 1.698120e+12       3
# 1.697160e+12       3
# 1.691800e+12       2
# 1.692110e+12       2
# 1.692810e+12       2
# 1.691080e+12       2
# 1.692760e+12       2
# 1.697640e+12       2
# 1.698690e+12       2
# 1.691110e+12       2
# 1.698660e+12       2
# 1.697690e+12       2
# 1.691620e+12       2
# 1.692550e+12       2
# 1.697210e+12       2
# 1.697250e+12       2
# 1.698250e+12       2
# 1.698090e+12       2
# 1.692700e+12       2
# 1.692220e+12       2
# 1.698330e+12       2
# 1.698630e+12       2
# 1.698290e+12       2
# 1.690560e+12       2
# 1.692070e+12       2
# 1.690960e+12       2
# 1.697000e+12       2
# 1.697650e+12       2
# 1.697880e+12       2
# 1.697110e+12       2
# 1.690990e+12       2
# 1.692420e+12       2
# 1.692330e+12       2
# 1.695680e+12       2
# 1.714600e+12     250
# 1.708280e+12     215
# 1.708390e+12     174
# 1.695280e+12     169
# 1.695460e+12     156
# 1.714610e+12     122
# 1.708380e+12     114
# 1.695270e+12     111
# 1.708300e+12     108
# 1.701680e+12      87
# 1.695350e+12      86
# 1.695400e+12      85
# 1.695360e+12      83
# 1.695410e+12      67
# 1.695240e+12      60
# 1.701540e+12      54
# 1.701620e+12      52
# 1.708400e+12      49
# 1.701690e+12      48
# 1.714330e+12      48
# 1.701550e+12      47
# 1.714340e+12      44
# 1.714520e+12      42
# 1.695390e+12      40
# 1.697920e+12      38
# 1.708410e+12      37
# 1.701580e+12      35
# 1.714630e+12      33
# 1.700250e+12      33
# 1.707250e+12      32
# 1.701380e+12      30
# 1.714320e+12      29
# 1.707240e+12      27
# 1.714620e+12      26
# 1.714310e+12      23
# 1.704230e+12      20
# 1.701370e+12      20
# 1.708190e+12      20
# 1.701710e+12      18
# 1.707230e+12      17
# 1.701610e+12      17
# 1.714570e+12      17
# 1.708270e+12      16
# 1.708210e+12      15
# 1.695380e+12      15
# 1.701360e+12      14
# 1.695370e+12      13
# 1.700260e+12      12
# 1.708200e+12      11
# 1.708420e+12      11
# 1.695510e+12      11
# 1.701600e+12       9
# 1.694290e+12       9
# 1.701390e+12       9
# 1.701350e+12       9
# 1.700180e+12       8
# 1.708350e+12       8
# 1.708180e+12       8
# 1.700510e+12       8
# 1.701730e+12       8
# 1.708360e+12       7
# 1.708220e+12       7
# 1.714350e+12       7
# 1.708320e+12       6
# 1.697930e+12       6
# 1.707260e+12       6
# 1.708370e+12       6
# 1.694300e+12       6
# 1.697910e+12       6
# 1.714300e+12       5
# 1.701720e+12       5
# 1.714640e+12       5
# 1.698020e+12       5
# 1.708240e+12       4
# 1.694280e+12       4
# 1.707220e+12       3
# 1.695310e+12       3
# 1.698030e+12       3
# 1.698050e+12       3
# 1.701700e+12       3
# 1.698010e+12       3
# 1.706830e+12       3
# 1.703100e+12       3
# 1.703960e+12       3
# 1.704220e+12       3
# 1.704240e+12       2
# 1.697940e+12       2
# 1.694390e+12       2
# 1.714560e+12       2
# 1.701530e+12       2
# 1.706740e+12       2
# 1.704150e+12       2
# 1.706810e+12       2
# 1.714580e+12       2
# 1.700500e+12       2
# 1.705690e+12       2
# 1.707840e+12       2
# 1.695250e+12       2
# 1.704270e+12       1
# 1.707600e+12       1
# 1.707580e+12       1
# 1.707570e+12       1
# 1.707330e+12       1
# 1.707770e+12       1
# 1.694270e+12       1
# 1.707760e+12       1
# 1.707560e+12       1
# 1.695300e+12       1
# 1.695260e+12       1
# 1.701570e+12       1
# 1.714530e+12       1
# 1.714510e+12       1
# 1.714680e+12       1
# 1.699050e+12       1
# 1.706820e+12       1
# 1.699080e+12       1
# 1.700860e+12       1
# 1.714490e+12       1
# 1.701340e+12       1
# 1.701320e+12       1
# 1.714500e+12       1
# 1.714410e+12       1
# 1.698040e+12       1
# 1.700600e+12       1
# 1.705710e+12       1
# 1.707670e+12       1
# 1.714420e+12       1
# 1.700170e+12       1
# 1.705700e+12       1
# 1.703110e+12       1
# 1.714400e+12       1
# 1.703120e+12       1
# 1.700520e+12       1
# 1.708310e+12       1
# 1.708340e+12       1
# 1.708230e+12       1
# Name: count, dtype: int64

# %%
# Check the unique values of 'closed_time' column
raw_df['closed_time'].value_counts()
# Out:
# closed_time
# 1.690000e+12    928
# 1.700000e+12    244
# Name: count, dtype: int64

# %%
# Check the unique values of 'listed_time' column
raw_df['listed_time'].value_counts()
# Out:
# listed_time
# 1.699050e+12    6910
# 1.699040e+12    5465
# 1.692740e+12    4550
# 1.692730e+12    3189
# 1.692830e+12    2561
# 1.692850e+12    1389
# 1.699070e+12    1328
# 1.692750e+12    1216
# 1.699060e+12    1138
# 1.692840e+12     947
# 1.698960e+12     795
# 1.692820e+12     686
# 1.699080e+12     643
# 1.698970e+12     464
# 1.692860e+12     300
# 1.692680e+12     286
# 1.692760e+12     123
# 1.692870e+12     121
# 1.692810e+12      99
# 1.692640e+12      86
# 1.699030e+12      81
# 1.699090e+12      74
# 1.698780e+12      73
# 1.698790e+12      69
# 1.692800e+12      68
# 1.698770e+12      48
# 1.698950e+12      47
# 1.692770e+12      40
# 1.691700e+12      39
# 1.691690e+12      38
# 1.698760e+12      37
# 1.699100e+12      37
# 1.699020e+12      35
# 1.698990e+12      29
# 1.692720e+12      28
# 1.692790e+12      25
# 1.692660e+12      20
# 1.691680e+12      19
# 1.699010e+12      16
# 1.699120e+12      16
# 1.692780e+12      15
# 1.698940e+12      14
# 1.692630e+12       8
# 1.699130e+12       7
# 1.698750e+12       7
# 1.698800e+12       7
# 1.699110e+12       7
# 1.692670e+12       5
# 1.691710e+12       5
# 1.692650e+12       5
# 1.698980e+12       4
# 1.691670e+12       4
# 1.699140e+12       3
# 1.692210e+12       2
# 1.692290e+12       2
# 1.691760e+12       2
# 1.698850e+12       2
# 1.692710e+12       2
# 1.691770e+12       1
# 1.692030e+12       1
# 1.698870e+12       1
# 1.698730e+12       1
# 1.692040e+12       1
# 1.698860e+12       1
# 1.692020e+12       1
# 1.699000e+12       1
# 1.692120e+12       1
# 1.692000e+12       1
# Name: count, dtype: int64

# %% [markdown]
# After checking the unique values from each of the time variable, we can spot a pattern where the time values are listed in a scientific timestamp format (i.e. 1.692000e+12). Hence, we will convert this to a standard datetime format (Source: https://www.scaler.com/topics/python-timestamp-to-datetime/).

# %% [markdown]
# #### Original_Listed_Time

# %%
# Convert scientific notation to standard notation (float)
raw_df['original_listed_time']=raw_df['original_listed_time'].astype('float64')

# %%
# Convert milliseconds to seconds 
raw_df['original_listed_time']=raw_df['original_listed_time']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
raw_df['original_listed_time'] = raw_df['original_listed_time'].apply(lambda x: datetime.fromtimestamp(x))
raw_df['original_listed_time']
# Out:
# 0       2023-11-04 05:26:40
# 1       2023-11-04 02:40:00
# 2       2023-11-04 02:40:00
# 3       2023-11-04 02:40:00
# 4       2023-11-02 20:06:40
#                 ...
# 33241   2023-08-23 18:33:20
# 33242   2023-11-03 15:33:20
# 33243   2023-11-03 18:20:00
# 33244   2023-08-22 20:20:00
# 33245   2023-11-03 18:20:00
# Name: original_listed_time, Length: 33246, dtype: datetime64[ns]

# %%
# Sanity Check
raw_df.head()
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
#    min_salary pay_period formatted_work_type          location  applies  \
# 0         NaN    MONTHLY           Full-time  Little River, SC      NaN
# 1         NaN        NaN           Full-time    Beaver Dam, WI      NaN
# 2         NaN        NaN           Full-time      Bessemer, AL      NaN
# 3         NaN     HOURLY           Full-time   Aliso Viejo, CA      NaN
# 4    205956.0     YEARLY           Full-time     United States      NaN
#
#   original_listed_time  remote_allowed  views  \
# 0  2023-11-04 05:26:40             NaN    9.0
# 1  2023-11-04 02:40:00             NaN    NaN
# 2  2023-11-04 02:40:00             NaN    NaN
# 3  2023-11-04 02:40:00             NaN    1.0
# 4  2023-11-02 20:06:40             1.0    NaN
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
# 4  https://www.linkedin.com/jobs/view/3757937095/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#          expiry  closed_time formatted_experience_level  \
# 0  1.701680e+12          NaN                Entry level
# 1  1.701680e+12          NaN                        NaN
# 2  1.701680e+12          NaN                        NaN
# 3  1.701680e+12          NaN                Entry level
# 4  1.701680e+12          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
# 4                                                NaN  1.699090e+12
#
#              posting_domain  sponsored  work_type currency compensation_type  \
# 0  careers-demant.icims.com          0  FULL_TIME      USD       BASE_SALARY
# 1       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 2       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 3           jobs.apploi.com          0  FULL_TIME      USD       BASE_SALARY
# 4         careers.iherb.com          0  FULL_TIME      USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346

# %% [markdown]
# From above, we can observe that the data entries from `original_listed_time` have been transformed into datetime format. We will repeat this process for the remaining three columns.

# %% [markdown]
# #### Expiry

# %%
# Convert scientific notation to standard notation (float)
raw_df['expiry']=raw_df['expiry'].astype('float64')

# %%
# Convert milliseconds to seconds 
raw_df['expiry']=raw_df['expiry']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
raw_df['expiry'] = raw_df['expiry'].apply(lambda x: datetime.fromtimestamp(x))
raw_df['expiry']
# Out:
# 0       2023-12-04 03:53:20
# 1       2023-12-04 03:53:20
# 2       2023-12-04 03:53:20
# 3       2023-12-04 03:53:20
# 4       2023-12-04 03:53:20
#                 ...
# 33241   2023-09-22 20:46:40
# 33242   2023-12-03 14:00:00
# 33243   2023-12-03 16:46:40
# 33244   2024-02-18 18:46:40
# 33245   2024-05-01 17:46:40
# Name: expiry, Length: 33246, dtype: datetime64[ns]

# %%
# Sanity Check
raw_df.head()
# Out:
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
# 4  3757937095    437225.0        Principal Cloud Security Architect (Remote)
#
#                                          description  max_salary  med_salary  \
# 0  Overview\n\nHearingLife is a national hearing ...         NaN     5250.00
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...         NaN         NaN
# 2  \nThe TSUBAKI name is synonymous with excellen...         NaN         NaN
# 3  descriptionTitle\n\n Looking for a great oppor...         NaN       22.27
# 4  Job Summary\nAt iHerb, we are on a mission to ...    275834.0         NaN
#
#    min_salary pay_period formatted_work_type          location  applies  \
# 0         NaN    MONTHLY           Full-time  Little River, SC      NaN
# 1         NaN        NaN           Full-time    Beaver Dam, WI      NaN
# 2         NaN        NaN           Full-time      Bessemer, AL      NaN
# 3         NaN     HOURLY           Full-time   Aliso Viejo, CA      NaN
# 4    205956.0     YEARLY           Full-time     United States      NaN
#
#   original_listed_time  remote_allowed  views  \
# 0  2023-11-04 05:26:40             NaN    9.0
# 1  2023-11-04 02:40:00             NaN    NaN
# 2  2023-11-04 02:40:00             NaN    NaN
# 3  2023-11-04 02:40:00             NaN    1.0
# 4  2023-11-02 20:06:40             1.0    NaN
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
# 4  https://www.linkedin.com/jobs/view/3757937095/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
# 4  https://careers.iherb.com/global/en/job/IHINGL...     OffsiteApply
#
#                expiry  closed_time formatted_experience_level  \
# 0 2023-12-04 03:53:20          NaN                Entry level
# 1 2023-12-04 03:53:20          NaN                        NaN
# 2 2023-12-04 03:53:20          NaN                        NaN
# 3 2023-12-04 03:53:20          NaN                Entry level
# 4 2023-12-04 03:53:20          NaN           Mid-Senior level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
# 4                                                NaN  1.699090e+12
#
#              posting_domain  sponsored  work_type currency compensation_type  \
# 0  careers-demant.icims.com          0  FULL_TIME      USD       BASE_SALARY
# 1       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 2       www.click2apply.net          0  FULL_TIME      NaN               NaN
# 3           jobs.apploi.com          0  FULL_TIME      USD       BASE_SALARY
# 4         careers.iherb.com          0  FULL_TIME      USD       BASE_SALARY
#
#       scraped
# 0  1699138101
# 1  1699085420
# 2  1699085644
# 3  1699087461
# 4  1699085346

# %% [markdown]
# #### Closed_Time

# %%
# Convert scientific notation to standard notation (float)
raw_df['closed_time']=raw_df['closed_time'].astype('float64')

# %%
# Convert milliseconds to seconds 
raw_df['closed_time']=raw_df['closed_time']/1000

# %% [markdown]
# Since there are NaN (missing) values in `closed_time` column, we first have to filter these null values to apply datetime function.

# %%
# Filter out NaN values
not_null_ct = raw_df['closed_time'].notnull()
raw_df.loc[not_null_ct, 'closed_time'] = raw_df.loc[not_null_ct, 'closed_time'].apply(lambda x: datetime.fromtimestamp(x))

# Print the updated DataFrame
print(raw_df['closed_time'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 33241    NaN
# 33242    NaN
# 33243    NaN
# 33244    NaN
# 33245    NaN
# Name: closed_time, Length: 33246, dtype: object
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_46404/971382252.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<DatetimeArray>
# ['2023-11-14 17:13:20', '2023-11-14 17:13:20', '2023-11-14 17:13:20',
#  '2023-11-14 17:13:20', '2023-11-14 17:13:20', '2023-11-14 17:13:20',
#  '2023-11-14 17:13:20', '2023-11-14 17:13:20', '2023-11-14 17:13:20',
#  '2023-11-14 17:13:20',
#  ...
#  '2023-07-22 00:26:40', '2023-07-22 00:26:40', '2023-07-22 00:26:40',
#  '2023-07-22 00:26:40', '2023-07-22 00:26:40', '2023-07-22 00:26:40',
#  '2023-07-22 00:26:40', '2023-07-22 00:26:40', '2023-07-22 00:26:40',
#  '2023-07-22 00:26:40']
# Length: 1172, dtype: datetime64[ns]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   raw_df.loc[not_null_ct, 'closed_time'] = raw_df.loc[not_null_ct, 'closed_time'].apply(lambda x: datetime.fromtimestamp(x))

# %%
raw_df.sample(50)
# Out:
#            job_id  company_id  \
# 30973  3693051492   9901130.0
# 23004  3699059188      3264.0
# 22663  3699079632   1104193.0
# 17583  3701369569     10667.0
# 31764  3693048063     20489.0
# 30335  3693057090    861806.0
# 706    3757798169      2646.0
# 10895  3755597062      3532.0
# 10182  3756109953  10122698.0
# 30266  3693058211   9328925.0
# 32839  3693036850  96360915.0
# 3064   3757721323   4854165.0
# 13294  3755552601  40934666.0
# 4749   3757489154      2622.0
# 13954  3753086711   2548094.0
# 30941  3693051619     30086.0
# 25970  3694138574   1110268.0
# 16792  3749339882    204715.0
# 16481  3749345617  11170816.0
# 508    3757910822  80862575.0
# 21274  3699413328  27249903.0
# 15509  3749352178  13323120.0
# 9978   3756112015      9479.0
# 24866  3697376675     49042.0
# 15497  3749352224   2619961.0
# 29820  3693066785  74971597.0
# 31721  3693048258   9185109.0
# 14667  3749372743  18506580.0
# 170    3757920617  54350022.0
# 14506  3749376018      8710.0
# 17365  3701372792    163578.0
# 23139  3699056999     34638.0
# 12287  3755582914   1623211.0
# 8376   3756900836     30225.0
# 11020  3755595322    165697.0
# 33007  3690830913  29037477.0
# 23264  3699054769     77301.0
# 14206  3749902530  28132450.0
# 30537  3693054367   3757480.0
# 7557   3757444982   2074994.0
# 12856  3755576221     47040.0
# 15419  3749352919      7795.0
# 32841  3693035554  96654985.0
# 657    3757902925    162677.0
# 21350  3699411594  15451728.0
# 23554  3697396174      3240.0
# 19356  3701310242  79017472.0
# 23617  3697395040      6215.0
# 16309  3749346482     11056.0
# 12732  3755577974  18312164.0
#
#                                                    title  \
# 30973                                   Business Analyst
# 23004                Claims Adjuster Senior - Litigation
# 22663                   Operations Student Intern (9025)
# 17583           Marketing Insights Researcher - Business
# 31764                              CRM Marketing Analyst
# 30335                                             Busser
# 706    (USA) Pharmacy Manager-$40,000 Sign On Bonus A...
# 10895                          Financial Advisor - Omaha
# 10182                                      Groundskeeper
# 30266  Head of Product Management & Marketing - Fixed...
# 32839                      Developer Internship [unpaid]
# 3064                                 Technical Architect
# 13294                           Sales Operations Manager
# 4749                                    Business Manager
# 13954                                Pharmacy Technician
# 30941               Principal Escalation Engineer (NGFW)
# 25970                                          Architect
# 16792                           Sr. Full-Stack Engineer
# 16481        Information Technology - Systems Analyst II
# 508                   Radiologic Technologist Contingent
# 21274                                Chief of Staff, CRO
# 15509               Director, Human Resources Operations
# 9978                            Trust Investment Officer
# 24866                                      Waiter/Server
# 15497     Industrial Production Manager (Group Director)
# 29820                                   Assistant Editor
# 31721                    Electrical Engineering Manager
# 14667  Travel Nurse RN - CVICU - $2,016 per week - a0...
# 170              Full Stack Developer - API Integrations
# 14506  Enhanced Claim Resolution Operations, Senior A...
# 17365                             Assoc Material Handler
# 23139                           Plumbing Design Engineer
# 12287                                 Proprietary Trader
# 8376    Sr. Analyst - Treasury - Aramco Trading Americas
# 11020            0046 - Concord CA - Sr Sales Specialist
# 33007                                 Payroll Specialist
# 23264                         Customer Service Associate
# 14206                          Unit Secretary Geri Psych
# 30537                                   Staff Accountant
# 7557             Account Executive - Mechanical Division
# 12856                            Supply Chain Specialist
# 15419                               Veterinary Assistant
# 32841                                 Associate Attorney
# 657           Associate Technician Production Operations
# 21350               Part Time Customer Service Associate
# 23554  Customer Service Representative-Farmers Direct...
# 19356                Business Development Representative
# 23617                        Accounts Payable Supervisor
# 16309  Advanced Manufacturing and Sustainability Proj...
# 12732                             SDR/Appointment-Setter
#
#                                              description  max_salary  \
# 30973  Job SummaryThe Business Analyst is a crucial r...         NaN
# 23004  As a senior claims specialist on our team, you...    80000.00
# 22663  Work for Our Water Resources.\nHelp protect on...         NaN
# 17583  The Global Business and Product Marketing orga...   182000.00
# 31764  POSITION SUMMARY STATEMENT  The CRM Marketing ...         NaN
# 30335  Job Description\n JOIN A WINNING TEAM! \n BUSS...         NaN
# 706    Position Summary...\n\nWhat you'll do...\n\nTh...         NaN
# 10895  At FNBO, our employees are the heart of our st...         NaN
# 10182  Our Company: \n\nQuarterra Group, Inc., a whol...         NaN
# 30266  Client is the 2nd largest broadband and mobile...         NaN
# 32839  About Company:Early Transition in Tech Associa...         NaN
# 3064   Job Title: Technical ArchitectLocation: UtahJo...         NaN
# 13294  About the JobAbout UsWe are a company dedicate...   140000.00
# 4749   Career Area\n\nAll Job Families\n\nJob Descrip...         NaN
# 13954  Description\n\nIntroduction\n\nDo you want to ...         NaN
# 30941  Your CareerThis is a highly visible, senior le...         NaN
# 25970  For the role of Architect, we are looking for ...         NaN
# 16792  In this role, you'll lead the development of w...         NaN
# 16481  12-14 months contract ;100% remote \nQUALIFICA...       35.00
# 508    Employment Type:\n\nPart time\n\nShift:\n\nRot...         NaN
# 21274  About Attentive: \nAttentive® is the leader in...   200000.00
# 15509  Who We AreAt OKX, we believe the future will b...   254000.00
# 9978   Job Description\n\nHow will your role impact F...         NaN
# 24866  Work With Purpose\nAt Five Star Senior Living,...         NaN
# 15497  LinkedIn does not support Internet Explorer 11...   177978.00
# 29820  We are looking for a passionate team member wh...         NaN
# 31721  Our Client, an Innovative Company, has spent t...   150000.00
# 14667  MedPro Healthcare Staffing is seeking a travel...         NaN
# 170    Full Stack Developer - API IntegrationsJob Des...         NaN
# 14506  Join us as we work to create a thriving ecosys...         NaN
# 17365  Supports specified Warehouse and/or Distributi...         NaN
# 23139  Ballinger is an integrated design-led practice...         NaN
# 12287  Job Title: Proprietary Trader\n\nLocation: New...         NaN
# 8376   Position Overview\n\nAramco Trading Americas (...         NaN
# 11020  Overview\n\nREI Co-op is united around discove...       28.08
# 33007  Payroll Specialist\nCAL’s Convenience, Inc. op...         NaN
# 23264  Starting hiring pay range (based on location, ...       16.50
# 14206  Overview\n\nJoin an award-winning team of dedi...         NaN
# 30537  Aduro Advisors is looking for bright and talen...    65000.00
# 7557   SOUTH COAST FACILITY SERVICES is a full-servic...         NaN
# 12856  Network Supply Planner\nAre you an innovative ...         NaN
# 15419  Create a healthier, brighter future for pets, ...         NaN
# 32841  We are a boutique Real Estate law firm in the ...   160000.00
# 657    2nd Shift 2PM - 10:30PM\n\nIn this role, you w...         NaN
# 21350  Job Details\nJob Location\nKSAND_Andover - And...         NaN
# 23554  We are Farmers!\nWe are… more than just your f...       19.50
# 19356  The Sales Scout is working with a client with ...    80000.00
# 23617  We are currently hiring for an Accounts Payabl...         NaN
# 16309  *US Citizenship with the willingness and abili...       65.00
# 12732  (Side-Gig) SDR/Appointment-SetterUnited States...    50000.00
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 30973         NaN         NaN        NaN           Full-time
# 23004         NaN    70000.00     YEARLY           Full-time
# 22663       14.74         NaN     HOURLY           Part-time
# 17583         NaN   133000.00     YEARLY           Full-time
# 31764         NaN         NaN        NaN           Full-time
# 30335         NaN         NaN        NaN           Full-time
# 706           NaN         NaN        NaN           Full-time
# 10895         NaN         NaN        NaN           Full-time
# 10182       18.00         NaN     HOURLY           Full-time
# 30266         NaN         NaN        NaN           Full-time
# 32839         NaN         NaN        NaN          Internship
# 3064    125000.00         NaN     YEARLY            Contract
# 13294         NaN   120000.00     YEARLY           Full-time
# 4749          NaN         NaN        NaN           Full-time
# 13954         NaN         NaN        NaN           Full-time
# 30941         NaN         NaN        NaN           Full-time
# 25970         NaN         NaN        NaN           Full-time
# 16792         NaN         NaN        NaN           Full-time
# 16481         NaN       30.00     HOURLY            Contract
# 508           NaN         NaN        NaN           Part-time
# 21274         NaN   154000.00     YEARLY           Full-time
# 15509         NaN   174000.00     YEARLY           Full-time
# 9978          NaN         NaN        NaN           Full-time
# 24866         NaN         NaN        NaN           Full-time
# 15497         NaN   116393.00     YEARLY           Full-time
# 29820         NaN         NaN        NaN           Part-time
# 31721         NaN   130000.00     YEARLY           Full-time
# 14667         NaN         NaN        NaN           Full-time
# 170           NaN         NaN        NaN           Full-time
# 14506         NaN         NaN        NaN           Full-time
# 17365         NaN         NaN        NaN           Full-time
# 23139         NaN         NaN        NaN           Full-time
# 12287         NaN         NaN        NaN           Full-time
# 8376          NaN         NaN        NaN           Full-time
# 16481         NaN  1.699040e+12                                 NaN
# 508           NaN  1.699080e+12             jobs.trinity-health.org
# 21274         NaN  1.692850e+12                       jobs.lever.co
# 15509         NaN  1.699040e+12                                 NaN
# 9978          NaN  1.699050e+12           firstcommand.silkroad.com
# 24866         NaN  1.692740e+12    careers.fivestarseniorliving.com
# 15497         NaN  1.699040e+12                                 NaN
# 29820         NaN  1.692740e+12                                 NaN
# 31721         NaN  1.692730e+12                                 NaN
# 14667         NaN  1.699090e+12                    click.appcast.io
# 170           NaN  1.699080e+12                                 NaN
# 14506         NaN  1.699050e+12  athenahealth.wd1.myworkdayjobs.com
# 17365         NaN  1.692740e+12       edwards.wd5.myworkdayjobs.com
# 23139         NaN  1.692830e+12                                 NaN
# 12287         NaN  1.699040e+12                       t3trading.com
# 8376          NaN  1.698960e+12        motiva.wd1.myworkdayjobs.com
# 11020         NaN  1.699050e+12                        www.rei.jobs
# 33007         NaN  1.691690e+12                                 NaN
# 23264         NaN  1.692820e+12          raisingcanes.jibeapply.com
# 14206         NaN  1.699070e+12   careers-primehealthcare.icims.com
# 30537         NaN  1.692740e+12                                 NaN
# 7557          NaN  1.699040e+12                                 NaN
# 12856         NaN  1.699040e+12                                 NaN
# 15419         NaN  1.699050e+12                   careers.petco.com
# 32841         NaN  1.692730e+12                                 NaN
# 657           NaN  1.699080e+12                    jobs.danaher.com
# 21350         NaN  1.692850e+12                www.paycomonline.net
# 23554         NaN  1.692750e+12           jobs.farmersinsurance.com
# 19356         NaN  1.692730e+12                                 NaN
# 23617         NaN  1.692750e+12        uscareers-fujifilm.icims.com
# 16309         NaN  1.699040e+12                                 NaN
# 12732         NaN  1.699040e+12                                 NaN
#
#        sponsored   work_type currency compensation_type     scraped
# 30973          0   FULL_TIME      NaN               NaN           1
# 23004          0   FULL_TIME      USD       BASE_SALARY           1
# 22663          1   PART_TIME      USD       BASE_SALARY           1
# 17583          0   FULL_TIME      USD       BASE_SALARY           1
# 31764          0   FULL_TIME      NaN               NaN           1
# 30335          0   FULL_TIME      NaN               NaN           1
# 706            0   FULL_TIME      NaN               NaN  1699137951
# 10895          0   FULL_TIME      NaN               NaN  1699090595
# 10182          1   FULL_TIME      USD       BASE_SALARY  1699063790
# 30266          0   FULL_TIME      NaN               NaN           1
# 32839          0  INTERNSHIP      NaN               NaN           1
# 3064           0    CONTRACT      USD       BASE_SALARY  1699082675
# 13294          1   FULL_TIME      USD       BASE_SALARY  1699060313
# 4749           0   FULL_TIME      NaN               NaN  1699135011
# 13954          0   FULL_TIME      NaN               NaN  1698964859
# 30941          1   FULL_TIME      NaN               NaN           1
# 25970          0   FULL_TIME      NaN               NaN           1
# 16792          1   FULL_TIME      NaN               NaN  1699036771
# 16481          0    CONTRACT      USD       BASE_SALARY  1699039814
# 508            0   PART_TIME      NaN               NaN  1699085420
# 21274          0   FULL_TIME      USD       BASE_SALARY           1
# 15509          0   FULL_TIME      USD       BASE_SALARY  1699041203
# 9978           0   FULL_TIME      NaN               NaN  1699055117
# 24866          1   FULL_TIME      NaN               NaN           1
# 15497          0   FULL_TIME      USD       BASE_SALARY  1699041496
# 29820          0   PART_TIME      NaN               NaN           1
# 31721          1   FULL_TIME      USD       BASE_SALARY           1
# 14667          0   FULL_TIME      NaN               NaN  1699133129
# 170            0   FULL_TIME      NaN               NaN  1699080309
# 14506          0   FULL_TIME      NaN               NaN  1699137201
# 17365          1   FULL_TIME      NaN               NaN           1
# 23139          0   FULL_TIME      NaN               NaN           1
# 12287          0   FULL_TIME      NaN               NaN  1699135547
# 8376           0   FULL_TIME      NaN               NaN  1699039150
# 11020          0   FULL_TIME      USD       BASE_SALARY  1699136825
# 33007          1   FULL_TIME      NaN               NaN           1
# 23264          0   PART_TIME      USD       BASE_SALARY           1
# 14206          0   FULL_TIME      NaN               NaN  1699136299
# 30537          1   FULL_TIME      USD       BASE_SALARY           1
# 7557           1   FULL_TIME      NaN               NaN  1699038782
# 12856          0    CONTRACT      NaN               NaN  1699051839
# 15419          0   FULL_TIME      NaN               NaN  1699136299
# 32841          1   FULL_TIME      USD       BASE_SALARY           1
# 657            0   FULL_TIME      NaN               NaN  1699138101
# 21350          0   PART_TIME      NaN               NaN           1
# 23554          1   FULL_TIME      USD       BASE_SALARY           1
# 19356          1   FULL_TIME      USD       BASE_SALARY           1
# 23617          0   FULL_TIME      NaN               NaN           1
# 16309          0   FULL_TIME      USD       BASE_SALARY  1699072845
# 12732          0   PART_TIME      USD       BASE_SALARY  1699138251

# %% [markdown]
# Through filtering the NaN values and applying the datetime function, the data entries are now in the proper datetime format.

# %% [markdown]
# #### Listed_Time

# %%
# Convert scientific notation to standard notation (float)
raw_df['listed_time']=raw_df['listed_time'].astype('float64')

# %%
# Convert milliseconds to seconds 
raw_df['listed_time']=raw_df['listed_time']/1000

# %%
# Convert timestamp into datetime 
from datetime import datetime
raw_df['listed_time'] = raw_df['listed_time'].apply(lambda x: datetime.fromtimestamp(x))
raw_df['listed_time']
# Out:
# 0       2023-11-04 05:26:40
# 1       2023-11-04 02:40:00
# 2       2023-11-04 02:40:00
# 3       2023-11-04 02:40:00
# 4       2023-11-04 05:26:40
#                 ...
# 33241   2023-08-23 18:33:20
# 33242   2023-11-03 15:33:20
# 33243   2023-11-03 18:20:00
# 33244   2023-08-22 20:20:00
# 33245   2023-11-03 18:20:00
# Name: listed_time, Length: 33246, dtype: datetime64[ns]

# %%
raw_df.sample(50)
# Out:
#            job_id  company_id  \
# 9122   3756143936  18860134.0
# 20118  3701198915     43876.0
# 1537   3757744197    120393.0
# 30505  3693055044   2058906.0
# 22000  3699087776         NaN
# 21164  3699417040      5927.0
# 32031  3693046819   8047188.0
# 30151  3693062969     11056.0
# 10374  3756107906     13074.0
# 788    3757781464  28647688.0
# 6038   3757468607  42747663.0
# 11666  3755589149  89877420.0
# 18546  3701320187     13151.0
# 27269  3694101479     34616.0
# 2368   3757733442     13499.0
# 6596   3757461246  33439815.0
# 22340  3699083526      2649.0
# 28291  3693586358         NaN
# 2583   3757731065  68648187.0
# 6669   3757460751      7601.0
# 4380   3757491960     18043.0
# 9122   Want to learn more about this role and Jobot? ...   120000.00
# 20118  WHO WE ARE: It’s an exciting time to be joinin...         NaN
# 1537   The Business Solutions Group provides entrepre...         NaN
# 30505  About WhatfixWhatfix empowers anyone, anywhere...         NaN
# 22000  The ideal candidate will be disciplined and ha...         NaN
# 21164  Nuestras instalaciones de fabricación de bomba...         NaN
# 32031  Job Title: ServiceNow Solutions ArchitectDurat...         NaN
# 30151  A mid-sized telecom company is looking for a S...   141440.00
# 10374  You Belong Here.\n\nAt MultiCare, we strive to...       35.58
# 788    Call 214-949-4428 to get connected to a recrui...         NaN
# 6038   Overview ‪CAB Enterprises, Inc., is the exclus...         NaN
# 11666  Overview\n\nWorking across the globe, V2X buil...         NaN
# 18546  Around the world, people, businesses, and coun...         NaN
# 27269  Job Title: Lead Data EngineerLocation: RemoteT...         NaN
# 2368   Are you an experienced Finance Manager who enj...         NaN
# 6596   At Foundation Academies, we promise to equip o...         NaN
# 22340  Academic Advisor\nHiring Department: UIC, Math...         NaN
# 28291  Job Posting: Facilities and Equipment Maintena...         NaN
# 2583   About Pacaso\n\nPacaso exists to enrich lives ...   170000.00
# 6669   Primary Function:Primary Function: This role w...         NaN
# 4380   BILINGUAL RECRUITER- Forest Park, IL - Full ti...       27.00
# 30602  5 years of Middleware experience, particularly...         NaN
# 9260   Description\n\nCOME WORK FOR A ROCK SOLID TEAM...       29.00
# 16839  Job Title: R&D Systems EngineerLocation: Haver...   145000.00
# 20068  Job Description: Business Development Manager ...         NaN
# 4833   Registered Nurse - RN - Skilled Nursing Facili...         NaN
# 21415  The incumbent is responsible for managing surv...         NaN
# 7349   Development Director | Utility Scale Wind, Sol...   185000.00
# 10707  Description\n\nLogistics Specialist\n\nLocatio...         NaN
# 21600  Position Summary\nAs one of our highly skilled...         NaN
# 958    Why Wells Fargo\n\nAre you ready for the next ...       59.76
# 25511  Typically manages a small team of 3 to 5 assoc...   111250.00
# 13861  Want to learn more about this role and Jobot? ...   120000.00
# 461    Company:\n\nCogent Communications is a global,...         NaN
# 9802   Are you an Industrial Designer specialized in ...       60.00
# 22636  Allied Health --> Radiology\nPatchogue, NY\nID...         NaN
# 5237   Registered Nurse - RN - L&D - Labor and Delive...         NaN
# 13591  Company DescriptionSame Sun of Vermont focuses...    80000.00
# 16542  LocknCharge is a fast-growing international co...         NaN
# 22457  Overview\nCrew positions are entry level oppor...         NaN
# 16549  JD275Job Title: Director Analytical and Proces...         NaN
# 19779  City Lifestyle [formerly Lifestyle Publication...         NaN
# 4413   Job Location: One Henkel Way, Rocky Hill, CT 0...         NaN
# 21917  The role will be to manage the operational day...         NaN
# 26579  At Dow, we believe in putting people first and...         NaN
# 31549  Apex Systems is looking for a IT Cloud Control...       70.00
# 27807  When you join Verizon\n\nVerizon is one of the...    56000.00
# 22284  Job Description\n\nAssistant Managers are resp...         NaN
# 6259   Protech Automotive Solutions is looking for hi...         NaN
# 11149  $45 / hour\n\nThe Correctional RN works in col...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 9122          NaN   100000.00     YEARLY           Full-time
# 20118         NaN         NaN        NaN           Full-time
# 1537     71000.00         NaN     YEARLY           Full-time
# 30505         NaN         NaN        NaN           Full-time
# 22000         NaN         NaN        NaN           Full-time
# 21164         NaN         NaN        NaN           Full-time
# 32031         NaN         NaN        NaN            Contract
# 30151         NaN   120640.00     YEARLY            Contract
# 10374         NaN       21.53     HOURLY           Full-time
# 788           NaN         NaN        NaN           Full-time
# 6038          NaN         NaN        NaN           Full-time
# 11666         NaN         NaN        NaN           Full-time
# 18546         NaN         NaN        NaN           Full-time
# 27269         NaN         NaN        NaN           Full-time
# 2368          NaN         NaN        NaN           Full-time
# 6596          NaN         NaN        NaN           Full-time
# 22340         NaN         NaN        NaN           Full-time
# 28291         NaN         NaN        NaN           Full-time
# 2583          NaN   150000.00     YEARLY           Full-time
# 6669          NaN         NaN        NaN           Full-time
# 4380          NaN       23.00     HOURLY           Full-time
# 30602         NaN         NaN        NaN            Contract
# 9260          NaN       25.00     HOURLY           Full-time
# 16839         NaN   100000.00     YEARLY           Full-time
# 20068         NaN         NaN        NaN           Full-time
# 4833        48.00         NaN     HOURLY           Full-time
# 21415         NaN         NaN        NaN           Full-time
# 7349          NaN   170000.00     YEARLY           Full-time
# 10707         NaN         NaN        NaN           Full-time
# 21600       14.85         NaN     HOURLY           Part-time
# 958           NaN       33.61     HOURLY           Full-time
# 25511         NaN    70000.00     YEARLY           Full-time
# 13861         NaN    75000.00     YEARLY           Full-time
# 461           NaN         NaN        NaN           Full-time
# 9802          NaN       50.00     HOURLY            Contract
# 22636         NaN         NaN        NaN           Full-time
# 5237        57.00         NaN     HOURLY           Full-time
# 13591         NaN    60000.00     YEARLY           Full-time
# 16542         NaN         NaN        NaN           Full-time
# 22457         NaN         NaN        NaN           Part-time
# 16549         NaN         NaN        NaN           Full-time
# 19779         NaN         NaN        NaN           Full-time
# 4413        25.00         NaN     HOURLY            Contract
# 21917         NaN         NaN        NaN           Full-time
# 26579         NaN         NaN        NaN           Full-time
# 31549         NaN       60.00     HOURLY            Contract
# 27807         NaN    43000.00     YEARLY           Full-time
# 22284         NaN         NaN        NaN           Full-time
# 6259          NaN         NaN        NaN           Part-time
# 11149       45.00         NaN     HOURLY           Full-time
#
#                                      location  applies original_listed_time  \
# 9122                           Cincinnati, OH      NaN  2023-11-03 23:53:20
# 20118                          Greenville, SC      3.0  2023-08-22 14:46:40
# 1537                         Poughkeepsie, NY      1.0  2023-11-02 20:06:40
# 30505                           Nashville, TN      3.0  2023-08-22 17:33:20
# 22000                    Greater Phoenix Area      3.0  2023-08-23 21:20:00
# 21164                           Taneytown, MD      NaN  2023-08-22 20:20:00
# 32031                           United States      NaN  2023-08-22 14:46:40
# 30151                              Boston, MA    135.0  2023-08-22 17:33:20
# 10374                              Tacoma, WA      NaN  2023-11-03 18:20:00
# 788                              Meridian, ID      NaN  2023-11-03 23:53:20
# 6038                            Cleveland, OH      6.0  2023-11-03 15:33:20
# 11666                             Liberty, NC      NaN  2023-11-02 20:06:40
# 18546                          New Iberia, LA      3.0  2023-08-22 17:33:20
# 22457         NaN 2023-08-23 18:33:20                    careers.7-eleven.com
# 16549         NaN 2023-11-03 15:33:20                                     NaN
# 19779         NaN 2023-08-22 14:46:40                                     NaN
# 4413          NaN 2023-11-03 18:20:00                                     NaN
# 21917         NaN 2023-08-23 18:33:20                      apply.workable.com
# 26579         NaN 2023-08-24 00:06:40               dow.wd1.myworkdayjobs.com
# 31549         NaN 2023-08-22 17:33:20                                     NaN
# 27807         NaN 2023-08-23 18:33:20                        www.aplitrak.com
# 22284         NaN 2023-08-24 02:53:20                jobs.smartrecruiters.com
# 6259          NaN 2023-11-03 15:33:20  calibercollision.wd1.myworkdayjobs.com
# 11149         NaN 2023-11-03 18:20:00               careers.maximstaffing.com
#
#        sponsored  work_type currency compensation_type     scraped
# 9122           0  FULL_TIME      USD       BASE_SALARY  1699088430
# 20118          1  FULL_TIME      NaN               NaN           1
# 1537           0  FULL_TIME      USD       BASE_SALARY  1699137801
# 30505          1  FULL_TIME      NaN               NaN           1
# 22000          0  FULL_TIME      NaN               NaN           1
# 21164          0  FULL_TIME      NaN               NaN           1
# 32031          0   CONTRACT      NaN               NaN           1
# 30151          1   CONTRACT      USD       BASE_SALARY           1
# 10374          0  FULL_TIME      USD       BASE_SALARY  1699086944
# 788            0  FULL_TIME      NaN               NaN  1699139078
# 6038           0  FULL_TIME      NaN               NaN  1699080532
# 11666          0  FULL_TIME      NaN               NaN  1699050804
# 18546          0  FULL_TIME      NaN               NaN           1
# 27269          0  FULL_TIME      NaN               NaN           1
# 2368           0  FULL_TIME      NaN               NaN  1699063569
# 6596           0  FULL_TIME      NaN               NaN  1699132828
# 22340          0  FULL_TIME      NaN               NaN           1
# 28291          0  FULL_TIME      NaN               NaN           1
# 2583           0  FULL_TIME      USD       BASE_SALARY  1699055413
# 6669           1  FULL_TIME      NaN               NaN  1699065055
# 4380           1  FULL_TIME      USD       BASE_SALARY  1699072698
# 30602          0   CONTRACT      NaN               NaN           1
# 9260           0  FULL_TIME      USD       BASE_SALARY  1699088281
# 16839          1  FULL_TIME      USD       BASE_SALARY  1698994363
# 20068          1  FULL_TIME      NaN               NaN           1
# 4833           0  FULL_TIME      USD       BASE_SALARY  1699050435
# 21415          0  FULL_TIME      NaN               NaN           1
# 7349           1  FULL_TIME      USD       BASE_SALARY  1699052505
# 10707          0  FULL_TIME      NaN               NaN  1699061719
# 21600          0  PART_TIME      USD       BASE_SALARY           1
# 958            1  FULL_TIME      USD       BASE_SALARY  1699087983
# 25511          1  FULL_TIME      USD       BASE_SALARY           1
# 13861          0  FULL_TIME      USD       BASE_SALARY  1698994731
# 461            0  FULL_TIME      NaN               NaN  1699131404
# 9802           0   CONTRACT      USD       BASE_SALARY  1699089250
# 22636          0  FULL_TIME      NaN               NaN           1
# 5237           1  FULL_TIME      USD       BASE_SALARY  1699064093
# 13591          1  FULL_TIME      USD       BASE_SALARY  1699133506
# 16542          1  FULL_TIME      NaN               NaN  1699037005
# 22457          0  PART_TIME      NaN               NaN           1
# 16549          1  FULL_TIME      NaN               NaN  1699036696
# 19779          0  FULL_TIME      NaN               NaN           1
# 4413           0   CONTRACT      USD       BASE_SALARY  1699081567
# 21917          1  FULL_TIME      NaN               NaN           1
# 26579          0  FULL_TIME      NaN               NaN           1
# 31549          0   CONTRACT      USD       BASE_SALARY           1
# 27807          1  FULL_TIME      USD       BASE_SALARY           1
# 22284          1  FULL_TIME      NaN               NaN           1
# 6259           0  PART_TIME      NaN               NaN  1699050509
# 11149          1  FULL_TIME      USD       BASE_SALARY  1699138776

# %% [markdown]
# From the sample table above, we can see that all time variables have been converted into standard datetime format. In the standard notation, we can observe the following:
# - `original_listed_time` and `listed_time` are displaying similar information, further investigation is needed.
# - `closed_time` variable contains a lot of null values and the non-null values seem to be inconsistent as some timestamps occur prior to `original_listed_time` timestamps (closed_time: 2023-07-22, 00:26:40 vs original_listed_time: 2023-08-22, 17:33:20). We will conduct further analysis to determine the relevance of `closed_time` column and take actions accordingly.

# %%
# Find rows with duplicate combinations of 'original_time_listed' and 'listed_time'
duplicate_rows = raw_df[raw_df.duplicated(subset=['original_listed_time', 'listed_time'], keep=False)]

# Group by the combination of 'original_time_listed' and 'listed_time' and count the occurrences
duplicate_counts = duplicate_rows.groupby(['original_listed_time', 'listed_time']).size().reset_index(name='count')

# Sum the counts to get the total duplicate count
total_duplicate_count = duplicate_counts['count'].sum()

print("Total duplicate count:", total_duplicate_count)
# Out:
# Total duplicate count: 32861

# %% [markdown]
# There are total 32861 duplicated rows (out of 33246 rows) between `original_listed_time` and `listed_time`. This leaves us with 385 unique values from `listed_time` column, and these values suggest that there are job postings that are being reposted. From these two columns, we can calculate the repost duration of each job posting.

# %%
raw_df['repost_duration'] = raw_df['listed_time'] - raw_df['original_listed_time']

# %%
raw_df[['listed_time', 'original_listed_time', 'repost_duration']].sample(50)
# Out:
#               listed_time original_listed_time  repost_duration
# 11379 2023-11-03 18:20:00  2023-11-02 20:06:40  0 days 22:13:20
# 2255  2023-11-03 18:20:00  2023-11-03 18:20:00  0 days 00:00:00
# 18861 2023-08-22 17:33:20  2023-08-21 19:20:00  0 days 22:13:20
# 20573 2023-08-22 00:53:20  2023-08-08 20:13:20 13 days 04:40:00
# 20909 2023-08-24 02:53:20  2023-08-24 02:53:20  0 days 00:00:00
# 9456  2023-11-03 21:06:40  2023-11-02 20:06:40  1 days 01:00:00
# 16947 2023-11-02 20:06:40  2023-11-02 20:06:40  0 days 00:00:00
# 18105 2023-08-22 17:33:20  2023-08-22 17:33:20  0 days 00:00:00
# 4732  2023-11-03 18:20:00  2023-11-03 18:20:00  0 days 00:00:00
# 6126  2023-11-03 15:33:20  2023-11-03 15:33:20  0 days 00:00:00
# 25503 2023-08-22 14:46:40  2023-08-22 14:46:40  0 days 00:00:00
# 24064 2023-08-22 20:20:00  2023-08-22 17:33:20  0 days 02:46:40
# 17629 2023-08-22 17:33:20  2023-08-22 17:33:20  0 days 00:00:00
# 27550 2023-08-23 21:20:00  2023-08-23 21:20:00  0 days 00:00:00
# 6152  2023-11-03 15:33:20  2023-11-03 15:33:20  0 days 00:00:00
# 19592 2023-08-22 14:46:40  2023-08-22 14:46:40  0 days 00:00:00
# 23925 2023-08-22 20:20:00  2023-08-22 17:33:20  0 days 02:46:40
# 5440  2023-11-03 15:33:20  2023-11-02 20:06:40  0 days 19:26:40
# 15377 2023-11-03 18:20:00  2023-11-02 20:06:40  0 days 22:13:20
# 14430 2023-11-03 18:20:00  2023-11-02 20:06:40  0 days 22:13:20
# 6703  2023-11-03 15:33:20  2023-11-03 15:33:20  0 days 00:00:00
# 31474 2023-08-22 14:46:40  2023-08-22 14:46:40  0 days 00:00:00
# 3441  2023-11-03 18:20:00  2023-11-03 18:20:00  0 days 00:00:00
# 9156  2023-11-03 23:53:20  2023-10-25 01:00:00  9 days 22:53:20
# 29357 2023-08-22 17:33:20  2023-08-22 17:33:20  0 days 00:00:00
# 18154 2023-08-22 17:33:20  2023-08-22 17:33:20  0 days 00:00:00
# 7365  2023-11-03 15:33:20  2023-11-03 15:33:20  0 days 00:00:00
# 17986 2023-08-23 13:00:00  2023-08-22 17:33:20  0 days 19:26:40
# 5365  2023-11-03 18:20:00  2023-11-03 18:20:00  0 days 00:00:00
#
# 28409  3693584935      9089.0
# 11233  3755593455    398606.0
# 31525  3693049024      4097.0
# 8654   3756383306     36704.0
# 23122  3699057348     77301.0
# 2431   3757732801    808034.0
# 18420  3701321687      1906.0
# 21143  3699417519      1703.0
# 24312  3697384612     13033.0
# 33158  3566610728         NaN
# 30427  3693056054    484002.0
# 17119  3748838936     57281.0
# 15058  3749358672     20573.0
# 1785   3757739979    461332.0
# 13316  3755551794     15227.0
# 26044  3694123207      1505.0
# 25391  3697354863  56119363.0
# 4543   3757490480     13946.0
# 31448  3693049370    373568.0
# 23351  3698003058    686294.0
# 911    3757769875      1396.0
# 21304  3699412829  64550438.0
# 8614   3756724610      8070.0
# 21508  3699407708      2251.0
# 7597   3757443593      3240.0
#
#                                                    title  \
# 32384        Bookkeeper / Office Manager with QuickBooks
# 27253              Relationship Banker - Bellevue Branch
# 18378     Microsoft Search and Power Apps/Power Automate
# 23954      Senior Manager, Cost Model Analytics - Hybrid
# 2225                                  Accounting Manager
# 7735                                  Equipment Operator
# 28173                                   Staff Accountant
# 31955                             Technical Site Manager
# 33207                         Mental Health Professional
# 26276          Workers Compensation Unit Stat Specialist
# 31898             Real Estate Financial Analysis Manager
# 25538                                        INSULATOR 9
# 6237                                        Receptionist
# 2988    Senior Clinical Biospecimen Operations Associate
# 4120                                  Project Accountant
# 19903                         Mechanical Project Manager
# 18135                 Guidewire Billing Center Developer
# 1440       Virtual Medical Receptionist/Office Assistant
# 10974                             Restaurant Team Member
# 31306                  Industrial Maintenance Technician
# 32476      Remote Global Success Factors Project Manager
# 15690                             Architectural Designer
# 27725                             Retail Sales Associate
# 14934                         Class A CDL Shuttle Driver
# 17053      Technical Support Analyst - Database Security
# 28409                               Data Project Manager
# 11233                               Body Shop Technician
# 31525                               Data Management Lead
# 8654                                Electrical Estimator
# 23122                                            Cashier
# 2431   Travel ER RN job in Fullerton, CA - Make $2602...
# 18420                         Program Finance Specialist
# 21143                    Xfinity Retail Sales Consultant
# 24312                           Associate Sales Engineer
# 33158                                  Account Executive
# 30427                                Application Manager
# 17119                                     Chief Engineer
# 15058             Admissions Nurse (Registered Nurse/RN)
# 1785                              Plumber Heating and AC
# 13316                    Food Systems and Policy Adjunct
# 26044               Senior Analyst, Engineering Services
# 25391         Dietary Aide - Days, No nights or weekends
# 4543                   Supply Chain Equipment Specialist
# 31448                       Temporary Operations Analyst
# 23351                           Administrative Assistant
# 911                               Maintenance Supervisor
# 21304                                 Sr. Java Developer
# 8614                        IT Manager – User Experience
# 21508       Regional Asset Protection Manager (Colorado)
# 7597                                        Agency Owner
#
#                                              description  max_salary  \
# 32384  Bookkeeper / Office Manager with QuickBooks - ...    60000.00
# 27253  Who We Are First Fed is a local community bank...       39.66
# 18378  Position Responsibilities:Configure MS Search ...         NaN
# 23954  \n \n\nSolutions driven success.\n\n \n\nXPO i...         NaN
# 2225   Company DescriptionCoast to Coast Commercial, ...   110000.00
# 7735   Job Title: Equipment OperatorLocation: Hegins,...       30.00
# 28173  Frisco CPA firm is looking for a Staff Account...         NaN
# 31955  When an entire city needs to be rendered into ...    90000.00
# 33207  You Belong Here.\nAt MultiCare, we strive to o...    79541.00
# 26276  **Our leading Insurance Industry Client is loo...         NaN
# 31898  GENERAL DESCRIPTION:High Real Estate Group (HR...         NaN
# 25538  Job Description\n\nZACHRY is currently seeking...         NaN
# 6237   About ParadromicsAt Paradromics, we’re enablin...         NaN
# 2988   Overview\n\nWe are currently searching for a s...         NaN
# 4120   Avdoo & Partners, a fully integrated, privatel...         NaN
# 19903  Job Requirements:Job Requirements:Experience m...         NaN
# 18135  Role: Guidewire Billing Center DeveloperLocati...         NaN
# 1440   A virtual medical assistant /receptionist perf...       15.00
# 10974  Average Rate: $19.15 / hour!*\n\n(*Average rat...         NaN
# 31306  Shifts Available:2nd shift - Mon–Fri - 2pm-10p...         NaN
# 32476  Global Success Factors Project Manager$80 - $1...      107.14
# 15690  \n Role: Mid-Level ArchitectDuration: Contract...         NaN
# 27725  When you join Verizon\n\nVerizon is one of the...    56000.00
# 14934  Position Details:\n\nPay: $75,000 - $85,000 an...    85000.00
# 17053  Job Description\n\nAs a member of the Support ...       63.46
# 28409  One of our esteemed client is looking for Data...         NaN
# 11233  A Body Shop Technician will repair or replace ...       36.00
# 31525  Quality Information System LeadLocation: Marys...         NaN
# 8654   Description\n\nJob Description:\n\nStructure T...         NaN
# 23122  Privacy Notice: Visit https://www.raisingcanes...       16.50
# 2431   Aya Healthcare has an immediate opening for th...         NaN
# 18420  About the role:Functional responsibility withi...         NaN
# 21143  R370331\n\nComcast brings together the best in...         NaN
# 24312  Proven Leadership, Hard Work and Innovation Al...         NaN
# 33158  🌟 **Join the LA Exhibits Team – Your Career in...         NaN
# 30427  (Fintech experience is a plus)Location: United...         NaN
# 17119  Who is Waterton?\n\nWe are passionate about de...         NaN
# 15058  Seeking an RN or LPN! Monday-Friday from 8am-4...         NaN
# 1785   \n$5k SIGN ON BONUS for CT HVAC license of typ...       40.00
# 13316  Food Systems and Policy Adjunct\nJob Descripti...         NaN
# 26044  Date Posted:\n2023-08-21\nCountry:\nUnited Sta...         NaN
# 25391  Employment Type\nFull time\nShift\nDescription...         NaN
# 4543   Mortenson’s success is not a matter of luck; i...         NaN
# 31448  Our client, a financial services company, is l...       21.00
# 23351  About Us\n\nOne Medical is a primary care solu...         NaN
# 911    We’re a leader in the pet care industry, which...   101000.00
# 21304  Job Summary\nThe Senior Java Application Devel...         NaN
# 8614   The IT Manager – User Experience will be respo...         NaN
# 21508  Description\nThe Regional Asset Protection Man...   110250.00
# 7597   DISCOVER BUSINESS OWNERSHIP. There are busines...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 32384         NaN    50000.00     YEARLY           Full-time
# 27253         NaN       23.33     HOURLY           Full-time
# 18378         NaN         NaN        NaN           Full-time
# 23954         NaN         NaN        NaN           Full-time
# 2225          NaN    85000.00     YEARLY           Full-time
# 7735          NaN       25.00     HOURLY           Full-time
# 28173         NaN         NaN        NaN           Full-time
# 31955         NaN    75000.00     YEARLY           Full-time
# 33207         NaN    55280.00     YEARLY           Full-time
# 26276         NaN         NaN        NaN            Contract
# 31898         NaN         NaN        NaN           Full-time
# 25538         NaN         NaN        NaN           Full-time
# 6237          NaN         NaN        NaN           Full-time
# 2988          NaN         NaN        NaN            Contract
# 4120          NaN         NaN        NaN           Full-time
# 19903         NaN         NaN        NaN           Full-time
# 18135         NaN         NaN        NaN           Full-time
# 1440          NaN       10.00     HOURLY            Contract
# 10974       19.15         NaN     HOURLY           Full-time
# 31306         NaN         NaN        NaN           Full-time
# 32476         NaN       90.00     HOURLY            Contract
# 15690         NaN         NaN        NaN            Contract
# 27725         NaN    43000.00     YEARLY           Full-time
# 14934         NaN    75000.00     YEARLY           Full-time
# 17053         NaN       26.92     HOURLY           Full-time
# 28409         NaN         NaN        NaN            Contract
# 11233         NaN       18.00     HOURLY           Full-time
# 31525         NaN         NaN        NaN           Full-time
# 8654          NaN         NaN        NaN           Full-time
# 23122         NaN       15.50     HOURLY           Full-time
# 2431          NaN         NaN        NaN           Part-time
# 18420         NaN         NaN        NaN           Full-time
# 21143       15.63         NaN     HOURLY           Full-time
# 24312         NaN         NaN        NaN           Full-time
# 33158         NaN         NaN        NaN           Full-time
# 30427         NaN         NaN        NaN           Full-time
# 17119         NaN         NaN        NaN           Full-time
# 15058         NaN         NaN        NaN           Part-time
# 1785          NaN       25.00     HOURLY           Full-time
# 13316         NaN         NaN        NaN           Part-time
# 26044         NaN         NaN        NaN           Full-time
# 25391         NaN         NaN        NaN           Full-time
# 4543          NaN         NaN        NaN           Full-time
# 31448         NaN       20.00     HOURLY           Temporary
# 23351       20.50         NaN     HOURLY           Full-time
# 911           NaN    72000.00     YEARLY           Full-time
# 21304         NaN         NaN        NaN           Full-time
# 8614          NaN         NaN        NaN           Full-time
# 21508         NaN    84000.00     YEARLY           Full-time
# 7597          NaN         NaN        NaN            Contract
#
#                                  location  applies original_listed_time  \
# 32384                      Alpharetta, GA     18.0  2023-08-22 14:46:40
# 27253                        Bellevue, WA      NaN  2023-08-23 18:33:20
# 18378                     Foster City, CA     31.0  2023-08-22 17:33:20
# 23954            North Richland Hills, TX      1.0  2023-08-21 19:20:00
# 2225                    Mission Viejo, CA      8.0  2023-11-03 18:20:00
# 7735                           Hegins, PA      2.0  2023-11-03 15:33:20
# 28173                          Frisco, TX      4.0  2023-08-23 18:33:20
# 31955                     Port Arthur, TX      1.0  2023-08-22 14:46:40
# 33207                         Spokane, WA      NaN  2023-08-24 00:06:40
# 26276                    Philadelphia, PA      NaN  2023-08-22 20:20:00
# 31898                       Lancaster, PA      3.0  2023-08-22 14:46:40
# 25538                        La Porte, TX      NaN  2023-08-22 14:46:40
# 6237      Austin, Texas Metropolitan Area      1.0  2023-11-03 15:33:20
# 2988                        United States      NaN  2023-10-22 20:13:20
# 4120                         New York, NY     11.0  2023-11-03 18:20:00
# 19903                       Baltimore, MD     14.0  2023-08-22 14:46:40
# 18135                       United States      NaN  2023-08-22 17:33:20
# 1440                         Richmond, VA     22.0  2023-11-03 21:06:40
# 26276                           click.appcast.io          0   CONTRACT
# 31898                                        NaN          0  FULL_TIME
# 25538                   zhi.mua.hrdepartment.com          0  FULL_TIME
# 6237                                         NaN          1  FULL_TIME
# 2988                   jobs.advancedclinical.com          0   CONTRACT
# 4120                                         NaN          1  FULL_TIME
# 19903                                        NaN          0  FULL_TIME
# 18135                                        NaN          0  FULL_TIME
# 1440                                         NaN          0   CONTRACT
# 10974           shakeshack.wd5.myworkdayjobs.com          0  FULL_TIME
# 31306                                        NaN          0  FULL_TIME
# 32476                                        NaN          0   CONTRACT
# 15690                                        NaN          0   CONTRACT
# 27725                           www.aplitrak.com          1  FULL_TIME
# 14934                        sjobs.brassring.com          0  FULL_TIME
# 17053                eeho.fa.us2.oraclecloud.com          0  FULL_TIME
# 28409                                        NaN          0   CONTRACT
# 11233                careers.rushenterprises.com          0  FULL_TIME
# 31525                                        NaN          0  FULL_TIME
# 8654                            jobs.jobvite.com          1  FULL_TIME
# 23122                 raisingcanes.jibeapply.com          0  FULL_TIME
# 2431                       www.ayahealthcare.com          0  PART_TIME
# 18420  generaldynamics-us-careers.ttcportals.com          0  FULL_TIME
# 21143                      comcast.contacthr.com          0  FULL_TIME
# 24312                      rittal.applytojob.com          1  FULL_TIME
# 33158                                        NaN          0  FULL_TIME
# 30427                                        NaN          0  FULL_TIME
# 17119                    recruiting2.ultipro.com          0  FULL_TIME
# 15058              lifecarecareers.hcshiring.com          0  PART_TIME
# 1785                         www.click2apply.net          0  FULL_TIME
# 13316                                        NaN          0  PART_TIME
# 26044                            careers.rtx.com          0  FULL_TIME
# 25391                    jobs.trinity-health.org          0  FULL_TIME
# 4543                           www.mortenson.com          0  FULL_TIME
# 31448                                        NaN          0  TEMPORARY
# 23351                     careers.onemedical.com          0  FULL_TIME
# 911                        jobdetails.nestle.com          0  FULL_TIME
# 21304                            www.fasttek.com          0  FULL_TIME
# 8614                                         NaN          1  FULL_TIME
# 21508                careers.victoriassecret.com          0  FULL_TIME
# 7597                                         NaN          0   CONTRACT
#
#       currency compensation_type     scraped  repost_duration  reposted
# 32384      USD       BASE_SALARY           1  0 days 00:00:00         0
# 27253      USD       BASE_SALARY           1  0 days 00:00:00         0
# 18378      NaN               NaN           1  0 days 00:00:00         0
# 23954      NaN               NaN           1  0 days 22:13:20         1
# 2225       USD       BASE_SALARY  1699133506  0 days 00:00:00         0
# 7735       USD       BASE_SALARY  1699136524  0 days 00:00:00         0
# 28173      NaN               NaN           1  0 days 00:00:00         0
# 31955      USD       BASE_SALARY           1  0 days 00:00:00         0
# 33207      USD       BASE_SALARY           1  0 days 02:46:40         1
# 26276      NaN               NaN           1  1 days 03:46:40         1
# 31898      NaN               NaN           1  0 days 00:00:00         0
# 25538      NaN               NaN           1  0 days 00:00:00         0
# 6237       NaN               NaN  1699046400  0 days 00:00:00         0
# 2988       NaN               NaN  1699051987 11 days 22:06:40         1
# 4120       NaN               NaN  1699133961  0 days 00:00:00         0
# 19903      NaN               NaN           1  0 days 00:00:00         0
# 18135      NaN               NaN           1  0 days 00:00:00         0
# 1440       USD       BASE_SALARY  1699129732  0 days 00:00:00         0
# 10974      USD       BASE_SALARY  1699073743 25 days 00:00:00         1
# 31306      NaN               NaN           1  0 days 00:00:00         0
# 32476      USD       BASE_SALARY           1  0 days 00:00:00         0
# 15690      NaN               NaN  1699055339  0 days 00:00:00         0
# 27725      USD       BASE_SALARY           1  0 days 00:00:00         0
# 14934      USD       BASE_SALARY  1699054437  0 days 00:00:00         0
# 17053      USD       BASE_SALARY  1698964335  0 days 22:13:20         1
# 28409      NaN               NaN           1  0 days 00:00:00         0
# 11233      USD       BASE_SALARY  1699088579  0 days 22:13:20         1
# 31525      NaN               NaN           1  0 days 00:00:00         0
# 8654       NaN               NaN  1698996228  0 days 00:00:00         0
# 23122      USD       BASE_SALARY           1  0 days 00:00:00         0
# 2431       NaN               NaN  1699083195  0 days 08:20:00         1
# 18420      NaN               NaN           1  0 days 00:00:00         0
# 21143      USD       BASE_SALARY           1  1 days 03:46:40         1
# 24312      NaN               NaN           1  0 days 00:00:00         0
# 33158      NaN               NaN  1699051543  0 days 00:00:00         0
# 30427      NaN               NaN           1  0 days 00:00:00         0
# 17119      NaN               NaN  1698993995 13 days 21:20:00         1
# 15058      NaN               NaN  1699136223  0 days 05:33:20         1
# 1785       USD       BASE_SALARY  1699090595  0 days 00:00:00         0
# 13316      NaN               NaN  1699037230  0 days 00:00:00         0
# 26044      NaN               NaN           1  1 days 03:46:40         1
# 25391      NaN               NaN           1 15 days 06:40:00         1
# 4543       NaN               NaN  1699050210  0 days 00:00:00         0
# 31448      USD       BASE_SALARY           1  0 days 00:00:00         0
# 23351      USD       BASE_SALARY           1  1 days 01:00:00         1
# 911        USD       BASE_SALARY  1699082972  0 days 00:00:00         0
# 21304      NaN               NaN           1  0 days 00:00:00         0
# 8614       NaN               NaN  1698996375  0 days 00:00:00         0
# 21508      USD       BASE_SALARY           1  0 days 00:00:00         0
# 7597       NaN               NaN  1699038635  0 days 00:00:00         0

# %%
raw_df['reposted'].value_counts()
# Out:
# reposted
# 0    23377
# 1     9869
# Name: count, dtype: int64

# %% [markdown]
# There were 23377 job postings that weren't reposted at all, whereas 9869 job postings were reposted at least once. Now we know whether the job postings have been reposted or not, we can remove the `repost_duration` column from the dataset.

# %%
raw_df.drop(columns=['repost_duration'], inplace=True)

# Sanity Check
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  job_posting_url             33246 non-null  object
#  15  application_url             20996 non-null  object
#  16  application_type            33246 non-null  object
#  17  expiry                      33246 non-null  datetime64[ns]
#  18  closed_time                 1172 non-null   object
#  19  formatted_experience_level  24065 non-null  object
#  20  skills_desc                 337 non-null    object
#  21  listed_time                 33246 non-null  datetime64[ns]
#  22  posting_domain              19688 non-null  object
#  23  sponsored                   33246 non-null  int64
#  24  work_type                   33246 non-null  object
#  25  currency                    13352 non-null  object
#  26  compensation_type           13352 non-null  object
#  27  scraped                     33246 non-null  int64
#  28  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(4), object(15)
# memory usage: 7.4+ MB

# %% [markdown]
# Next, let's take a look at `closed_time` column.

# %%
raw_df['closed_time'].isna().sum()/raw_df.shape[0]*100
# Out:
# 96.47476388136919

# %% [markdown]
# Since the `closed_time` column is missing approximately 96 percent of the data, it will be difficult to draw any meaningful insights. The `expiry` column shows timestamps of when the job postings will expire compared to `closed_time` column where it displays timestamps of when the job postings were actually closed. For our analysis, `expiry` data is sufficient enough to showcase the relationship between number of views and the duration of the job posting. Therefore, we will drop the `closed_time` variable to avoid data inconsistency and redundancy.

# %%
raw_df.drop(columns=['closed_time'], inplace=True)

# Sanity Check
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  job_posting_url             33246 non-null  object
#  15  application_url             20996 non-null  object
#  16  application_type            33246 non-null  object
#  17  expiry                      33246 non-null  datetime64[ns]
#  18  formatted_experience_level  24065 non-null  object
#  19  skills_desc                 337 non-null    object
#  20  listed_time                 33246 non-null  datetime64[ns]
#  21  posting_domain              19688 non-null  object
#  22  sponsored                   33246 non-null  int64
#  23  work_type                   33246 non-null  object
#  24  currency                    13352 non-null  object
#  25  compensation_type           13352 non-null  object
#  26  scraped                     33246 non-null  int64
#  27  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(4), object(14)
# memory usage: 7.1+ MB

# %% [markdown]
# #### Dealing with Unnecessary Columns

# %% [markdown]
# From the datatype table and initial analysis, we can remove the following columns: `job_posting_url`, `application_url`, and `scraped`.

# %%
# Drop irrelevant columns 
df = raw_df.drop(['job_posting_url', 'application_url', 'scraped'], axis=1)

# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  listed_time                 33246 non-null  datetime64[ns]
#  19  posting_domain              19688 non-null  object
#  20  sponsored                   33246 non-null  int64
#  21  work_type                   33246 non-null  object
#  22  currency                    13352 non-null  object
#  23  compensation_type           13352 non-null  object
#  24  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(3), object(12)
# memory usage: 6.3+ MB

# %% [markdown]
# The three variables mentioned above have been successfully dropped, we will now look at the "formatted_work_type" vs "work_type".

# %% [markdown]
# #### "formatted_work_type" vs "work_type"

# %%
df['formatted_work_type'].value_counts()
# Out:
# formatted_work_type
# Full-time     26900
# Contract       3459
# Part-time      2244
# Temporary       260
# Internship      228
# Other           110
# Volunteer        45
# Name: count, dtype: int64

# %%
df['work_type'].value_counts()
# Out:
# work_type
# FULL_TIME     26900
# CONTRACT       3459
# PART_TIME      2244
# TEMPORARY       260
# INTERNSHIP      228
# OTHER           110
# VOLUNTEER        45
# Name: count, dtype: int64

# %% [markdown]
# Since the two 'work type' columns show identical data structure, we can confirm that the two columns are redundant. Hence, we will drop 'work_type' column as the 'formatted_work_type' column is the refined version of 'work_type' column with proper headings (only the first letter is capitalized instead of every letter being  capitalized).

# %%
df.drop(columns=['work_type'], inplace=True)

# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  listed_time                 33246 non-null  datetime64[ns]
#  19  posting_domain              19688 non-null  object
#  20  sponsored                   33246 non-null  int64
#  21  currency                    13352 non-null  object
#  22  compensation_type           13352 non-null  object
#  23  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(3), object(11)
# memory usage: 6.1+ MB

# %% [markdown]
# Lastly, let's take a look at the two categorical variables, `Currency` and `Compensation_Type`.

# %% [markdown]
# #### Currency

# %%
df['currency'].value_counts()
# Out:
# currency
# USD    13352
# Name: count, dtype: int64

# %%
df['currency'].unique()
# Out:
# array(['USD', nan], dtype=object)

# %% [markdown]
# Since the `currency` only has one type of data entry, "USD", we will drop this column.

# %%
df.drop(columns=['currency'], inplace=True)

# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  listed_time                 33246 non-null  datetime64[ns]
#  19  posting_domain              19688 non-null  object
#  20  sponsored                   33246 non-null  int64
#  21  compensation_type           13352 non-null  object
#  22  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(3), object(10)
# memory usage: 5.8+ MB

# %% [markdown]
# The column `currency` has been dropped, now we will take a look at the column `compensation_type`.

# %% [markdown]
# #### Compensation Type

# %%
df['compensation_type'].value_counts()
# Out:
# compensation_type
# BASE_SALARY    13352
# Name: count, dtype: int64

# %%
df['compensation_type'].unique()
# Out:
# array(['BASE_SALARY', nan], dtype=object)

# %% [markdown]
# The `compensation_type` variable contains "BASE_SALARY" as the only response, thus we will drop this column.

# %%
df.drop(columns=['compensation_type'], inplace=True)

# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  listed_time                 33246 non-null  datetime64[ns]
#  19  posting_domain              19688 non-null  object
#  20  sponsored                   33246 non-null  int64
#  21  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(3), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# The `compensation_type` column has been dropped. From the new datatype table, we can observe that all the unnecessary columns have been dropped. Following the data loading process, we will enter the data cleaning phase using the refined dataset.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# In this section, we will be conducting various data cleaning methods, such as checking datatypes, finding any duplicates, and removing null values to prepare a clean dataset for preliminary EDA.

# %% [markdown]
# <a id = 'Datatypes'><a/>
# ## Datatypes
#
# ---

# %% [markdown]
# Now let's check the updated number of rows and columns in the dataset

# %%
print(f"We have {df.shape[0]} rows and {df.shape[1]} columns with  string (categorical), floats and integers.")
# Out:
# We have 33246 rows and 22 columns with  string (categorical), floats and integers.

# %% [markdown]
# Revisit the datatypes using the updated dataset after dropping variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33245 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  13352 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  24065 non-null  object
#  17  skills_desc                 337 non-null    object
#  18  listed_time                 33246 non-null  datetime64[ns]
#  19  posting_domain              19688 non-null  object
#  20  sponsored                   33246 non-null  int64
#  21  reposted                    33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(3), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# After removing irrelevant columns, the dataset now has 22 columns, 3 datetime variables, 10 numerical variables, and 9 categorical variables. We will continue data processing and conduct various data cleaning methods to prepare a clean dataset for preliminary EDA.

# %% [markdown]
# Now let's check for any duplicates in the dataset.

# %% [markdown]
# <a id = 'Duplicates'><a/>
# ## Duplicates
#
# ---

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 33241    False
# 33242    False
# 33243    False
# 33244    False
# 33245    False
# Length: 33246, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicated rows, now let's check duplicated columns

# %%
df.T.duplicated()
# Out:
# job_id                        False
# company_id                    False
# title                         False
# description                   False
# max_salary                    False
# med_salary                    False
# min_salary                    False
# pay_period                    False
# formatted_work_type           False
# location                      False
# applies                       False
# original_listed_time          False
# remote_allowed                False
# views                         False
# application_type              False
# expiry                        False
# formatted_experience_level    False
# skills_desc                   False
# listed_time                   False
# posting_domain                False
# sponsored                     False
# reposted                      False
# dtype: bool

# %%
df.T.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Since there are no duplicate columns, we can proceed to the final stage of data cleaning, dealing with null values.

# %% [markdown]
# <a id = 'Null'><a/>
# ## Missing Values
#
# ---

# %% [markdown]
# Let's first take a look at the missing values present in each column

# %%
df.isna().sum()
# Out:
# job_id                            0
# company_id                      654
# title                             0
# description                       1
# max_salary                    22135
# med_salary                    31005
# min_salary                    22135
# pay_period                    19894
# formatted_work_type               0
# location                          0
# applies                       17008
# original_listed_time              0
# remote_allowed                28444
# views                          7360
# application_type                  0
# expiry                            0
# formatted_experience_level     9181
# skills_desc                   32909
# listed_time                       0
# posting_domain                13558
# sponsored                         0
# reposted                          0
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# job_id                         0.000000
# company_id                     1.967154
# title                          0.000000
# description                    0.003008
# max_salary                    66.579438
# med_salary                    93.259339
# min_salary                    66.579438
# pay_period                    59.838778
# formatted_work_type            0.000000
# location                       0.000000
# applies                       51.158034
# original_listed_time           0.000000
# remote_allowed                85.556157
# views                         22.138002
# application_type               0.000000
# expiry                         0.000000
# formatted_experience_level    27.615352
# skills_desc                   98.986344
# listed_time                    0.000000
# posting_domain                40.780846
# sponsored                      0.000000
# reposted                       0.000000
# dtype: float64

# %% [markdown]
# We can observe that there are several missing values across different columns within the dataset. Let's separate them by their respective datatypes and try to deal with them one by one. This process could involve filling in the null values or entirely dropping the columns if needed.

# %% [markdown]
# ### Categorical Variables

# %% [markdown]
# #### Description

# %%
df['description'].isna().sum()
# Out:
# 1

# %% [markdown]
# Since the `description` column is only missing one value, we will fill this missing information using "Not Specified".

# %%
df['description'] = df['description'].fillna("Not Specified")
df['description'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Pay Period

# %%
df['pay_period'].value_counts()
# Out:
# pay_period
# YEARLY     8009
# HOURLY     5036
# MONTHLY     224
# WEEKLY       82
# ONCE          1
# Name: count, dtype: int64

# %%
df['pay_period'].isna().sum()/df.shape[0]*100
# Out:
# 59.83877759730494

# %% [markdown]
# We will fill the missing values with "Not Specified".

# %%
df['pay_period'] = df['pay_period'].fillna("Not Specified")
df['pay_period'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Experience Level

# %%
df['formatted_experience_level'].value_counts()
# Out:
# formatted_experience_level
# Mid-Senior level    11258
# Entry level          7969
# Associate            2793
# Director             1354
# Internship            387
# Executive             304
# Name: count, dtype: int64

# %%
df['formatted_experience_level'].isna().sum()/df.shape[0]*100
# Out:
# 27.615352222823798

# %% [markdown]
# Similarly, we will fill in the missing values from `formatted_experience_level` using "Not Specified".

# %%
df['formatted_experience_level'] = df['formatted_experience_level'].fillna("Not Specified")
df['formatted_experience_level'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Skills Description

# %%
df['skills_desc'].isna().sum()
# Out:
# 32909

# %%
df['skills_desc'].isna().sum()/df.shape[0]*100
# Out:
# 98.98634422186127

# %% [markdown]
# Since it's missing roughly 99 percent of the values, we will create a binary column of '0' and '1' to depict whether the job posting provides the required skills description or not. Hence, the '0' will represent the missing values where the company has not provided the skills information within the job posting, and '1' will represent the job postings that have listed the skills description within the job posting. Then, we will drop the `skills_desc` column.

# %%
df['skills_present'] = df['skills_desc'].notnull().astype(int)

# %%
df.drop(columns=['skills_desc'], inplace=True)

# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  33246 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  33246 non-null  object
#  17  listed_time                 33246 non-null  datetime64[ns]
#  18  posting_domain              19688 non-null  object
#  19  sponsored                   33246 non-null  int64
#  20  reposted                    33246 non-null  int64
#  21  skills_present              33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(4), object(8)
# memory usage: 5.6+ MB

# %%
df['skills_present'].value_counts()
# Out:
# skills_present
# 0    32909
# 1      337
# Name: count, dtype: int64

# %% [markdown]
# From above, we can observe that majority of the companies (32909, or 99 percent) did not include skills description within their job postings. This shows that the majority of companies do not bother including skills description, instead they just include the general description about the job under `description`.

# %% [markdown]
# #### Posting Domain

# %%
df['posting_domain'].value_counts()
# Out:
# posting_domain
# www.click2apply.net                    533
# jobs.smartrecruiters.com               466
# click.appcast.io                       447
# boards.greenhouse.io                   385
# recruiting.ultipro.com                 351
#                                       ...
# santegroup.clearcompany.com              1
# sforce.co                                1
# libertyglobal.wd3.myworkdayjobs.com      1
# matthey.wd3.myworkdayjobs.com            1
# jobs.armstrongceilings.com               1
# Name: count, Length: 2576, dtype: int64

# %%
df['posting_domain'].isna().sum()/df.shape[0]*100
# Out:
# 40.78084581603802

# %% [markdown]
# LinkedIn has two options for applying, first method is to apply through LinkedIn directly using their "Easy Apply" feature, and the second method is to apply through company's website as LinkedIn redirects the applicant to a specific company's web domain through "Apply" button. Therefore, we will assume that the reported missing values from `posting_domain` column represent the applications submitted through "Easy Apply" feature on LinkedIn.

# %% [markdown]
# Now let's organize this into a binary column where '0' represents the missing values or the direct apply through LinkedIn and '1' represents the applications through a specific company's website (having specific web domain).

# %%
df['application_portal'] = df['posting_domain'].notnull().astype(int)

# %%
df.drop(columns=['posting_domain'], inplace=True)

# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  32592 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   max_salary                  11111 non-null  float64
#  5   med_salary                  2241 non-null   float64
#  6   min_salary                  11111 non-null  float64
#  7   pay_period                  33246 non-null  object
#  8   formatted_work_type         33246 non-null  object
#  9   location                    33246 non-null  object
#  10  applies                     16238 non-null  float64
#  11  original_listed_time        33246 non-null  datetime64[ns]
#  12  remote_allowed              4802 non-null   float64
#  13  views                       25886 non-null  float64
#  14  application_type            33246 non-null  object
#  15  expiry                      33246 non-null  datetime64[ns]
#  16  formatted_experience_level  33246 non-null  object
#  17  listed_time                 33246 non-null  datetime64[ns]
#  18  sponsored                   33246 non-null  int64
#  19  reposted                    33246 non-null  int64
#  20  skills_present              33246 non-null  int64
#  21  application_portal          33246 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(5), object(7)
# memory usage: 5.6+ MB

# %%
df['application_portal'].value_counts()
# Out:
# application_portal
# 1    19688
# 0    13558
# Name: count, dtype: int64

# %% [markdown]
# There were 19688 applications that were submitted directly through LinkedIn, whereas 13558 applications were redirected and submitted through a company's web domain.

# %%
# Sanity Check
df.isna().sum()
# Out:
# job_id                            0
# company_id                      654
# title                             0
# description                       0
# max_salary                    22135
# med_salary                    31005
# min_salary                    22135
# pay_period                        0
# formatted_work_type               0
# location                          0
# applies                       17008
# original_listed_time              0
# remote_allowed                28444
# views                          7360
# application_type                  0
# expiry                            0
# formatted_experience_level        0
# listed_time                       0
# sponsored                         0
# reposted                          0
# skills_present                    0
# application_portal                0
# dtype: int64

# %% [markdown]
# We have completed the data cleaning process for categorical variables through feature engineering and filling in the null values. Now we will take a look at numerical variables and deal with missing values.

# %% [markdown]
# ### Numerical Variables

# %% [markdown]
# #### Company ID

# %%
df['company_id'].isna().sum()
# Out:
# 654

# %%
df['company_id'].isna().sum()/df.shape[0]*100
# Out:
# 1.9671539433315284

# %%
df['company_id'].value_counts()
# Out:
# company_id
# 11056.0       217
# 3570660.0     198
# 808034.0      191
# 3706049.0     186
# 1103.0        154
#              ...
# 18192301.0      1
# 81149246.0      1
# 3628379.0       1
# 2937626.0       1
# 140719.0        1
# Name: count, Length: 11325, dtype: int64

# %% [markdown]
# We are missing roughly 2 percent of `company_id` data. There are some company ids that are repeating (indicating that companies can list multiple job postings), hence we will check how many company ids are repeated versus the company ids that are recorded once.

# %%
# Group the data by company_id and count the occurrences
company_id_counts = df.groupby('company_id').size()

# Filter for company_ids with more than one occurrence
repeated_company_ids = company_id_counts[company_id_counts > 1]

repeated_company_ids.sum()
# Out:
# 25560

# %% [markdown]
# There are total of 25560 company ids that occur more than once in the dataset out of 33246 rows (77 percent). In other words, majority of the company ids are repeated, implicating that several companies are posting multiple job postings. Given the fact that majority of the company ids are repeating, we will use random sampling method to fill in the null values. First, we would randomly select a company ID from the pool of company IDs that occur more than once. Then, we would replace missing values in the `company_id` column with the randomly selected company IDs.

# %%
# Identify company IDs occurring more than once 
repeat_company_id = df['company_id'].value_counts()[df['company_id'].value_counts() > 1].index.tolist()

# %%
# Replace missing values with a randomly selected company ID
missing_indices = df['company_id'].isnull()
df.loc[missing_indices, 'company_id'] = np.random.choice(repeat_company_id, size=missing_indices.sum())

# %%
# Sanity Check
df.isnull().sum()/df.shape[0]*100
# Out:
# job_id                         0.000000
# company_id                     0.000000
# title                          0.000000
# description                    0.000000
# max_salary                    66.579438
# med_salary                    93.259339
# min_salary                    66.579438
# pay_period                     0.000000
# formatted_work_type            0.000000
# location                       0.000000
# applies                       51.158034
# original_listed_time           0.000000
# remote_allowed                85.556157
# views                         22.138002
# application_type               0.000000
# expiry                         0.000000
# formatted_experience_level     0.000000
# listed_time                    0.000000
# sponsored                      0.000000
# reposted                       0.000000
# skills_present                 0.000000
# application_portal             0.000000
# dtype: float64

# %% [markdown]
# #### Salary

# %% [markdown]
# Now let's take a look at the salaries data. There are three different salary variables: 'med_salary', 'min_salary' and 'max_salary'. We will perform some basic EDA to uncover any underlying patterns or correlations.

# %%
df['max_salary'].describe()
# Out:
# count    1.111100e+04
# mean     8.880883e+04
# std      8.764506e+04
# min      1.000000e+01
# 25%      5.100000e+01
# 50%      8.392800e+04
# 75%      1.400000e+05
# max      1.300000e+06
# Name: max_salary, dtype: float64

# %%
df['max_salary'].isna().sum()/df.shape[0]*100
# Out:
# 66.57943812789509

# %% [markdown]
# Let's create a visualization to observe the distribution of `max_salary` column.

# %%
plt.figure()

plt.hist(df['max_salary'], bins=40)
plt.axvline(df['max_salary'].mean(), color="lightcoral", label="mean")
plt.axvline(df['max_salary'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of max_salary - before imputation".title())
plt.xlabel("Max Salary Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `max_salary` data is right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df['max_salary'] = df['max_salary'].fillna(df['max_salary'].median())
df['max_salary'].isna().sum()
# Out:
# 0

# %%
# Sanity Check
df.isnull().sum()/df.shape[0]*100
# Out:
# job_id                         0.000000
# company_id                     0.000000
# title                          0.000000
# description                    0.000000
# max_salary                     0.000000
# med_salary                    93.259339
# min_salary                    66.579438
# pay_period                     0.000000
# formatted_work_type            0.000000
# location                       0.000000
# applies                       51.158034
# original_listed_time           0.000000
# remote_allowed                85.556157
# views                         22.138002
# application_type               0.000000
# expiry                         0.000000
# formatted_experience_level     0.000000
# listed_time                    0.000000
# sponsored                      0.000000
# reposted                       0.000000
# skills_present                 0.000000
# application_portal             0.000000
# dtype: float64

# %% [markdown]
# Null values from `max_salary` column has been filled with median values. We will now take a look at `min_salary`.

# %%
df['min_salary'].describe()
# Out:
# count     11111.000000
# mean      62650.128421
# std       58732.644143
# min           7.250000
# 25%          40.945000
# 50%       62128.000000
# 75%      100000.000000
# max      800000.000000
# Name: min_salary, dtype: float64

# %%
df['min_salary'].isna().sum()/df.shape[0]*100
# Out:
# 66.57943812789509

# %% [markdown]
# Let's create a visualization to observe the distribution of `min_salary` column.

# %%
plt.figure()

plt.hist(df['min_salary'], bins=40)
plt.axvline(df['min_salary'].mean(), color="lightcoral", label="mean")
plt.axvline(df['min_salary'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of min_salary - before imputation".title())
plt.xlabel("Min Salary Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `min_salary` data is right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df['min_salary'] = df['min_salary'].fillna(df['min_salary'].median())
df['min_salary'].isna().sum()
# Out:
# 0

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# job_id                         0.000000
# company_id                     0.000000
# title                          0.000000
# description                    0.000000
# max_salary                     0.000000
# med_salary                    93.259339
# min_salary                     0.000000
# pay_period                     0.000000
# formatted_work_type            0.000000
# location                       0.000000
# applies                       51.158034
# original_listed_time           0.000000
# remote_allowed                85.556157
# views                         22.138002
# application_type               0.000000
# expiry                         0.000000
# formatted_experience_level     0.000000
# listed_time                    0.000000
# sponsored                      0.000000
# reposted                       0.000000
# skills_present                 0.000000
# application_portal             0.000000
# dtype: float64

# %% [markdown]
# Null values from `min_salary` has been filled with median. Finally, we will observe the `med_salary` column and fill the missing values accordingly.

# %%
df['med_salary'].describe()
# Out:
# count      2241.000000
# mean      32426.170598
# std       76860.422528
# min           0.000000
# 25%          18.780000
# 50%          29.000000
# 75%       42746.000000
# max      998426.000000
# Name: med_salary, dtype: float64

# %%
df['med_salary'].isna().sum()/df.shape[0]*100
# Out:
# 93.25933946940985

# %% [markdown]
# Let's create a visualization to observe the distribution of `med_salary` column.

# %%
plt.figure()

plt.hist(df['med_salary'], bins=40)
plt.axvline(df['med_salary'].mean(), color="lightcoral", label="mean")
plt.axvline(df['med_salary'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of med_salary - before imputation".title())
plt.xlabel("Med Salary Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# Similar to `min_salary` and `max_salary`, `med_salary` is also heavily right skewed. However, the mean and median values are significantly less than the other two salary columns (median value near 0) due to high volume of missing values from `med_salary` column. Hence, we will impute those missing values using the `min_salary` and `max_salary` values.

# %%
df['med_salary'].fillna((df['min_salary'] + df['max_salary']) / 2, inplace=True)
# Out:
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_46404/868775850.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['med_salary'].fillna((df['min_salary'] + df['max_salary']) / 2, inplace=True)

# %%
df.sample(50)
# Out:
#            job_id  company_id  \
# 31141  3693050833      3556.0
# 6727   3757460053    153293.0
# 9221   3756134472  96642179.0
# 20378  3701164045  90518804.0
# 3532   3757701715     21337.0
# 7521   3757445983  15599730.0
# 33234  1004740969    882349.0
# 2524   3757731650    808034.0
# 5771   3757473814     24765.0
# 5876   3757471326   1264953.0
# 25719  3696993898     26923.0
# 6721   3757460071    166572.0
# 12892  3755575444     77097.0
# 23505  3697397451    165422.0
# 19195  3701312535     39189.0
# 1230   3757751220   3706049.0
# 12599  3755579670     11758.0
# 22221  3699084958  18527534.0
# 21401  3699410368      2251.0
# 4761   3757488984     12446.0
# 21281  3699413152   3159554.0
# 30712  3693053152     11229.0
# 33134  3635154108   2144424.0
# 31875  3693047625   2532635.0
# 27595  3693597505   2382910.0
# 6389   3757463900  33313988.0
# 7101   3757453906   1945473.0
# 928    3757768475     24494.0
# 13305  3755551932  14542824.0
# 4410   3757491758     11056.0
# 17112  3748838969   2689946.0
# 2108   3757736252     23379.0
# 1023   3757758001   5034592.0
# 12225  3755583480     18691.0
# 32094  3693046563    118698.0
# 26972  3694104220  86694680.0
# 4335   3757492257      7425.0
# 30034  3693064835   7972561.0
# 21726  3699401386  14542824.0
# 15764  3749350169    612493.0
# 10201  3756109809   2014725.0
# 23450  3697398617     37768.0
# 14817  3749367221    108340.0
# 2055   3757736780      2995.0
# 19785  3701303007   2396310.0
# 22899  3699061258      2162.0
# 21722  3699401415    383000.0
# 21237  3699414693   2524729.0
# 30020  3693064892  18506580.0
# 10569  3756104949  64639449.0
#
#                                                    title  \
# 31141  Assistant Professor, Questrom School of Busine...
# 6727                      Electrical Engineering Manager
# 9221                            Fire Protection Engineer
# 20378                              Mortgage Loan Officer
# 3532   Community Health Worker - Special Population (...
# 7521                             Chief Financial Officer
# 33234                                     Civil Engineer
# 2524   Travel - Telemetry - Nurse Job - $2447/wk - $2...
# 30712  Description: \nIncluding but not limited to ro...    83928.00
# 33134  Salary$18.00–$22.00 an hour DescriptionReporti...       22.00
# 31875  Commercial Property Manager, Medical Office - ...    83928.00
# 27595  Description\nThe Amazon Security Special Progr...   231400.00
# 6389   Allied Global Marketing is a leading full-serv...    50000.00
# 7101   Interested in making a positive impact? You’ve...    83928.00
# 928    Work Shift:\n\nWeekend Option (Day)\n\nTime Ty...    83928.00
# 13305  Job Name: ND - ICU RN - Day\n\nFacility Addres...    83928.00
# 4410   Insight Global is hiring for business savvy, p...    83928.00
# 17112  Role: Manual QA EngineerLocation: Remote (Need...    83928.00
# 2108   Summary Job Description\n\nPenn Medicine Lanca...    83928.00
# 1023   Are you a self-motivated, hands-on individual ...       25.00
# 12225  Optimal nutrition is an important part of good...    83928.00
# 32094  Lighthouse Lab Services seeks a Laboratory Sup...    99000.00
# 26972  About Ascendion\nAscendion is a full-service d...   114400.00
# 4335   Woodward’s Diversity, Inclusion and Belonging ...    83928.00
# 30034  About KariusKarius is a venture-backed life sc...    83928.00
# 21726  Emergency room nurse within a 5 bed Critical A...    83928.00
# 15764  Work with us and make a difference in Texas! \...    83928.00
# 10201  Who We Are\n\nCome and join us at Redis, where...   194000.00
# 23450  Company Overview\nMilestone Technologies is a ...   106000.00
# 14817  Overview\n\nDo you like to work in different a...    83928.00
# 2055   Summary\n\nThe ideal candidate has excellent c...    94199.00
# 19785  Looking for an experienced Procurement Analyst...       27.00
# 22899  What Application Development & Maintenance con...   126400.00
# 21722  At Libbey, we are all MAKERS. No matter what y...    83928.00
# 21237  The Pre-Marketing Specialist will support the ...       27.50
# 30020  Advantis Medical is seeking a travel nurse RN ...    83928.00
# 10569  Delivery Material Handler / Roof Loader\n\nJoi...    83928.00
#
#        med_salary  min_salary     pay_period formatted_work_type  \
# 31141   73028.000    62128.00  Not Specified           Full-time
# 6727    73028.000    62128.00  Not Specified           Full-time
# 9221    73028.000    62128.00  Not Specified           Full-time
# 20378   73028.000    62128.00  Not Specified           Full-time
# 3532    54250.000    62128.00         YEARLY           Full-time
# 7521    73028.000    62128.00  Not Specified           Full-time
# 33234   73028.000    62128.00  Not Specified           Full-time
# 2524    73028.000    62128.00  Not Specified           Part-time
# 5771   130000.000   120000.00         YEARLY           Full-time
# 5876    73028.000    62128.00  Not Specified           Full-time
# 25719   73028.000    62128.00  Not Specified           Part-time
# 6721    73028.000    62128.00  Not Specified           Full-time
# 12892   73028.000    62128.00  Not Specified            Contract
# 23505      26.190       20.94         HOURLY           Full-time
# 19195      38.125       35.00         HOURLY            Contract
# 1230       48.000    62128.00         HOURLY           Full-time
# 12599   45450.000    40400.00         YEARLY           Full-time
# 22221  190000.000   180000.00         YEARLY           Full-time
# 21401   73028.000    62128.00  Not Specified           Part-time
# 4761    73028.000    62128.00  Not Specified           Part-time
# 21281   92500.000    85000.00         YEARLY           Full-time
# 30712   73028.000    62128.00  Not Specified           Full-time
# 33134      20.000       18.00         HOURLY           Part-time
Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  33246 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   med_salary                  33246 non-null  float64
#  5   pay_period                  33246 non-null  object
#  6   formatted_work_type         33246 non-null  object
#  7   location                    33246 non-null  object
#  8   applies                     16238 non-null  float64
#  9   original_listed_time        33246 non-null  datetime64[ns]
#  10  remote_allowed              4802 non-null   float64
#  11  views                       25886 non-null  float64
#  12  application_type            33246 non-null  object
#  13  expiry                      33246 non-null  datetime64[ns]
#  14  formatted_experience_level  33246 non-null  object
#  15  listed_time                 33246 non-null  datetime64[ns]
#  16  sponsored                   33246 non-null  int64
#  17  reposted                    33246 non-null  int64
#  18  skills_present              33246 non-null  int64
#  19  application_portal          33246 non-null  int64
# dtypes: datetime64[ns](3), float64(5), int64(5), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# #### Applies

# %%
df['applies'].isna().sum()
# Out:
# 17008

# %%
df['applies'].isna().sum()/df.shape[0]
# Out:
# 0.5115803404920892

# %%
df['applies'].value_counts()
# Out:
# applies
# 1.0       3706
# 2.0       1954
# 3.0       1262
# 4.0        970
# 5.0        729
# 6.0        587
# 7.0        498
# 8.0        413
# 9.0        384
# 10.0       340
# 11.0       340
# 12.0       294
# 13.0       259
# 14.0       215
# 15.0       213
# 16.0       189
# 17.0       172
# 18.0       153
# 19.0       144
# 20.0       127
# 21.0       116
# 22.0       108
# 51.0       104
# 24.0       102
# 23.0       101
# 26.0        88
# 25.0        86
# 28.0        84
# 27.0        83
# 31.0        80
# 29.0        73
# 30.0        67
# 32.0        60
# 34.0        58
# 52.0        54
# 35.0        54
# 33.0        52
# 36.0        48
# 44.0        46
# 38.0        44
# 42.0        43
# 41.0        43
# 43.0        41
# 46.0        41
# 55.0        40
# 40.0        39
# 48.0        38
# 53.0        37
# 39.0        37
# 45.0        36
# 49.0        35
# 37.0        34
# 54.0        31
# 47.0        28
# 50.0        28
# 65.0        26
# 56.0        24
# 67.0        23
# 69.0        23
# 71.0        22
# 60.0        21
# 82.0        20
# 68.0        20
# 66.0        19
# 59.0        19
# 61.0        19
# 64.0        19
# 62.0        19
# 58.0        18
# 77.0        18
# 72.0        18
# 75.0        17
# 76.0        17
# 57.0        17
# 79.0        16
# 63.0        15
# 78.0        15
# 70.0        15
# 84.0        15
# 81.0        15
# 86.0        14
# 74.0        14
# 105.0       12
# 94.0        12
# 92.0        11
# 112.0       10
# 88.0        10
# 102.0       10
# 114.0       10
# 80.0        10
# 103.0       10
# 85.0        10
# 87.0         9
# 83.0         9
# 93.0         9
# 97.0         9
# 95.0         8
# 91.0         8
# 99.0         8
# 96.0         8
# 100.0        8
# 98.0         8
# 110.0        8
# 101.0        8
# 73.0         8
# 104.0        7
# 199.0        7
# 134.0        7
# 131.0        7
# 162.0        7
# 117.0        7
# 123.0        7
# 90.0         6
# 116.0        6
# 118.0        6
# 115.0        6
# 147.0        6
# 106.0        6
# 126.0        6
# 149.0        6
# 120.0        5
# 177.0        5
# 137.0        5
# 113.0        5
# 122.0        5
# 89.0         5
# 127.0        5
# 144.0        5
# 125.0        5
# 128.0        5
# 156.0        5
# 188.0        5
# 154.0        5
# 159.0        5
# 129.0        5
# 169.0        5
# 170.0        5
# 142.0        5
# 109.0        5
# 172.0        5
# 174.0        4
# 140.0        4
# 132.0        4
# 146.0        4
# 145.0        4
# 119.0        4
# 214.0        4
# 212.0        4
# 135.0        4
# 245.0        4
# 171.0        4
# 143.0        4
# 141.0        3
# 290.0        3
# 278.0        3
# 107.0        3
# 150.0        3
# 161.0        3
# 176.0        3
# 133.0        3
# 219.0        3
# 152.0        3
].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of applies - before imputation".title())
plt.xlabel("Applies Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `applies` data is heavily right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df['applies'] = df['applies'].fillna(df['applies'].median())

# %%
df['applies'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Views

# %%
df['views'].isna().sum()
# Out:
# 7360

# %%
df['views'].isna().sum()/df.shape[0]*100
# Out:
# 22.138001564097937

# %%
df['views'].describe()
# Out:
# count    25886.000000
# mean        58.339875
# std        141.253774
# min          1.000000
# 25%          4.000000
# 50%         16.000000
# 75%         54.000000
# max       5656.000000
# Name: views, dtype: float64

# %%
df['views'].value_counts()
# Out:
# views
# 1.0       2850
# 2.0       1839
# 3.0       1364
# 4.0       1030
# 5.0        874
# 6.0        744
# 7.0        645
# 8.0        578
# 9.0        543
# 10.0       438
# 11.0       437
# 14.0       401
# 12.0       365
# 16.0       360
# 13.0       355
# 15.0       329
# 17.0       317
# 18.0       301
# 19.0       289
# 20.0       277
# 22.0       258
# 21.0       254
# 25.0       227
# 23.0       225
# 24.0       223
# 26.0       211
# 30.0       183
# 28.0       180
# 27.0       178
# 31.0       172
# 29.0       166
# 32.0       164
# 33.0       157
# 34.0       157
# 35.0       150
# 38.0       149
# 39.0       143
# 37.0       143
# 41.0       141
# 40.0       140
# 36.0       137
# 44.0       129
# 43.0       122
# 45.0       120
# 50.0       116
# 42.0       111
# 49.0       110
# 52.0       104
# 47.0       100
# 56.0        99
# 54.0        96
# 58.0        95
# 48.0        90
# 46.0        88
# 55.0        88
# 51.0        88
# 57.0        87
# 61.0        85
# 53.0        83
# 60.0        82
# 59.0        79
# 62.0        79
# 71.0        69
# 65.0        68
# 63.0        67
# 69.0        67
# 78.0        65
# 70.0        64
# 72.0        63
# 64.0        61
# 68.0        61
# 75.0        61
# 81.0        60
# 66.0        60
# 73.0        58
# 79.0        56
# 74.0        53
# 76.0        53
# 86.0        51
# 90.0        50
# 87.0        49
# 67.0        49
# 84.0        49
# 83.0        48
# 92.0        47
# 94.0        47
# 88.0        46
# 80.0        46
# 77.0        46
# 95.0        45
# 91.0        43
# 85.0        43
# 89.0        43
# 101.0       43
# 99.0        43
# 93.0        42
# 82.0        42
# 96.0        39
# 104.0       39
# 126.0       38
# 111.0       38
# 105.0       37
# 102.0       36
# 97.0        35
# 98.0        35
# 108.0       35
# 106.0       34
# 100.0       33
# 132.0       33
# 110.0       32
# 109.0       32
# 124.0       32
# 123.0       31
# 103.0       31
# 129.0       31
# 117.0       31
# 112.0       31
# 118.0       31
# 115.0       30
# 114.0       30
# 116.0       30
# 141.0       30
# 133.0       29
# 121.0       28
# 107.0       27
# 125.0       27
# 113.0       26
# 152.0       26
# 149.0       26
# 120.0       25
# 144.0       25
# 148.0       25
# 147.0       24
# 128.0       24
# 145.0       24
# 119.0       24
# 158.0       23
# 184.0       23
# 168.0       23
# 137.0       23
# 122.0       23
# 142.0       22
# 131.0       22
# 130.0       22
# 157.0       22
# 136.0       22
# 127.0       22
# 154.0       20
# 151.0       20
# 134.0       19
# 162.0       19
# 138.0       19
# 160.0       18
# 173.0       18
# 165.0       18
# 140.0       17
# 155.0       17
# 170.0       17
# 215.0       17
# 156.0       17
# 183.0       16
# 135.0       16
# 161.0       16
# 150.0       16
# 177.0       16
# 197.0       16
# 143.0       15
# 166.0       15
# 159.0       15
# 139.0       15
# 200.0       15
# 199.0       15
# 207.0       15
# 172.0       15
# 163.0       15
# 182.0       14
# 153.0       14
# 178.0       14
# 195.0       14
# 204.0       14
# 171.0       13
# 227.0       13
# 216.0       13
# 180.0       13
# 226.0       13
# 220.0       13
# 196.0       13
# 186.0       13
# 209.0       13
# 167.0       13
# 146.0       13
# 218.0       13
# 174.0       13
# 284.0       13
# 259.0       12
# 181.0       12
# 221.0       12
# 194.0       12
# 247.0       12
# 201.0       12
# 188.0       12
# 213.0       12
# 176.0       12
# 191.0       11
# 202.0       11
# 192.0       11
# 164.0       11
# 169.0       11
# 198.0       11
# 258.0       11
# 275.0       11
# 211.0       11
# 229.0       11
# 295.0       10
# 228.0       10
# 256.0       10
# 244.0       10
# 233.0       10
# 237.0       10
# 232.0       10
# 257.0       10
# 266.0        9
# 262.0        9
# 190.0        9
# 189.0        9
# 206.0        9
# 230.0        9
# 179.0        9
# 203.0        9
# 238.0        9
# 235.0        9
# 234.0        9
# 185.0        9
# 248.0        8
# 243.0        8
# 212.0        8
# 214.0        8
# 281.0        8
# 187.0        8
# 297.0        8
# 276.0        8
# 285.0        8
# 208.0        8
# 219.0        8
# 225.0        8
# 224.0        8
# 175.0        7
# 249.0        7
# 193.0        7
# 305.0        7
# 263.0        7
# 223.0        7
# 241.0        7
# 236.0        7
# 282.0        7
# 329.0        7
# 205.0        7
# 311.0        7
# 273.0        7
# 255.0        7
# 479.0        6
# 242.0        6
# 272.0        6
# 300.0        6
# 294.0        6
# 411.0        6
# 291.0        6
# 319.0        6
# 302.0        6
# 239.0        6
# 309.0        6
# 323.0        6
# 240.0        6
# 265.0        6
# 231.0        6
# 308.0        6
# 290.0        6
# 280.0        6
# 293.0        6
# 254.0        6
# 330.0        6
# 316.0        6
# 279.0        6
# 296.0        5
# 303.0        5
# 467.0        5
# 462.0        5
# 416.0        5
# 488.0        5
# 341.0        5
# 271.0        5
# 261.0        5
# 250.0        5
# 287.0        5
# 426.0        5
# 313.0        5
# 350.0        5
# 253.0        5
# 289.0        5
# 310.0        5
# 332.0        5
# 380.0        5
# 347.0        5
# 298.0        5
# 325.0        4
# 434.0        4
# 447.0        4
# 358.0        4
# 360.0        4
# 476.0        4
# 543.0        4
# 436.0        4
# 455.0        4
# 438.0        4
# 345.0        4
# 372.0        4
# 346.0        4
# 412.0        4
# 338.0        4
# 402.0        4
# 501.0        4
# 397.0        4
# 429.0        4
# 349.0        4
# 362.0        4
# 269.0        4
# 267.0        4
# 357.0        4
# 514.0        4
# 335.0        4
# 264.0        4
# 536.0        4
# 559.0        4
# 278.0        4
# 334.0        4
# 389.0        4
# 344.0        4
# 368.0        4
# 286.0        4
# 210.0        4
# 268.0        4
# 288.0        4
# 301.0        4
# 217.0        4
# 2151.0       1
# 1062.0       1
# 657.0        1
# 829.0        1
# 685.0        1
# 716.0        1
# 938.0        1
# 410.0        1
# 1792.0       1
# 491.0        1
# 428.0        1
# 821.0        1
# 572.0        1
# 849.0        1
# 618.0        1
# 644.0        1
# 616.0        1
# 5656.0       1
# 760.0        1
# 740.0        1
# 776.0        1
# 640.0        1
# 430.0        1
# 1885.0       1
# 888.0        1
# 2478.0       1
# 1922.0       1
# 1073.0       1
# 781.0        1
# 974.0        1
# 725.0        1
# 763.0        1
# 744.0        1
# 811.0        1
# 1382.0       1
# 1334.0       1
# 729.0        1
# 1972.0       1
# 1133.0       1
# 528.0        1
# 510.0        1
# 928.0        1
# 745.0        1
# 677.0        1
# 2245.0       1
# 656.0        1
# 1459.0       1
# 424.0        1
# 631.0        1
# 791.0        1
# 891.0        1
# 1136.0       1
# 612.0        1
# 878.0        1
# 1241.0       1
# 454.0        1
# 1433.0       1
# 571.0        1
# 457.0        1
# 956.0        1
# 793.0        1
# 604.0        1
# 972.0        1
# 858.0        1
# 1151.0       1
# 554.0        1
# 458.0        1
# 715.0        1
# 437.0        1
# 1256.0       1
# 1555.0       1
# 812.0        1
# Name: count, dtype: int64

# %% [markdown]
# Let's create a visualization to observe the distribution of `views` column.

# %%
plt.figure()

plt.hist(df['views'], bins=40)
plt.axvline(df['views'].mean(), color="lightcoral", label="mean")
plt.axvline(df['views'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of views - before imputation".title())
plt.xlabel("Views Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %% [markdown]
# The histogram show that the `views` data is heavily right skewed, which signals that there are some outliers skewing the data. The presence of outliers distorts the mean value, thus we will use median value to fill the missing values.

# %%
df['views'] = df['views'].fillna(df['views'].median())

# %%
df['views'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Remote Allowed

# %%
df['remote_allowed'].describe()
# Out:
# count    4802.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: remote_allowed, dtype: float64

# %%
df['remote_allowed'].value_counts()
# Out:
# remote_allowed
# 1.0    4802
# Name: count, dtype: int64

# %% [markdown]
# The dataset only contains the response of '1'. This is likely due to an error in the data collection process. For instance, the data may have been encoded in a way that only captures instances where remote work is allowed, and other scenarios (where remote work is not allowed) are not explicitly represented in the dataset.

# %%
df['remote_allowed'].isna().sum()/df.shape[0]*100
# Out:
# 85.55615713168501

# %% [markdown]
# To fill in the null values, we will convert this variable into a binary column (0 and 1). Here, we are making an assumption that '0' will represent the missing values (remote-working not allowed), and '1' will be remote working allowed responses. We can simply fill the missing values in with 0s to achieve this.

# %%
# Fill in the missing values with the entries of '0'
df['remote_allowed'] = df['remote_allowed'].fillna(0)
df['remote_allowed'].isna().sum()
# Out:
# 0

# %%
# Sanity Check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  33246 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   med_salary                  33246 non-null  float64
#  5   pay_period                  33246 non-null  object
#  6   formatted_work_type         33246 non-null  object
#  7   location                    33246 non-null  object
#  8   applies                     33246 non-null  float64
#  9   original_listed_time        33246 non-null  datetime64[ns]
#  10  remote_allowed              33246 non-null  float64
#  11  views                       33246 non-null  float64
#  12  application_type            33246 non-null  object
#  13  expiry                      33246 non-null  datetime64[ns]
#  14  formatted_experience_level  33246 non-null  object
#  15  listed_time                 33246 non-null  datetime64[ns]
#  16  sponsored                   33246 non-null  int64
#  17  reposted                    33246 non-null  int64
#  18  skills_present              33246 non-null  int64
#  19  application_portal          33246 non-null  int64
# dtypes: datetime64[ns](3), float64(5), int64(5), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# We have completed all the data cleaning processes by filling in the null values. Now we will plot some graphs to analyze any patterns that may occur to address our question of interest: "Is there any relationships between the `views` column and other job attributes within the `job_postings` dataset?"

# %% [markdown]
# <a id = 'EDA'><a/>
# ## Preliminary EDA
#
# ---

# %% [markdown]
# We will begin by creating some visualizations to depict any relationships between the `views` column and other variables. Our goal is to see if there are any patterns within the dataset to analyze the job trends regarding the `views` column. We will begin by looking at various distributions of variables and their counts.

# %%
df.shape
# Out:
# (33246, 20)

# %% [markdown]
# We will separate the variables according to their data types, 'numerical' vs 'categorical'.

# %%
df.select_dtypes(["float", "int"]).columns
# Out:
# Index(['job_id', 'company_id', 'med_salary', 'applies', 'remote_allowed',
#        'views', 'sponsored', 'reposted', 'skills_present',
#        'application_portal'],
#       dtype='object')

# %%
df.select_dtypes(["object"]).columns
# Out:
# Index(['title', 'description', 'pay_period', 'formatted_work_type', 'location',
#        'application_type', 'formatted_experience_level'],
#       dtype='object')

# %% [markdown]
# We will also check for the datetime columns within the dataset.

# %%
df.select_dtypes(["datetime"]).columns
# Out:
# Index(['original_listed_time', 'expiry', 'listed_time'], dtype='object')

# %% [markdown]
# For visualization, we will group variables into their respective data types. For numerical column, we will include all the 'int' and 'float' variables except 'job_id' and 'company_id'. This is because these columns contain unique values for labelling purposes, insignificant to our analysis.

# %%
numerical_cols=['med_salary','applies', 'remote_allowed', 'views', 
               'sponsored', 'reposted', 'skills_present', 'application_portal']

# %% [markdown]
# In 'object' data types, we will leave out 'title', 'description' and 'location' columns as these categorical columns need further investigation and cleaning.

# %%
categorical_cols=['pay_period', 'formatted_work_type',
       'application_type', 'formatted_experience_level']

# %%
datetime_cols=['original_listed_time', 'expiry', 'listed_time']

# %%
# Visualizations for numeric data
for col in numerical_cols:
    sns.histplot(data=df, x=col, bins=10)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# It's hard to understand non-binary columns like `med_salary`, `applies` and `views` by just looking at these bar graphs, hence we will plot these variables individually to gain some better insights.

# %%
plt.figure()

plt.hist(df['med_salary'], bins=40)
plt.axvline(df['med_salary'].mean(), color="lightcoral", label="mean")
plt.axvline(df['med_salary'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of med_salary - after imputation".title())
plt.xlabel("Med Salary Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %%
df['med_salary'].describe()
# Out:
# count    3.324600e+04
# mean     7.119402e+04
# std      4.724055e+04
# min      0.000000e+00
# 25%      7.302800e+04
# 50%      7.302800e+04
# 75%      7.302800e+04
# max      1.050000e+06
# Name: med_salary, dtype: float64

# %%
plt.figure()

plt.hist(df['applies'], bins=40)
plt.axvline(df['applies'].mean(), color="lightcoral", label="mean")
plt.axvline(df['applies'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of applies - after imputation".title())
plt.xlabel("Applies Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %%
df['applies'].describe()
# Out:
# count    33246.000000
# mean        11.786711
# std         34.981863
# min          1.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.000000
# max       1615.000000
# Name: applies, dtype: float64

# %%
plt.figure()

plt.hist(df['views'], bins=40)
plt.axvline(df['views'].mean(), color="lightcoral", label="mean")
plt.axvline(df['views'].median(), color="lightcoral", linestyle="--", label="median")

plt.title("Distribution of views - after imputation".title())
plt.xlabel("Views Bins")
plt.ylabel("Counts")


plt.legend()
plt.show()

# %%
df['views'].describe()
# Out:
# count    33246.000000
# mean        48.966673
# std        125.874522
# min          1.000000
# 25%          6.000000
# 50%         16.000000
# 75%         38.000000
# max       5656.000000
# Name: views, dtype: float64

# %% [markdown]
# Analysis:
# - med_salary, applies, and views are all heavily right skewed, indication of some extreme values (outliers) within the dataset.
# - The average median salary is around 70k.
# - On average, each job post receives about 12 applications.
# - On average, each job posting gets approximately 49 views.
# - Majority of the companies do not allow remote working.
# - Only 1/4 of the companies promote their job postings (sponsored).
# - Only 30 percent of the companies repost their job postings.
# - Majority of the companies do not include skills description within their job postings.
# - Roughly 60 percent of the job applicants apply through LinkedIn directly.

# %%
for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.set(style="whitegrid")
    ax = sns.countplot(data=df, x=col, order=df[col].value_counts().index,color='coral')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    
    # Adding count labels above the bars
    for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points', rotation=45)
    
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# Analysis:
# - Yearly pay period option seems to be the most popular, followed by hourly and monthly. This may be due to the work type. For instance, with more full-time positions available in the market, the higher chance of pay period being yearly (salary), instead of hourly which is more associated with part time jobs.
# - Correspondingly, full time positions were the most demanded work type, followed by contract and part time.
# - Roughly 60 percent of the job applications are submitted through various online platforms.
# - Companies are in need for mid-senior level talents to fill in the vancancies. Entry level and associate positions seem to be in demand as well, but not as much as experienced workers that are considered to be in mid-senior level.

# %%
for col in datetime_cols:
    sns.histplot(data=df, x=col, bins=10)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# The distribution of datetime variables display that the majority of the job were posted in September and November of 2023, followed by the expiration in October and December. From this, we can assume that most of the job post duration is a month. Unfortunately, since we have limited access to the time information since the data only consists of 2 periods of job listed time, we will not be able to conduct time analysis for more in-depth analysis.

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    plt.scatter(df[col], df['views'], alpha=0.5)
    plt.title(f'Scatter plot of {col} vs. Number of Views')
    plt.xlabel(col)
    plt.ylabel('Views')
    plt.grid(True)
    plt.show()

# %% [markdown]
# Analysis:
# - There is a weak positive relationship between median salary and number of views.
# - There is a moderately positive relationship between number of applications submitted and number of views.

# %%
for col in categorical_cols:
    # Calculate mean views per category and sort them in descending order
    sorted_df = df.groupby(col)['views'].mean().reset_index()
    sorted_df = sorted_df.sort_values('views', ascending=False)
    
    # Create the bar plot
    plt.figure(figsize=(10, 6))
    sns.barplot(x=col, y='views', data=sorted_df, ci=None)
    plt.title(f'Average Views by {col}')
    plt.xlabel(col)
    plt.ylabel('Average Views')
    plt.xticks(rotation=45)  # Rotate x-axis labels if needed
    plt.show()
# Out:
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_46404/2173964818.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='views', data=sorted_df, ci=None)
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_46404/2173964818.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='views', data=sorted_df, ci=None)
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_46404/2173964818.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='views', data=sorted_df, ci=None)
# /var/folders/5d/y_cf75vx4c9dxq1445qbw6pc0000gn/T/ipykernel_46404/2173964818.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y='views', data=sorted_df, ci=None)

# %% [markdown]
# Analysis:
# - Yearly pay period recorded the highest number of views on average, followed by Not Specified, Hourly, and Monthly. This suggests that most of the companies prefer to list their compensation information in yearly salary format.
# - The most popular work type seems to be contract and internship as the two categories recorded high number of views. This reflects job applicants' preference as they seem to opt for short-term positions, instead of full-time, long-term positions. There could be several reasons leading to this phenomenon, such as seasonality.
# - Onsite applying methods seem to be more popular than offsite (online) applying methods, such as job fair, networking events and more. Further investigation is needed to study this behaviour.
# - Lastly, higher level positions seem to be in demand, such as director and executive. This trend aligns with the trend observed in the pay_period section where the yearly payment was the most popular option. On the other hand, lower level positions like entry level and internship roles seem to be relatively less popular. The above trends reflect the job market trends at the time data was collected.

# %%
# Check data types of DataFrame columns
data_types = df.dtypes

# Filter columns with object data type
string_columns = data_types[data_types == 'object'].index.tolist()

# Check for string values in each column
for column in string_columns:
    unique_values = df[column].unique()
    if len(unique_values) <= 10:  
        print(f"Unique values in column '{column}': {unique_values}")
    else:
        print(f"Column '{column}' contains many unique values.")
# Out:
# Column 'title' contains many unique values.
# Column 'description' contains many unique values.
# Unique values in column 'pay_period': ['MONTHLY' 'Not Specified' 'HOURLY' 'YEARLY' 'WEEKLY' 'ONCE']
# Unique values in column 'formatted_work_type': ['Full-time' 'Contract' 'Other' 'Part-time' 'Volunteer' 'Temporary'
#  'Internship']
# Column 'location' contains many unique values.
# Unique values in column 'application_type': ['OffsiteApply' 'SimpleOnsiteApply' 'ComplexOnsiteApply']
# Unique values in column 'formatted_experience_level': ['Entry level' 'Not Specified' 'Mid-Senior level' 'Director' 'Associate'
#  'Executive' 'Internship']

# %% [markdown]
# We have 7 categorical columns in the dataset. In the next notebook where we conduct our advanced EDA, we will use feature engineering to convert these categorical variables into numerical variables to create a heatmap to observe the correlations among different job attributes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      33246 non-null  int64
#  1   company_id                  33246 non-null  float64
#  2   title                       33246 non-null  object
#  3   description                 33246 non-null  object
#  4   med_salary                  33246 non-null  float64
#  5   pay_period                  33246 non-null  object
#  6   formatted_work_type         33246 non-null  object
#  7   location                    33246 non-null  object
#  8   applies                     33246 non-null  float64
#  9   original_listed_time        33246 non-null  datetime64[ns]
#  10  remote_allowed              33246 non-null  float64
#  11  views                       33246 non-null  float64
#  12  application_type            33246 non-null  object
#  13  expiry                      33246 non-null  datetime64[ns]
#  14  formatted_experience_level  33246 non-null  object
#  15  listed_time                 33246 non-null  datetime64[ns]
#  16  sponsored                   33246 non-null  int64
#  17  reposted                    33246 non-null  int64
#  18  skills_present              33246 non-null  int64
#  19  application_portal          33246 non-null  int64
# dtypes: datetime64[ns](3), float64(5), int64(5), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# The preliminary EDA has been completed. Now we will save the cleaned data and conduct further analysis in a new notebook using the cleaned dataset.

# %%
# Save the DataFrame to a CSV file in the 'Data' folder
df.to_csv("../Data/clean_linkedin_job_posting.csv", index=False)

# %% [markdown]
# <a id = 'Summary'><a/>
# ## Summary
#
# ---

# %% [markdown]
# In this notebook, we performed an analysis of a job posting dataset from LinkedIn, focusing on the `views` variable. The preliminary analysis included data loading, data cleaning, and basic & advanced EDA with visualization. Through experimentation, we were able to see the impacts of various job posting features, such as the experience level, number of applications submitted, median salary and more. The basic EDA analysis culminated in visualizations and insights aimed at understanding the job market trends, with an emphasis on number of views. This notebook continues to "Part_Two_LinkedIn_Advanced_EDA_and_Modeling.ipynb" notebook.
